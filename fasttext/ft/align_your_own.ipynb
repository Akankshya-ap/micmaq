# %% [markdown]
# # So, show me how to align two vector spaces for myself!

# %% [markdown]
# No problem. We're going to run through the example given in the README again, and show you how to learn your own transformation to align the French vector space to the Russian vector space.
#
# First, let's define a few simple functions...

# %%
import numpy as np
from fasttext import FastVector

# from https://stackoverflow.com/questions/21030391/how-to-normalize-array-numpy
def normalized(a, axis=-1, order=2):
    """Utility function to normalize the rows of a numpy array."""
    l2 = np.atleast_1d(np.linalg.norm(a, order, axis))
    l2[l2==0] = 1
    return a / np.expand_dims(l2, axis)

def make_training_matrices(source_dictionary, target_dictionary, bilingual_dictionary):
    """
    Source and target dictionaries are the FastVector objects of
    source/target languages. bilingual_dictionary is a list of 
    translation pair tuples [(source_word, target_word), ...].
    """
    source_matrix = []
    target_matrix = []

    for (source, target) in bilingual_dictionary:
        #print source,target
        if source in source_dictionary and target in target_dictionary:
            #print source, target
            source_matrix.append(source_dictionary[source])
            target_matrix.append(target_dictionary[target])

    # return training matrices
    return np.array(source_matrix), np.array(target_matrix)

def learn_transformation(source_matrix, target_matrix, normalize_vectors=True):
    """
    Source and target matrices are numpy arrays, shape
    (dictionary_length, embedding_dimension). These contain paired
    word vectors from the bilingual dictionary.
    """
    # optionally normalize the training vectors
    if normalize_vectors:
        source_matrix = normalized(source_matrix)
        print len(source_matrix.transpose())
        target_matrix = normalized(target_matrix)

    # perform the SVD
    product = np.matmul(source_matrix.transpose(), target_matrix)
    U, s, V = np.linalg.svd(product)

    # return orthogonal transformation which aligns source language to the target
    return np.matmul(U, V)

# %% [markdown]
# Now we load the English and Micmaq word vectors, and evaluate the similarity of "one" and "newt":

# %%
en_dictionary = FastVector(vector_file='/home/apatra/fastText/fastText_multilingual-master/eng.vec')
mi_dictionary = FastVector(vector_file='/home/apatra/fastText/fastText_multilingual-master/mic.vec')

en_vector = en_dictionary["one"]
mi_vector = mi_dictionary["newt"]
print(FastVector.cosine_similarity(en_vector, mi_vector))
# Out:
# reading word vectors from /home/apatra/fastText/fastText_multilingual-master/eng.vec
# reading word vectors from /home/apatra/fastText/fastText_multilingual-master/mic.vec
# -0.05159327789053213

# %% [markdown]
# "chat" and "кот" both mean "cat", so they should be highly similar; clearly the two word vector spaces are not yet aligned. To align them, we need a bilingual dictionary of French and Russian translation pairs. As it happens, this is a great opportunity to show you something truly amazing...
#
# Many words appear in the vocabularies of more than one language; words like "alberto", "london" and "presse". These words usually mean similar things in each language. Therefore we can form a bilingual dictionary, by simply extracting every word that appears in both the French and Russian vocabularies.

# %%
print mi_dictionary.word2id.keys()
# Out:
# ['aklasiewaloqsultiji', 'esma\xe2\x80\x99titl', 'gelulatl', 'etlitum', "gi'lewei", 'ta\xe2\x80\x99ntelmilamuksit', 'litaqnwikas\xe2\x80\x99kl', 'mimajuinuigtug', 'atkitemi', 'mikwite\xe2\x80\x99tmu', 'kaqimaliaptiksip', 'maqamikekkiskuk', 'kiwto\xe2\x80\x99qa\xe2\x80\x99sikewe\xe2\x80\x99l', 'elakutultijik', "apgwa'tuan", 'jijgluewjig', 'iknemat', 'chiasso', 'pilue\xe2\x80\x99', "pma'toq", 'nemiatijel', "wels'tua'tigul", "we'wasitew", 'wtuisunmual', 'iknemaj', 'wuji', "wejgwa'lawoqo", 'teke\xe2\x80\x99k', "nasgua'tiji", 'telkisi', 'mawelkisnl', 'mawelkisni', "a'tugwaqa", 'tetpoqpilaqn', 'china', "pilato'q", 'westawu\xe2\x80\x99lkw', 'pajjoqe\xe2\x80\x99kemk', 'kidi', 'kisilukewknew', 'kisikuitl', "ukwita'q", 'apu\xe2\x80\x99ksinew', 'seskutaq', "la'lukete", 'wije\xe2\x80\x99wmi\xe2\x80\x99ti', "ta'n", 'battiste', "un'jan", "gji'jiaqat", 'nutaptukl', "a'so'q", '(rattle)', 'ntawa\xe2\x80\x99qa\xe2\x80\x99taqatijik', 'pemi______________elkomiktule', 'nutankuat', 'weleywioqipetlin\xe2\x80\x99tuanek', "te'sukunit", 'ktantekelin', 'eleka\xe2\x80\x99lik', 'kmu\xe2\x80\x99ji\xe2\x80\x99jek', 'puljaynewe\xe2\x80\x99l', 'ekna\xe2\x80\x99muksiekipnil', 'mime\xe2\x80\x99jk', 'mime\xe2\x80\x99jl', 'eliaqi', 'company\xe2\x80\x9d', 'eliaql', 'wejkwita\xe2\x80\x99jik', 'utmikemaimua', 'pitewey', 'keknuika', "gisgaja'tuloqol", 'pemkaqieji', "apgnua'la'titl", 'flossie', '(tkn', 'aqqtetpapo\xe2\x80\x99tasin', 'iknmutl', 'eliewap', 'wenitia\xe2\x80\x99mu', 'amalintuaqen(bernie', 'tewijo\xe2\x80\x99ltisnik', 'poqtukwatmi\xe2\x80\x99tis', 'elu\xc3\xa9ultiek', 'sapa\xe2\x80\x99lukwekaq', 'epjilaasi', 'walipo', 'wales', 'kisimkumie\xe2\x80\x99ja\xe2\x80\x99lsipni', 'piskwikiaqel', 'pukwelki\xe2\x80\x99', 'wutmo\xe2\x80\x99taqnuow', 'mawo\xe2\x80\x99ltimk', 'wooden', "mijua'ji'j", 'teli\xe2\x80\x99sultijik', 'lapilaskiktu', "a'suguanew", 'allan', 'la\xe2\x80\x99tuaten', 'kaqta\xe2\x80\x99w', 'tetkep', 'sespete\xe2\x80\x99tme', 'weskunmi\xe2\x80\x99tij', 'nujkimesawek', 'wejuowk', "l'napskuk", 'elmi\xe2\x80\x99knik', "a'ma", 'kanataewa\xe2\x80\x99ki', 'ajitaqw', "u'nakie", 'ewle\xe2\x80\x99jinwe\xe2\x80\x99kwanman', "newte'it", 'pulwel', 'ntupun', "ewi'tasikl", 'kqetejkewaq', 'siawi\xe2\x80\x99pi', "nemi'wo", 'ankite\xe2\x80\x99te\xe2\x80\x99n', 'kaqtukewik', "moqopa'qigtu", "waltesta'tiji", "mi'kama'ki", 'we\xe2\x80\x99jito\xe2\x80\x99q', 'ika\xe2\x80\x99taqney', 'jikla\xe2\x80\x99tuaq', 'kepmitetemitij', "kina'matinewey", "taqtmi'tisni'klthey", 'wlianko\xe2\x80\x99ta', "mijuaji'tl", "ugs'tuaqa", 'emteskemewey', 'teliewla\xe2\x80\x99luj', "wantaqitpa\xe2\x80\x99qwa'ntaqitpa'", "kelnmi'tij", 'wikitaq', 'eliujik', 'apaja\xe2\x80\x99tuekip', 'eli\xe2\x80\x99kik', 'klutjieweymkkekkam', 'apjila\xe2\x80\x99lajlaq', 'wokemaq', 'gelulapnn', 'piteleyiktuk', 'wkwija', 'tesipunqek', 'wkwijl', 'ewikultiyeq', 'mataqa\xe2\x80\x99taqanewe\xe2\x80\x99wk', 'eykipni\xe2\x80\x99k', 'tapuipunqekl', 'utwikuwomk', 'telimultes', 'amsamisukisipnekit', 'teloqsit', "e'pilitl", 'apoqonmua\xe2\x80\x99tijik', "ugt'pung", 'mkite\xe2\x80\x99lmule', "unaqa'sitew", 'newtqo\xe2\x80\x99ltijik', "elmita'jik", "un'janultioqosn", 'mawiamskwesewe\xe2\x80\x99k', 'ejiklo\xe2\x80\x99likitipni\xe2\x80\x99k', 'mawiamskwesewe\xe2\x80\x99l', 'alsumaji', 'telkwitamemk', "ewi'tmi'titl", 'ktiyultipo', 'teliaqsi', 'telujimtua\xe2\x80\x99lukwi\xe2\x80\x99tij', '(puksuk)', 'nenuioq', 'winitpalamu', 'telitasuwaqenn', 'kesp\xc3\xa9', 'lukewinuey', 'samqwanji\xe2\x80\x99j', '\xe2\x80\x9cjukwita\xe2\x80\x99q', "telimg'pni", 'pewatmi\xe2\x80\x99tijnutjinaq', 'nutaptmn', 'metua\xe2\x80\x99si', 'nqasuenu', 'kespia', 'umaposemuwa', 'pilitokamonuhkiyi', 'kespit', 'sipuknemitumk', 'teliputuwaj', 'mawoluhkhotiye', 'union', 'telpewatmi\xe2\x80\x99tij', 'wja\xe2\x80\x99tui', "lta'woq", 'kaqlukweyane', 'atlasmit', 'matnewey', "nuta'maie", "gepmitelmi'gw", 'dave', 'utqutaqanmg', 'tankoqwey', "gigja's'g", 'eltu\xe2\x80\x99tij', 'wenaqiaq', 'kisiwi\xe2\x80\x99kikl', 'eltu\xe2\x80\x99tis', 'l\xe2\x80\x99nueym', 'kespeke ...

# %%
mi_words = set(mi_dictionary.word2id.keys())
en_words = set(en_dictionary.word2id.keys())
overlap = list(mi_words & en_words)
bilingual_dictionary = [(entry, entry) for entry in overlap]

# %%
#print len(en_vector)
#print mi_dictionary.word2id.keys()
#print mi_words
#print overlap
#for x in en_dictionary.word2id.keys():
#print x
#print len(en_dictionary.word2id.keys())
#print en_words
print bilingual_dictionary
# Out:
# [('writings', 'writings'), ('andre', 'andre'), ('negl', 'negl'), ('captain', 'captain'), ('paris', 'paris'), ('aul', 'aul'), ('edward', 'edward'), ('wji', 'wji'), ('saskatchewan', 'saskatchewan'), ('phial', 'phial'), ('jack', 'jack'), ('school', 'school'), ('whitman', 'whitman'), ('wooden', 'wooden'), ('herbert', 'herbert'), ('burke', 'burke'), ('enta', 'enta'), ('mius', 'mius'), ('nige', 'nige'), ('horu', 'horu'), ('lavery', 'lavery'), ('galal', 'galal'), ('asim', 'asim'), ('wuji', 'wuji'), ('asik', 'asik'), ('nek', 'nek'), ('neh', 'neh'), ('neg', 'neg'), ('kuo', 'kuo'), ('new', 'new'), ('net', 'net'), ('nes', 'nes'), ('nep', 'nep'), ('patu', 'patu'), ('jemu', 'jemu'), ('atel', 'atel'), ('men', 'men'), ('suga', 'suga'), ('mej', 'mej'), ('dore', 'dore'), ('china', 'china'), ('mes', 'mes'), ('celebration', 'celebration'), ('mima', 'mima'), ('k', 'k'), ('robin', 'robin'), ('digita', 'digita'), ('julia', 'julia'), ('lynne', 'lynne'), ('brought', 'brought'), ('koju', 'koju'), ('cocaine', 'cocaine'), ('sarah', 'sarah'), ('spoke', 'spoke'), ('army', 'army'), ('calu', 'calu'), ('tela', 'tela'), ('telegraph', 'telegraph'), ('teli', 'teli'), ('tell', 'tell'), ('telo', 'telo'), ('kgs', 'kgs'), ('nki', 'nki'), ('me', 'me'), ('flora', 'flora'), ('ma', 'ma'), ('mc', 'mc'), ('ml', 'ml'), ('mo', 'mo'), ('mn', 'mn'), ('mi', 'mi'), ('mk', 'mk'), ('mu', 'mu'), ('groves', 'groves'), ('ms', 'ms'), ('henry', 'henry'), ('my', 'my'), ('cited', 'cited'), ('repor', 'repor'), ('indies', 'indies'), ('british', 'british'), ('times', 'times'), ('joann', 'joann'), ('hoo', 'hoo'), ('enk', 'enk'), ('enn', 'enn'), ('beach', 'beach'), ('nuta', 'nuta'), ('elizabeth', 'elizabeth'), ('flossie', 'flossie'), ('after', 'after'), ('mesi', 'mesi'), ('summink', 'summink'), ('scare', 'scare'), ('keptin', 'keptin'), ('green', 'green'), ('order', 'order'), ('wind', 'wind'), ('lindsay', 'lindsay'), ('inverness', 'inverness'), ('cornwallis', 'cornwallis'), ('orang', 'orang'), ('dreamer', 'dreamer'), ('personal', 'personal'), ('cla', 'cla'), ('offic', 'offic'), ('wales', 'wales'), ('cree', 'cree'), ('plaster', 'plaster'), ('corporatio', 'corporatio'), ('dickson', 'dickson'), ('bank', 'bank'), ('wenn', 'wenn'), ('wenl', 'wenl'), ('alex', 'alex'), ('meat', 'meat'), ('weni', 'weni'), ('lillian', 'lillian'), ('l', 'l'), ('luce', 'luce'), ('each', 'each'), ('went', 'went'), ('alec', 'alec'), ('allan', 'allan'), ('douc', 'douc'), ('whit', 'whit'), ('fellows', 'fellows'), ('aji', 'aji'), ('tinkler', 'tinkler'), ('fred', 'fred'), ('aboriginal', 'aboriginal'), ('tiam', 'tiam'), ('macneil', 'macneil'), ('nta', 'nta'), ('kik', 'kik'), ('anga', 'anga'), ('atl', 'atl'), ('days', 'days'), ('ath', 'ath'), ('angu', 'angu'), ('isi', 'isi'), ('atu', 'atu'), ('already', 'already'), ('nigel', 'nigel'), ('awrence', 'awrence'), ('lebrun', 'lebrun'), ('hood', 'hood'), ('mercury', 'mercury'), ('\xc3\xa0', '\xc3\xa0'), ('mcgee', 'mcgee'), ('heights', 'heights'), ('garry', 'garry'), ('tom', 'tom'), ('john', 'john'), ('tasi', 'tasi'), ('took', 'took'), ('western', 'western'), ('totten', 'totten'), ('ktu', 'ktu'), ('project', 'project'), ('poirier', 'poirier'), ('historical', 'historical'), ('ran', 'ran'), ('churc', 'churc'), ('seen', 'seen'), ('nuel', 'nuel'), ('kaye', 'kaye'), ('susie', 'susie'), ('doin', 'doin'), ('glod', 'glod'), ('etang', 'etang'), ('marie', 'marie'), ('the', 'the'), ('don', 'don'), ('flor', 'flor'), ('professor', 'professor'), ('metal', 'metal'), ('jerse', 'jerse'), ('seki', 'seki'), ('mildred', 'mildred'), ('lpa', 'lpa'), ('reserve', 'reserve'), ('pku', 'pku'), ('lewis', 'lewis'), ('pka', 'pka'), ('claude', 'claude'), ('siew', 'siew'), ('sugar', 'sugar'), ('lodge', 'lodge'), ('mena', 'mena'), ('do', 'do'), ('nasta', 'nasta'), ('de', 'de'), ('kaki', 'kaki'), ('coast', 'coast'), ('ds', 'ds'), ('bay', 'bay'), ('ban', 'ban'), ('tkey', 'tkey'), ('secretary', 'secretary'), ('tasik', 'tasik'), ('nut', 'nut'), ('nuj', 'nuj'), ('nuk', 'nuk'), ('nui', 'nui'), ('hagar', 'hagar'), ('nue', ' ...

# %%
import codecs
bilingual_dictionary=[]
with codecs.open('/home/apatra/fastText/fastText_multilingual-master/eng-mic','r','utf-8') as f:
    for line in f:
        eng, mic=line.split(', ')
        #print eng
        eng=eng.strip('\"')
        #print eng
        mic=mic.strip('\"')
        mic=mic.replace('\n','')
        mic=mic.replace('"','')
        #print eng, mic
        bilingual_dictionary.append((eng,mic))
print bilingual_dictionary
# Out:
# [(u'txt', u'txt'), (u'all', u'ms\u02bct'), (u'choose', u'megnatl'), (u'choose', u'megng'), (u'German', u'alman'), (u'good', u'amiglu\u02bcsit'), (u'good', u'amiglu\u02bclg'), (u'good', u'gelu\u02bclg'), (u'good', u'gelu\u02bcsit'), (u'goodbye', u'atiu'), (u'I', u'nin'), (u'May', u'Sqoljuigu\u2019s'), (u'May', u'Sqoljuigu\u02bcs'), (u'Micmac', u'Mi\u2019gmaq'), (u'Micmac', u'Mi\u2019gmawi\u2019simg'), (u'Micmac', u'Mi\u02bcgmaq'), (u'Micmac', u'Mi\u02bcgmaw'), (u'Micmac', u'm\xedkmaq'), (u'Micmac', u'Mi\u02bckmaq'), (u'Micmac', u'm\xedgmaq'), (u'Mi\u2019kmaq', u'M\xedkmaw\xedsimk'), (u'Mi\u2019kmaq', u'Mi\u02bcgmaq'), (u'Mi\u2019kmaq', u'm\xedkmaq'), (u'Mi\u2019kmaq', u'Mi\u02bckmaq'), (u'Mi\u2019kmaq', u'm\xedgmaq'), (u'Mohawk', u'gwatej'), (u'Newfoundland', u'Taqamkuk'), (u'search', u'gwilg'), (u'search', u'gwiluasit'), (u'stop', u'enqa\u02bclatl'), (u'stop', u'enqa\u02bcs\u02bcg'), (u'translation', u'nesutmalsewu\u02bcti'), (u'elderly woman', u'gisigui\u02bcsgw'), (u'is that so', u'toqo na'), (u'what is this', u'goqwei net'), (u'abandon', u'naqt\u02bcg'), (u'a bit', u'gimu\u02bctug'), (u'a bit', u'musse\u02bcj'), (u'able', u'gisgajiet'), (u'aboard', u'tepteg'), (u'aboard', u'teppit'), (u'aboriginal', u'Lnu'), (u'above', u'g\u02bcp\u02bcta\u02bcq'), (u'absolutely', u'talma\u02bc'), (u'abstruse', u'temig'), (u'accompany', u'aluggwalatl'), (u'accompany', u'aluggwatg'), (u'accumulate', u'masqo\u02bctasit'), (u'ache', u'gesnuguig'), (u'ache', u'gesnuguit'), (u'ache', u'gesnugwaj'), (u'across', u'a\u02bcsispit'), (u'across', u'a\u02bcsisteg'), (u'active', u'sesgwe\u02bcg'), (u'add', u'mawgiljet'), (u'add', u'mawgitg'), (u'add salt', u'salawa\u02bctat'), (u'adequate', u'tepiet'), (u'adequate', u'tepiaq'), (u'adjust', u'ila\u02bctoq'), (u'adjust', u'ila\u02bclatl'), (u'adopt', u'gisigwenatl'), (u'adopted child', u'gisigwenign'), (u'advise', u'gegnuimatl'), (u'affect', u'mesiatl'), (u'afraid', u'jipasit'), (u'after a while', u'apugjig'), (u'again', u'app'), (u'aggravate', u'gi\u02bcgajo\u02bctg'), (u'aggravate', u'gi\u02bcgajeiwatl'), (u'aggravate', u'asgaiwatl'), (u'a little more', u'me\u02bc ijga'), (u'alive', u'mimajit'), (u'alive', u'mimajig'), (u'allow', u'ignmuatl'), (u'all right', u'na to\u02bcq'), (u'all-time', u'ne\u02bcgaw'), (u'almost', u'suel'), (u'almost', u'geget'), (u'alphabetize', u'gegnugwatg'), (u'alphabetize', u'gegnugwalatl'), (u'also', u'ngutei'), (u'also', u'elg'), (u'also', u'jel'), (u'always', u'ne\u02bcgaw'), (u'always', u'apjiw'), (u'amateur', u'sqapantiej'), (u'amateur', u'sgu\u02bctaqa\u02bcm'), (u'ambitious', u'sesgwe\u02bcg'), (u'ambush', u'gimteluatl'), (u'American eagle', u'niskamakwe\u02bcsu'), (u'American eagle', u'nisgamagwe\u02bcsu'), (u'amuse', u'maligeiwatl'), (u'amuse', u'maligo\u02bctg'), (u'anchor', u'eguma\u02bctoq'), (u'anchor', u'glpisun'), (u'anchor', u'klpisun'), (u'anchored', u'egumit'), (u'anchored', u'egumig'), (u'and', u'jel'), (u'and', u'aq'), (u'angel', u'ansale\u02bcwit'), (u'anger', u'tagala\u02bclatl'), (u'animal', u'oisis'), (u'animal', u'iku'), (u'animal', u'igu'), (u'animal', u'wi\u02bcwis'), (u'annoy', u'asgo\u02bctg'), (u'annoy', u'tagala\u02bclatl'), (u'anoint', u'mima\u02bclatl'), (u'anoint', u'mima\u02bctoq'), (u'another', u'igtig'), (u'another', u'app igtig'), (u'answer', u'asitematl'), (u'answer back', u'gi\u02bcgajimatl'), (u'answer back', u'asiteglulatl'), (u'anyhow', u'me\u02bc pa'), (u'any one', u'ta\u02bcn pa tegen'), (u'anyone else', u'me\u02bc wen'), (u'anything else', u'me\u02bc goqwei'), (u'anyway', u'me\u02bc pa'), (u'anyway', u'me\u02bc'), (u'apparel', u'aligew'), (u'apparel', u'alikew'), (u'appear', u'nei\u02bca\u02bcsit'), (u'appear', u'nei\u02bca\u02bcs\u02bcg'), (u'April', u'Penatmuigu\u2019s'), (u'apron', u'laqpisuti'), (u'archangel', u'gjiansale\u02bcwit'), (u'argue', u'gi\u02bcgaja\u02bcsit'), (u'arrive', u'pegising'), (u'arrive', u'oqwa\u02bcq'), (u'arrive', u'iga\u02bcq'), (u'arrive', u'iga\u02bct'), (u'arrogant', u'emtesgit'), (u'ashamed', u'netaga\ ...

# %% [markdown]
# Let's align the French vectors to the Russian vectors, using only this "free" dictionary that we acquired without any bilingual expert knowledge.

# %%
# form the training matrices
from copy import deepcopy
source_matrix, target_matrix = make_training_matrices(
    en_dictionary, mi_dictionary, bilingual_dictionary)
print len(source_matrix), len(target_matrix)
# learn and apply the transformation

#target_matrix=deepcopy(source_matrix)
print source_matrix[60][9], target_matrix[60][9]
transform = learn_transformation(source_matrix, target_matrix)
#print type(transform)
#print transform[299]
en_dictionary.apply_transform(transform)
# Out:
# 289 289
# -0.1425611234868448 -0.35762
# 300

# %% [markdown]
# Finally, we re-evaluate the similarity of "chat" and "кот":

# %%
en_vector = en_dictionary["one"]
mi_vector = mi_dictionary["newt"]
print(FastVector.cosine_similarity(en_vector, mi_vector))
# Out:
# 0.5346879727300464

# %% [markdown]
# "chat" and "кот" are pretty similar after all :)
#
# Use this simple "identical strings" trick to align other language pairs for yourself, or prepare your own expert bilingual dictionaries for optimal performance.
