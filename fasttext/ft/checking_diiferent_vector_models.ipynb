# %%
import codecs

# %%
f1=codecs.open('/home/apatra/fastText/fastText_multilingual-master/micmaq1.vec','r','utf-8')
f2=codecs.open('/home/apatra/fastText/fastText_multilingual-master/micmaq12.vec','r','utf-8')
f3=codecs.open('/home/apatra/fastText/fastText_multilingual-master/micmaq3.vec','r','utf-8')
f4=codecs.open('/home/apatra/fastText/fastText_multilingual-master/micmaq4.vec','r','utf-8')
f5=codecs.open('/home/apatra/fastText/fastText_multilingual-master/micmaq5.vec','r','utf-8')
f6=codecs.open('/home/apatra/fastText/fastText_multilingual-master/micmaq6.vec','r','utf-8')
f7=codecs.open('/home/apatra/fastText/fastText_multilingual-master/micmaq7.vec','r','utf-8')
f9=codecs.open('/home/apatra/fastText/fastText_multilingual-master/micmaq9.vec','r','utf-8')

# %%
embed=[]

word2id={}
idtoword=[]
(n_words, n_dim) = (int(x) for x in f1.readline().rstrip('\n').split(' '))
print (n_words, n_dim)

for i, line in enumerate(f1):

    elems = line.rstrip('\n').split(' ')
    #print (elems)
    word2id[elems[0]] = i
    embed.append(elems[1:])
    idtoword.append(elems[0])
# Out:
# (21906, 300)

# %%
embed2=[]

word2id2={}
idtoword2=[]
(n_words2, n_dim2) = (int(x) for x in f2.readline().rstrip('\n').split(' '))
print (n_words2, n_dim2)

for i, line in enumerate(f2):

    elems = line.rstrip('\n').split(' ')
    #print (elems)
    word2id2[elems[0]] = i
    embed2.append(elems[1:])
    idtoword2.append(elems[0])
# Out:
# (21906, 300)

# %%
embed3=[]

word2id3={}
idtoword3=[]
(n_words3, n_dim3) = (int(x) for x in f3.readline().rstrip('\n').split(' '))
print (n_words3, n_dim3)

for i, line in enumerate(f3):

    elems = line.rstrip('\n').split(' ')
    #print (elems)
    word2id3[elems[0]] = i
    embed3.append(elems[1:])
    idtoword3.append(elems[0])
# Out:
# (21906, 300)

# %%
embed5=[]

word2id5={}
idtoword5=[]
(n_words5, n_dim5) = (int(x) for x in f5.readline().rstrip('\n').split(' '))
print (n_words5, n_dim5)

for i, line in enumerate(f5):

    elems = line.rstrip('\n').split(' ')
    #print (elems)
    word2id5[elems[0]] = i
    embed5.append(elems[1:])
    idtoword5.append(elems[0])

# %%
embed7=[]

word2id7={}
idtoword7=[]
(n_words, n_dim) = (int(x) for x in f7.readline().rstrip('\n').split(' '))
print (n_words, n_dim)

for i, line in enumerate(f7):

    elems = line.rstrip('\n').split(' ')
    #print (elems)
    word2id7[elems[0]] = i
    embed7.append(elems[1:])
    idtoword7.append(elems[0])

# %%
embed4=[]

word2id4={}
idtoword4=[]
(n_words, n_dim) = (int(x) for x in f4.readline().rstrip('\n').split(' '))
print (n_words, n_dim)

for i, line in enumerate(f4):

    elems = line.rstrip('\n').split(' ')
    #print (elems)
    word2id4[elems[0]] = i
    embed4.append(elems[1:])
    idtoword4.append(elems[0])
# Out:
# (21906, 300)

# %%
cn1=0
cn2=0
print len(embed4)
#print embed[56]
for p in range(0, len(embed4)):
    if embed4[p]==embed2[p]:
        print idtoword4[p],idtoword2[p]
        cn1=cn1+1
    #if embed[p]!=embed3[p]:
        #print idtoword[p],idtoword3[p],'without rules'
       # cn2=cn2+1
print cn1,cn2
# Out:
# 21906
# aq aq
# ta'n ta'n
# mu mu
# Se'sus Se'sus
# jel jel
# gis gis
# mita mita
# tan tan
# goqwei goqwei
# msit msit
# muta muta
# gatu gatu
# negm negm
# app app
# ji'nm ji'nm
# amujpa amujpa
# glaman glaman
# me' me'
# gilew gilew
# gi'l gi'l
# toqo toqo
# tami tami
# Mikmaq Mikmaq
# nuji nuji
# samqwan samqwan
# teluet teluet
# asitemat asitemat
# getu getu
# newtiskaq newtiskaq
# me me
# teliaq teliaq
# tet tet
# eliet eliet
# na'gweg na'gweg
# mimajuaqan mimajuaqan
# negmow negmow
# glapis glapis
# iapjiw iapjiw
# asukom asukom
# teluisit teluisit
# ajiet ajiet
# espe'g espe'g
# awna awna
# ne'wt ne'wt
# gesgmnaq gesgmnaq
# mimajuinu mimajuinu
# naqsun naqsun
# iga'q iga'q
# e'pit e'pit
# ete ete
# eig eig
# 'lgowaqan 'lgowaqan
# mtln mtln
# telimatl telimatl
# teluisig teluisig
# neg neg
# kmu'ji'j kmu'ji'j
# mulin mulin
# Mi'kmaq Mi'kmaq
# eliaq eliaq
# te's te's
# ta'pu ta'pu
# suel suel
# gigjiw gigjiw
# mset mset
# ukmuljin ukmuljin
# ala ala
# ne'patoq ne'patoq
# ...
