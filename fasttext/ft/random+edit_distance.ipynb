# %%
import numpy as np

class FastVector1:
    """
    Minimal wrapper for fastvector embeddings.
    ```
    Usage:
        $ model = FastVector(vector_file='/path/to/wiki.en.vec')
        $ 'apple' in model
        > TRUE
        $ model['apple'].shape
        > (300,)
    ```
    """

    def __init__(self, vector_file='', transform=None):
        """Read in word vectors in fasttext format"""
        self.word2id = {}

        # Captures word order, for export() and translate methods
        self.id2word = []

        print('reading word vectors from %s' % vector_file)
        with open(vector_file, 'r') as f:
	    print ('1') 
            (self.n_words, self.n_dim) = \
            (int(x) for x in f.readline().rstrip('\n').split(' '))
            self.embed = np.zeros((self.n_words, self.n_dim))
            for i, line in enumerate(f):
                elems = line.rstrip('\n').split(' ')
                self.word2id[elems[0]] = i
                #print (elems[0])
                self.embed[i] = elems[1:self.n_dim+1]
                self.id2word.append(elems[0])
        
        # Used in translate_inverted_softmax()
        self.softmax_denominators = None
        
        if transform is not None:
            print('Applying transformation to embedding')
            self.apply_transform(transform)
    
    def apply_cop(self, matrix,i):
        self.embed[i]=matrix[:]
    
    def export(self, outpath):
        """
        Transforming a large matrix of WordVectors is expensive. 
        This method lets you write the transformed matrix back to a file for future use
        :param The path to the output file to be written 
        """
        fout = open(outpath, "w")

        # Header takes the guesswork out of loading by recording how many lines, vector dims
        fout.write(str(self.n_words) + " " + str(self.n_dim) + "\n")
        for token in self.id2word:
            vector_components = ["%.6f" % number for number in self[token]]
            vector_as_string = " ".join(vector_components)

            out_line = token + " " + vector_as_string + "\n"
            fout.write(out_line)

        fout.close()
    
    
    @classmethod
    
    def __contains__(self, key):
        return key in self.word2id

    def __getitem__(self, key):
        return self.embed[self.word2id[key]]

# %%
class FastVector2:
    """
    Minimal wrapper for fastvector embeddings.
    ```
    Usage:
        $ model = FastVector(vector_file='/path/to/wiki.en.vec')
        $ 'apple' in model
        > TRUE
        $ model['apple'].shape
        > (300,)
    ```
    """

    def __init__(self, vector_file='', transform=None):
        """Read in word vectors in fasttext format"""
        self.word2id = {}

        # Captures word order, for export() and translate methods
        self.id2word = []

        print('reading word vectors from %s' % vector_file)
        with open(vector_file, 'r') as f:
	    print ('2') 
            (self.n_words, self.n_dim) = \
            (int(x) for x in f.readline().rstrip('\n').split(' '))
            self.embed = np.zeros((self.n_words, self.n_dim))
            for i, line in enumerate(f):
                elems = line.rstrip('\n').split(' ')
                self.word2id[elems[0]] = i
                #print (elems[0])
                ini=np.random.rand(300)
                self.embed[i] = ini[:] #elems[1:self.n_dim+1]
                self.id2word.append(elems[0])
        
        # Used in translate_inverted_softmax()
        self.softmax_denominators = None
        
        if transform is not None:
            print('Applying transformation to embedding')
            self.apply_transform(transform)
    
    def apply_cop(self, matrix,i):
        self.embed[i]=matrix[:]
    
    def export(self, outpath):
        """
        Transforming a large matrix of WordVectors is expensive. 
        This method lets you write the transformed matrix back to a file for future use
        :param The path to the output file to be written 
        """
        fout = open(outpath, "w")

        # Header takes the guesswork out of loading by recording how many lines, vector dims
        fout.write(str(self.n_words) + " " + str(self.n_dim) + "\n")
        for token in self.id2word:
            vector_components = ["%.6f" % number for number in self[token]]
            vector_as_string = " ".join(vector_components)

            out_line = token + " " + vector_as_string + "\n"
            fout.write(out_line)

        fout.close()
    
    
    @classmethod
   
    def __contains__(self, key):
        return key in self.word2id

    def __getitem__(self, key):
        return self.embed[self.word2id[key]]

# %%
import numpy as np
ct1=0

# %%
def cosine_similarity(vec_a, vec_b):
        """Compute cosine similarity between vec_a and vec_b"""
        return np.dot(vec_a, vec_b) / \
            (np.linalg.norm(vec_a) * np.linalg.norm(vec_b))

# %%
def levenshteinDistance(s1, s2):
    if len(s1) > len(s2):
        s1, s2 = s2, s1
        #print s1,s2
    distances = range(len(s1) + 1)
    #print distances
    #print enumerate(s2)
    for i2, c2 in enumerate(s2):
        #print i2,c2
        distances_ = [i2+1]
        #print distances_
        for i1, c1 in enumerate(s1):
            #print distances_,i1, c1, c2
            if c1 == c2:
                distances_.append(distances[i1])
            else:
                distances_.append(1 + min((distances[i1], distances[i1 + 1], distances_[-1])))
        distances = distances_
        #print distances, char
        #if 0 not in distances and char=='@':
            #char=c2

        #if char in ['\'','k','g','j']:
            #dif=1
        #print 'hi', distances[-1], char
        #print char
    return distances[-1]

# %%
def make_training_matrices(source_dictionary, target_dictionary, bilingual_dictionary):
    """
    Source and target dictionaries are the FastVector objects of
    source/target languages. bilingual_dictionary is a list of 
    translation pair tuples [(source_word, target_word), ...].
    """
    source_matrix = []
    target_matrix = []
    ti=[]
    count=0
    for (source, target) in bilingual_dictionary:
        #print source,target
        if source in source_dictionary.word2id and target in target_dictionary.word2id:
            #print source, target
            count=count+1
            print source, target
            ti.append(target_dictionary.word2id[target])
            source_matrix.append(source_dictionary[source])
            target_matrix.append(target_dictionary[target])
        if source in source_dictionary.word2id and target not in target_dictionary.word2id:
            for q in target_dictionary.word2id:
                dis=levenshteinDistance(target,q)
                if dis==1 :
                    count=count+1
                    print source, target,q
                    ti.append(target_dictionary.word2id[q])
                    source_matrix.append(source_dictionary[source])
                    target_matrix.append(target_dictionary[q])
                    #count+=1
                    #print p, q

    print count
    return np.array(source_matrix), np.array(target_matrix), np.array(ti)

# %%
en_dictionary = FastVector1(vector_file='/home/apatra/fastText/fastText_multilingual-master/eng.vec')
mi_dictionary = FastVector2(vector_file='/home/apatra/fastText/fastText_multilingual-master/model.vec')
# Out:
# reading word vectors from /home/apatra/fastText/fastText_multilingual-master/eng.vec
# 1
# reading word vectors from /home/apatra/fastText/fastText_multilingual-master/model.vec
# 2

# %%
en_vector = en_dictionary["one"]
mi_vector = mi_dictionary["newt"]
print(cosine_similarity(en_vector, mi_vector))
# Out:
# 0.053885064631976426

# %%
mi_words = set(mi_dictionary.word2id.keys())
en_words = set(en_dictionary.word2id.keys())

# %%
import codecs
bilingual_dictionary=[]
with codecs.open('/home/apatra/fastText/fastText_multilingual-master/eng-mic','r','utf-8') as f:
    for line in f:
        eng, mic=line.split(', ')
        #print eng
        eng=eng.strip('\"')
        #print eng
        mic=mic.strip('\"')
        mic=mic.replace('\n','')
        mic=mic.replace('"','')
        #print eng, mic
        bilingual_dictionary.append((eng,mic))
#print bilingual_dictionary

# %%
# form the training matrices
#from copy import deepcopy
ct1=0
source_matrix, target_matrix ,ti= make_training_matrices(
    en_dictionary, mi_dictionary, bilingual_dictionary)
print len(source_matrix), len(target_matrix)
# learn and apply the transformation
print ti
#target_matrix=deepcopy(source_matrix)
print source_matrix[60][9], target_matrix[60][9]
#transform = learn_transformation(source_matrix, target_matrix)
#print type(transform)
#print transform[299]
#en_dictionary.apply_transform(transform)
# Out:
# /home/apatra/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:15: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   from ipykernel import kernelapp as app
# txt txt tet
# all msʼt mset
# all msʼt msit
# all msʼt ms't
# choose megnatl
# German alman klman
# good geluʼlg gelu'lg
# good geluʼsit gelusit
# goodbye atiu atu
# I nin
# Micmac míkmaq mikmaq
# Micmac Miʼkmaq Mi'kmaq
# Micmac Miʼkmaq Mikkmaq
# Micmac Miʼkmaq Mikmaq
# abandon naqtʼg naqt'g
# aboard tepteg telteg
# aboard teppit
# aboriginal Lnu
# abstruse temig
# ache gesnugwaj gesnugwat
# ache gesnugwaj gesnugwa
# ache gesnugwaj gsnugwaj
# add mawgitg mawgi'g
# adequate tepiet
# adequate tepiaq
# affect mesiatl mesimatl
# again app
# alive mimajit
# alive mimajig mimaji
# alive mimajig mimajit
# alive mimajig mimajis
# allow ignmuatl
# almost suel
# also ngutei nguti
# also elg
# also jel
# always apjiw
# and jel
# and aq
# angel ansaleʼwit ansale'wit
# animal iku pku
# animal iku isku
# animal iku ika
# another igtig
# answer asitematl asitemat
# anyway meʼ me'
# anyway meʼ men
# anyway meʼ mej
# anyway meʼ me
# arrive pegising
# arrive igaʼq iga'q
# aside gmetug
# ask etamatl etamat
# asleep nepat
# aspen miti mitji
# aspen miti mita
# assist apoqonmuatl apoqonmuate
# assistance apoqonmati apoqnmati
# assistance apoqonmati apoqonmasi
# at eteg
# attached naspit
# attached nasteg
# authority alsusuti
# aware gejiatl
# ay eʼe eke
# ay eʼe ete
# ay eʼe ewe
# ay amuj
# aye eʼe eke
# aye eʼe ete
# aye eʼe ewe
# aye amuj
# babysit nespit kespit
# babysit nespit naspit
# babysit nespit nespiw
# babysit nespit nespi
# bag munti muni
# bake etoqtet etoqtem
# basket ligpenigen ligpenignn
# battle matntimg
# battle matnaggewaqan
# beach sitm sit
# beach sitm sitmu
# bear muin
# bear muiʼn muin
# beaver gopit opit
# beaver gopit kopit
# beaver kopit
# because muta
# bee amu ami
# bee amu kmu
# bee amu apu
# bee amu au
# bee amu mu
# bee amu (mu
# bee amu atu
# bee amu amuj
# before tmg
# before gesgmnaq
# beg etawaqtmat etawaqtma
# beg etawaqtmat etawaqtmuat
# beg etawaqtmat etawaqtemat
# believe getlamsʼtuatl getlams'tuatl
# believe getlamsʼtg getlams'tg
# beside gmetug
# beside anapiw
# besides lnim ltim
# between miaweʼg miawe'g
# big mesgiʼg mesgi'g
# big mesgilg mesgi'g
# bird sisip lisip
# bird sisip sisipk
# bird sisip sisi
# blabbermouth seitun geitun
# blacksmith glaptan Klaptan
# blacksmith glaptan klaptan
# blacksmith klaptan
# blaze gnugwaqan
# blaze sisuei sisue
# bleed maltewiaq
# bless elapatoq
# blessed sapeʼwit sape'wit
# blessed sapeʼwig sape'wig
# blocked gepjoqteg gep'joqteg
# blood maltew maltewi
# blood maltew maltem
# blood maltew mal'tew
# bloody maltewig maltewi
# bloody maltewit maltewi
# born ugsʼtqamuit ugs'tqamuit
# boss alsusit
# boss assusit
# boss saqamawit saqamawin
# boss saqamawit saqamawik
# both gitg
# bow tapi tami
# bow tapi tapu
# bow tapi napi
# bow tapi tasi
# bow tapi api
# bow tapi tali
# bow tapi papi
# bow tapi tepi
# boy lpaʼtuj lpa'tuj
# bright gesateg gesatg
# brother nidap nitap
# bucket laʼtaqsun lataqsun
# bug jujij juji
# bug jujij ujij
# build eliatl eliaql
# build eliatl ejiatl
# build eliatl elietl
# build eltoq
# but gatu
# butcher neʼpatat ne'patat
# can gisaʼtoq gisa'toq
# Canada Ganata
# canoe gwitn kwitn
# canoe kwitn
# caribou qalipu
# catch mesnʼg mesn'g
# catch mesnatl megnatl
# catch mesnatl mesenatl
# chanticleer napeʼw napew
# chase getanatl
# chief saqamaw saqmaw
# chief saqamaw Saqamaw
# chief saqamaw saqemaw
# chief saqamaw saqama
# chief saqamawit saqamawin
# chief saqamawit saqamawik
# Christ Seʼsus Se'sus
# Christ Seʼsukuli Sesukuli
# Christ Seʼsuguli Se'suguli
# city gjigan
# cliff mtasoq
# closed gepjoqteg gep'joqteg
# cloth atlaʼwegn atla'wegn
# cloud alug
# cloud aluk alug
# cloud aluk alukk
# cock napeʼw napew
# cockerel napeʼw napew
# cod peju
# cold tegit telit
# cold tegig temig
# cold tegig tepgig
# comeuppance apajiaq apajia
# completely lpa
# confess agnutg
# congregate mawiejig mawiejik
# continue siawaʼsit siawa'sit
# continue siawaʼsit siawasit
# cost awtit awtij
# cost awtit awtik
# cost awtit awti'
# cost awtit awtil
# cost awtit awti
# cost telawtit telawtik
# cost telawtig telawtik
# count egimatl elgimatl
# create etlitoq etlintoq
# creates gisiatl kisiatl
# crow getuʼg getu'g
# cry etltemit
# cry atgitemit
# cured gispasasit kispasasit
# dance amalgat amalkat
# day naʼgweg na'gweg
# daylight naʼgweg na'gweg
# dead nepg nepu
# dead nepg nepa
# dead nepg nepk
# dead nepg neg
# dead nepg nep
# dead nepg nepga
# decision-making ilsutaqan ilsutaqa
# decision-making ilsutaqan alsutaqan
# deep temig
# deer lentuk
# deer lentug lentuk
# defend igalatl iga'latl
# detest masgeltʼg masgelt'g
# detest masgelmatl
# direct assusit
# direct alsusit
# disbelieve megtʼg megt'g
# discuss agnutmajig
# discussion agnutmaqan
# dish eptaqan eptaqang
# dish eptaqan eptaqn
# disobey elistuatl
# dog lmuj Amuj
# dog lmuj amuj
# dog nmuj Amuj
# dog nmuj nuj
# dog nmuj nmug
# dog nmuj nmuk
# dog nmuj amuj
# dog lmu'j kmu'j
# dog lmu'ji'j kmu'ji'j
# dog nmu'j kmu'j
# dog nmu'jig nme'jig
# dog nmu'ji'j kmu'ji'j
# dog nmu'ji'j nme'ji'j
# don nasaʼtoq nasa'toq
# don nasaʼlatl nasa'latl
# dormer gloqowej Kloqowej
# doubt megtʼg megt'g
# dress magot maqot
# drink esamqwat
# dry gispateg gispate
# during geʼs ge's
# dye essawiaqan essawiaqnn
# eagle gitpu itpu
# eagle gitpu kitpu
# eagle kitpu
# earn eltoq
# earn neʼpatoq ne'patoq
# eat malqutg malqutk
# eat malqutg malqotg
# eat malqutg malqut
# eel katew
# eel gatew katew
# eel kaʼt kat
# eight ukmuljin
# eight ugmuljin ugumuljin
# eight ugmuljin ukmuljin
# encourage ajipjutoq ajipjutaq
# ended gaqiet kaqiet
# ended gaqiaq
# endure saputaqatg
# Englishman aqalasieʼw aqalasie'w
# enjoys gesatg
# enmeshed nasteg
# enough tepiet
# enough tepiaq
# erase gasaʼlatl gasa'latl
# even lnim ltim
# eventually glapis
# every teʼs tes
# every teʼs te's
# exactly assma
# exhausted gaqiet kaqiet
# exit tewiet
# extinct getmenejig
# fact giʼwajiaq gigwajiaq
# far amaseg amasek
# far gneg
# favor igalatl iga'latl
# feet leppie leppi
# fence llutaqan 'llutaqan
# fifty naniskaʼq naniskaq
# fight matntijig matntiji
# fight matnaggewaqan
# finally glapis
# finished gaqiet kaqiet
# finished gaqiaq
# fire eseg eteg
# first amgwes
# first tmg
# fishnet aʼpi api
# five naʼn na'n
# five naʼn nan
# five nán nin
# five nán nan
# fix gisaʼtoq gisa'toq
# fix elugwatg elugwat
# fix elugwatg lugwatg
# fix elugwatg elugwatm
# fix elugwatg elugwatgl
# flag mtawegn mtawekn
# floor msaqtaqt
# food mijipjewei
# foolish amiet ajiet
# foolish amiet pmiet
# foot leppie leppi
# forever iapjiw
# forty newiskaʼq newiskaq
# four neʼw new
# four neʼw ne'w
# four néw new
# full wajuax wajuaq
# full wajuet waju'et
# full-grown gisigweg
# full-grown gisigweng gisigweg
# full-grown gisigwet
# garden igaʼtaqan iga'taqan
# gather megnatl
# gentleman saqamaw saqmaw
# gentleman saqamaw Saqamaw
# gentleman saqamaw saqemaw
# gentleman saqamaw saqama
# get mesnʼg mesn'g
# giant jenu tenu
# giant jenu jemu
# giant jenu jenua
# go majaʼsit maja'sit
# goes eliaq
# goes eliet
# grass msigu msiku
# grass msigu msigui
# grease mimei mime
# grease mimei mimey
# green esgit wesgit
# ground maqamigew
# hair sapun sapu
# hair sapun usapun
# hair sapun wsapun
# half aʼqataig aqataig
# halibut sanuk snuk
# handbasket ligpenigen ligpenignn
# handy tepaw
# happens teliaq
# have geggung
# have geggunatl
# hay msigu msiku
# hay msigu msigui
# he telimatl
# he negm
# head nunji nunje
# head nunji wunji
# head nunji nuji
# head nunji nunjie
# head kunji wunji
# head unji uji
# head unji wunji
# head unji un'ji
# head unji ugji
# head unji ukji
# hear nutax nuta
# hear nutax nuta'
# hear nutax nutaj
# hear nutax nutal
# hear nutax nutaq
# hear nutm
# help apoqonmuatl apoqonmuate
# help apoqonmati apoqnmati
# help apoqonmati apoqonmasi
# her telimatl
# her etamatl etamat
# her negm
# here tet
# hers negmewei negmeweg
# hide mimugwasit mimgwasit
# him negm
# his negmewei negmeweg
# hit taqamatl
# hits telteʼg telteg
# holler getuʼg getu'g
# holy sapeʼwig sape'wig
# holy sapeʼwit sape'wit
# home giʼg gitg
# honest giʼwajiaq gigwajiaq
# honor gepmiteʼlmatl gepmitelmatl
# hopefully jiptug jiptuk
# hot epteg eteg
# hot epsit epit
# house giʼg gitg
# hundred gasgʼptnnaqan gasgiptnnaqan
# hundred kaskimtlnaqan kaskimtlnaqn
# hundred gasgiptnnaqan
# hundred kaskimtlnaqn
# hundred gasgimtnnaqan gasgiptnnaqan
# hunt getanatl
# hurt gesnugwaj gesnugwat
# hurt gesnugwaj gesnugwa
# hurt gesnugwaj gsnugwaj
# hurt jileʼg jile'g
# hurt gesaʼlatl gesalatl
# ice mgumi mkumi
# immediately smtug
# inch mtijin
# inexpensive anawtig anawgtig
# infect mesiatl mesimatl
# influence mesiatl mesimatl
# inform gegnuaʼteget gegnua'teget
# injured jileʼg jile'g
# insect jujij juji
# insect jujij ujij
# inside lameʼg lame'g
# instead awna
# invent gisiteʼtg gisite'tg
# island menigu meniku
# its negmewei negmeweg
# jab taqamatl
# jail lapulusan laplusan
# Jesus Seʼsus Se'sus
# Jesus Seʼsukuli Sesukuli
# Jesus Seʼsuguli Se'suguli
# job lgowaqan lugowaqan
# job lgowaqan 'lgowaqan
# job lugowaqan
# jobs lugowaqan
# judge ilsutg ilsutm
# kill neʼpatoq ne'patoq
# king elegeʼwit elege'wit
# know geʼitoq geitoq
# know nenuatl nenuat
# laborer lugowinu
# lamb jijgluewjiʼj jijgluewji'j
# land maqamigew
# later gneʼg gneg
# law tplutaqan
# leach squ su
# leaf nipi napi
# leaf nipi nini
# leaf nipi nipk
# leaf nipi nipe
# leaf nipi nip
# leak espeg espe'g
# leak espeg espe'
# leak espet espe'
# lean-to anapig anapiw
# lean-to anapig anapi
# learning ginaʼmasuti gina'masuti
# leave majaʼsit maja'sit
# ledge mtasoq
# leftover esgwiet
# leftover esgwiaq
# lesson ginaʼmasuti gina'masuti
# lie egsuoʼqon egsuo'qon
# lie egsuet egsue
# lie egsuet egsueg
# life mimajuaqan
# like gesalatl
# like gesatg
# lip nsi nsis
# lip nsi lsi
# lip nsi isi
# lip nsi qsi
# lip nsi nui
# lip nsi ni
# lip nsi ns
# lip nsi msi
# lip nsi si
# lip nsi nki
# lip nsi ksi
# liver usgun usgupn
# living mimajuaqan
# loath masgeltʼg masgelt'g
# loath masgelmatl
# located eteg
# located epit
# loon gwimu Kwimu
# lose entoq eltoq
# loud gesigawweg gesigawwe
# machine mulin
# made gisiatl kisiatl
# make eltoq
# make eliatl eliaql
# make eliatl ejiatl
# make eliatl elietl
# make etlitoq etlintoq
# making etliatl etliaql
# man jiʼnm ji'nm
# man jinem
# maple snawei snawey
# marker gnugwaqan
# mass alameʼs alame's
# mature gisigweg
# mature gisigwet
# maybe etugjel etukjel
# maybe jiptug jiptuk
# meal mijjuaqan Mijjuaqan
# member naspit
# message agnutmaqan
# midday mewliaʼgweg mewlia'gweg
# midnight aqtatpaʼq aqtatpa'q
# mill mulin
# misbehave ewnasaʼsit ewnasa'sit
# misconduct ewnasaʼsit ewnasa'sit
# missionary aniapsuinu
# molest sespeiwatl sespeiwat
# money suliewei
# month tepgunset
# Montreal Mulian
# moon tepgunset
# moose tiaʼm tiam
# more meʼ me'
# more meʼ men
# more meʼ mej
# more meʼ me
# morning egsitpuʼg egsitpu'g
# mountain gmtn gm'tn
# mountain gmtn kmtn
# mountain mntn mntu
# mountain mentn mentu
# move majaʼsit maja'sit
# mud sisgu
# mushroom lgetu getu
# must amujpa
# name-calling miluiʼtatl milui'tatl
# named teluisig
# named teluisit
# native Lnu
# nay moqwaʼ moqwa
# nay moqwaʼ moqwa'
# near gigjiw
# near tepaw
# necessary amujpa
# need ewegetoq eweketoq
# need menuegetoq
# negotiate agnutmajig
# net aʼpi api
# new pilei
# news agnutmaqan
# news glusuaqan
# nice geluʼlg gelu'lg
# nice geluʼsit gelusit
# night tekik
# night tegig temig
# night tegig tepgig
# night tepgig
# nighttime tekik
# nighttime tegig temig
# nighttime tegig tepgig
# night-time tekik
# night-time tegig temig
# night-time tegig tepgig
# nine pesqunatek
# nine pesqunateg pesqunatek
# no moqwaʼ moqwa
# no moqwaʼ moqwa'
# noon mewliaʼgweg mewlia'gweg
# nope moqwaʼ moqwa
# nope moqwaʼ moqwa'
# obey getlamsʼtg getlams'tg
# occasionally egel etel
# occasionally egel ekel
# offshore apaqt
# oil mimei mime
# oil mimei mimey
# on tepteg telteg
# one newt
# one neʼwt newt
# one neʼwt ne'wt
# one néwt newt
# operates elugwet
# operating elugweg elugwe
# operating elugweg elugwet
# other igtig
# outcome apajiaq apajia
# outdoors gujm guj
# outside gujm guj
# oversee alsusit
# oversee assusit
# owe tettuet tettue
# own alsutg alsut
# own alsutg alsutk
# own alsumatl alsumat
# oyster mntmu mntu
# pack ilajit
# pail laʼtaqsun lataqsun
# path awtij
# path awtiʼj awtij
# penalty apajiaq apajia
# penitent aniapsuinu
# perhaps jiptug jiptuk
# perhaps etug
# perhaps etugjel etukjel
# permanently aptaqatg aptaqat
# permit ignmuatl
# person mimajuinu
# pipe tmaqan
# place igaʼlatl iga'latl
# placed eteg
# placed epit
# plan ilsuteget
# plant igaʼtaqug iga'taqug
# plate eptaqan eptaqang
# plate eptaqan eptaqn
# play eleget elegat
# pluck menaʼtoq mena'toq
# plugged gepjoqteg gep'joqteg
# poplar miti mitji
# poplar miti mita
# possess geggunatl
# possess geggung
# pour gutaʼtoq guta'toq
# prepare ilajit
# present eig
# prison lapulusan laplusan
# profound temig
# promise teplumatl
# protect igalatl iga'latl
# punch taqamatl
# put igaʼlatl iga'latl
# pyrexia epsimgewei
# pyrexia epsimkewei epsimgewei
# raise angoʼtg ango'tg
# raise gisigweng gisigweg
# reach tepnatl
# read egitg gitg
# read egitg egitgl
# read egimatl elgimatl
# rear gisigweng gisigweg
# receive mesnatl megnatl
# receive mesnatl mesenatl
# receive mesnʼg mesn'g
# recently gejigow gejigew
# recite egimatl elgimatl
# recite egitg gitg
# recite egitg egitgl
# recognize neng neg
# recognize neng nenk
# recognize neng nena
# recognize nenuatl nenuat
# recover saputawsit saputa'sit
# reindeer qalipu
# relax atlasmit atlasmi
# release igaʼlatl iga'latl
# release eleget elegat
# remainder esgwiet
# remainder esgwiaq
# remove menaʼtoq mena'toq
# repair elugwatg elugwat
# repair elugwatg lugwatg
# repair elugwatg elugwatm
# repair elugwatg elugwatgl
# repair gisaʼtoq gisa'toq
# repeat app
# reply asitematl asitemat
# report agnutmaqan
# report agnutmuatl agnutmuate
# report agnutmuatl aknutmuatl
# request etamatl etamat
# request etawet
# require menuegetoq
# resemble eluatl elulatl
# respect gepmiteʼlmatl gepmitelmatl
# rest atlasmit atlasmi
# return apajaʼsit apajasit
# return apajaʼsit apaja'sit
# return apajiaq apajia
# reward apajiaq apajia
# rich milesit
# ripe etteg eteg
# river sipu
# road awti
# roast etoqtet etoqtem
# roast etoqtasit
# rock guntew kuntew
# rock guntew gun'tew
# roe nijinj nijink
# rooster napeʼw napew
# rotten sugulegat sugul'gat
# run eleget elegat
# sack munti muni
# sailor matlot matlotk
# saintly sapeʼwit sape'wit
# salmon plamu
# sand atuomg atuomk
# sand atuomg atuom
# says teluet
# sea apaqt
# seated epit
# see nemiteget nemitege
# see nemiteget nemitegeg
# see nemiteget nemitegej
# see nemiteget nemitegen
# see nemitoq
# see nemiatl
# see nemitu
# seed nijinj nijink
# seek getanatl
# seldom awisiw
# select megnatl
# self-determination alsusuti
# send elgimatl
# sentence ilsumatl ilsumate
# sentence ilsumatl ilsumata
# sentence ilsumatl ilsumatal
# seven lʼuiknek l'uiknek
# seven lluiknek l'uiknek
# sharp giʼg gitg
# she negm
# sheep jijgluewj jijgluewji
# sheet laqsun naqsun
# shore sitm sit
# shore sitm sitmu
# should etug
# shouts gesigawwet gesigawwe
# shovel qalipit qaliput
# sick gesnugwat
# side anapo anapi
# silly amiet ajiet
# silly amiet pmiet
# silver suliewei
# sing getuʼg getu'g
# sing etlintoq
# sitting epit
# situated eteg
# six asʼgom asugom
# six asukom
# six asugom
# skunk apikjilu
# skunk apigjilu apikjilu
# slate mtasoq
# slaughterer neʼpatat ne'patat
# slave gisteju
# slave kisteju Gisteju
# slave kisteju gisteju
# snake mtesgm mteskm
# snake mteskm
# snake mteʼskm mteskm
# so toqo
# so giʼwajiaq gigwajiaq
# so glamen glaman
# sock sign sin
# soldier smaʼgnis sma'gnis
# some alt
# someone naʼtuen na'tuen
# someplace naʼtami na'tami
# someplace naʼtami natami
# sometimes jijuaqa
# somewhere naʼtami na'tami
# somewhere naʼtami natami
# soon gneʼg gneg
# soon apugjig
# sore gesnugwaj gesnugwat
# sore gesnugwaj gesnugwa
# sore gesnugwaj gsnugwaj
# soup lasup lassup
# sow igaʼtaqug iga'taqug
# speak gelusit
# spit elusgwatamit elusgatamit
# spiteful getanatl
# sprout saqaliaq
# stab sapaqqataʼtl sapaqqata'tl
# stand gaqamit
# stand gaqamig gaqami
# stand gaqamig gaqamis
# stand gaqamig gaqamit
# star gloqowej Kloqowej
# still meʼ me'
# still meʼ men
# still meʼ mej
# still meʼ me
# stocking sign sin
# stone guntew kuntew
# stone guntew gun'tew
# story aʼtugwaqan a'tugwaqan
# story agnutmaqan
# straight tetpaqig tetpaqi-
# straight tetpaqig tetpaqi
# stretch sipit mipit
# struggle matnaggewaqan
# suddenly jiniw
# sufficient tepiaq
# sufficient tepiet
# Sunday aqantieʼumg aqantie'umg
# Sunday Aqantie’umg Aqantie'umg
# supervise alsusit
# supervise assusit
# supervisor saqamawit saqamawin
# supervisor saqamawit saqamawik
# survive sapawsit sapawsita
# sweat tgnu tenu
# sweat tgniewuti tkniewuti
# tale aʼtugwaqan a'tugwaqan
# talk etlewistoq
# talk gelusit
# task lgowaqan lugowaqan
# task lgowaqan 'lgowaqan
# task lugowaqan
# teach geginaʼmuet gegina'muet
# tell telimatl
# ten mtln
# ten newtiskaʼq newtiskaq
# ten newtiskaʼq newtiska'q
# ten newtiskáq newtiskaq
# that ala
# that aʼt at
# that aʼt alt
# that aʼt awt
# that negla
# thaw saqaniaq saqaliaq
# theirs negmowowei
# them negmow
# there ala
# there eig
# therefore glamen glaman
# they negmow
# thief gmutnes gmutne
# thief gmutnes gmutnesg
# thief gmutnes Gmutnes
# thirty nesiskaʼq nesiska'q
# those negla
# thousand pituimtlnaqn
# three siʼst si'st
# three siʼst sist
# three síst sist
# throw eleget elegat
# thumb mtijin
# thus glamen glaman
# tired gispnet
# tired gispneg gispnet
# today gisgug
# tongue ninnu nilnu
# too elg
# too lnim ltim
# too ngutei nguti
# tooth nipit mipit
# totally lpa
# town gjiganjiʼj gjiganji'j
# town gutang
# track getanatl
# trail awti
# trail awtiʼj awtij
# tree mitis miti's
# tree mitiʼs miti's
# trial ilsutaqan ilsutaqa
# trial ilsutaqan alsutaqan
# true giʼwajiaq gigwajiaq
# true teliaq
# twenty tapuiskaʼq tapuiskaq
# twenty tapuiskaʼq tapuiska'q
# two tapu
# two taʼpu tapu
# two taʼpu ta'pu
# two tápu tapu
# uncured esgit wesgit
# under lameʼg lame'g
# underneath lameʼg lame'g
# undershirt lamqwan Samqwan
# undershirt lamqwan samqwan
# unless jiptug jiptuk
# urine sguti nguti
# us ginu
# very lnim ltim
# view angamatl
# village gjiganjiʼj gjiganji'j
# visit emittugwet mittugwet
# war matntimg
# waterfowl sisip lisip
# waterfowl sisip sisipk
# waterfowl sisip sisi
# wave tgu tu
# we ginu
# weak menaqanaq menaqana
# weak menaqanat menaqana
# wear nasgʼg nasg'g
# week aqantieʼuti aqantie'uti
# weep atgitemit
# weigh tetpaqq tetpaqi
# what goqwei
# when taʼn ta'n
# when taʼn taqn
# when taʼn tan
# where taʼn ta'n
# where taʼn taqn
# where taʼn tan
# where tami
# while geʼs ge's
# whisper gimewistoq Gimewistoq
# window tuopʼti tuopiti
# wine moqopaʼq moqopa'q
# winter gesig gesg
# wolf paqtesm
# wolf paqtɨsm paqtesm
# wolf paqtɨsm paqtism
# woman ebit epit
# woman e'pit
# woman eʼpit e'pit
# woman eʼpit epit
# word glusuaqan
# work elugwet
# work lugowaqan
# work elugweg elugwe
# work elugweg elugwet
# work lgowaqan lugowaqan
# work lgowaqan 'lgowaqan
# worker lugowinu
# write ewiʼgiget ewi'giget
# yard igaʼtaqan iga'taqan
# yard lapeʼlis lapelis
# yeah eʼe eke
# yeah eʼe ete
# yeah eʼe ewe
# yeah amuj
# yep eʼe eke
# yep eʼe ete
# yep eʼe ewe
# yep amuj
# yes eʼe eke
# yes eʼe ete
# yes eʼe ewe
# yes amuj
# yet meʼ me'
# yet meʼ men
# yet meʼ mej
# yet meʼ me
# you giʼl gi'l
# you gilew
# you gil Hil
# you gil gi'
# you gil gile
# you gil gi'l
# you gil Kil
# you gil mil
# you gil gis
# you gil gim
# you gil Mil
# you gil kil
# youngster maljeweʼj maljewej
# your giʼlewei gi'lewei
# yours giʼlewei gi'lewei
# dried-out gispasasit kispasasit
# education ginaʼmasuti gina'masuti
# fear jipatg jipatk
# fever epsimgewei
# fever epsimkewei epsimgewei
# hate masgelmatl
# hate masgeltʼg masgelt'g
# knowledge ginaʼmasuti gina'masuti
# love gesatg
# love gesalatl
# love kesaltimkewei kesaltimkewe
# poverty ewleʼjuaqan ewle'juaqan
# sleep nepat
# water samqwan
# 962
# 962 962
# [  175   515    33   966 17377  4297  5192 15063 13544  1474  4529   438
#   7043    89  1627  1360 16835  7099 16371  5110 13190 13133 16534  9254
#    578  4208    52 13258  1363 13258  7586 17285   483  2129   648    19
#    759    19     1 19431  1700 16307   967   629   131    71 18865  7653
#    164  1137   330  3340 16511  3858 10085    26 19013  2030 13079   683
#   1350  5357  2411  5113  8144   349  2582   945  8144   349  2582   945
#   9182  1350  1479  1272 16998  3339 16869 17133 16938  1570  3854  2232
#   2232  6323  1291  1291    38  1499  3420 21226 16231     9 14816 13544
#    945  1185   316 17252 16555  5543  1604 13488  3340 12258 21221 13779
#    752   752  6093  6354  6843 17186 19918 11959 11959 14274 17407 18793
#   3964 19445 17991 13039 18683 18671 14149 18683 18683 17227  2260  3637
#   6097  2721  2036    85  2609 20739 21079  4977   764  1364  1714  2688
#  15027  6824  4965  7835  3391 12040 21410 17238  1365    43 16932 16472
#  16956 20368 20368  6636 17158 17377  9836  3033 14312  1319  1619  6740
#   3490  6097  2721    14 18858  1833 17140  7862 13039 13010 20729 20729
#  21502  3033  3033 20551  3140 16371 13158 17160  1198 17138  1381 17073
#   8261  7147  5442 16960  7704   810   574   574 14965 15270 10510 13397
#  14220 13218 21496   849   185   185 16578  7533  4010   392  3407 13252
#  13606 16218 16371  5137  5137  3139 17192 14680  3637  2260 17026 16504
#    889 17270 21624 17280  1061   945  1061  1261 16498 21346   945  1811
#    394  1811  1891   394  2939  4774  3203  4687 17026 14358  1776 14892
#    632 10478  5876  7793  7793  1365   538  4158  1394 21335  1124  1124
#   2832   525 16763   525 14451  4301 13743 17109  2184 15027  5357  9254
#    578 17169 21221   190   659   445 13784  4301  1095 16939  3543  1015
#  14987  3139 14546 13838  4722 14506 16938   190  4301 13743   683 17148
#   1185  4977   693  1181  1474  1181 16472 14856  4979  2785 14565   729
#   2805   949   264 17316 14546   220  3852  5074   846  5074  4511 14550
#  16584 16584 16588  2553 17377  1319  1619  6740  3490 17158  4569  6908
#   7337  3148   442   177  9472 16777  4524 20150 16851  4258  5345  3821
#  20270  5010 21334 16869  4308   173  1774 14980  9472 16777   364    48
#  12318  4777    94 12319  4777  7412  4777  2585  2539 17859  3438 15248
#   7781 14489  7902  9247 19013  2030 13079   364 16511    48   175 13937
#  13985    48 13937 15013  1360 13397 17991 19445  2036  3543 13731  1204
#    683  1202  2036  2303  1148  2303  1148  2303 14312  5110 13190 13133
#  17113 13297   687   661  4502 17440  4208  4208 13110 17113  7835  3391
#  13040   309 14802  4248 13937 15013  5070    14 18858  1833  1926   362
#   1926  1926 16462   538 14259   748  3317 14797 17397  4258 14987 13793
#  21307 20739  9383   689  7695  1307   279 13801 13801 12258 12244 16732
#   3148  7862 13589  5383 16732 13643  2739 13727   186 13297 15027  3185
#  15268  3549  4489  1325  2465 21219 17454  3163 20088  2342 17229   186
#  17192 14680   683  1202  9894  1365 13723   406 10510  1365 12040 21410
#  17238 15270  8759    58   981 20895 14274 17048 16584 16588  1528  1204
#  13106  1350   889 16568 15286   406 16930 16930  6878 17114  1661 16315
#  11355 16315  6618    71 18865  7653   164 15062 13763 19747  7390  6927
#   3148  1498   135    62 17111   370   251  7099  3473 17132   497  4308
#     62  1087 17165 16504  4977  3059   889   798  5192 15063  9933 16371
#  13158 13158  9933 16371 13158  9933 16371 13158   700   700  3473 17132
#  16568  3473 17132 13488 11720  1683  4509  4524 20150  1360  1268  1268
#    310  1268  5090 16358  5090   629 17160  5309  5309  2260  3637  4159
#   3230  1908 10431  7390 21490  4965  7147  7147 17160  6878  1204  1576
#   1528 17163 17285   328 12301  3139   683  1202  2694   952 17270 21624
#   9841 15454 13039 10085    26 14980  1774 13314 21490   355  5070 16371
#  17157  3139 15013  3139 16567 16567  3106 16584 17161  2036 17128 14965
#  16584 17377  9836 17158 13165 14965  2036 17128   392 15346 14037  3317
#  17301  6636 15792  3139  9841 13589  5383 15454 14856  4979  2785 14565
#  16472    52   131   889 16936 20465 16511 21046 17165 21443 13731 15792
#  10092   881 17160 17160  1111   683  1578   810  3339 11172  1043  1930
#  10181  3033 13033  9841 16998  5047 19445  5201  5040  3654   109  4509
#   1202  1311 13156 14053 14096  1040   745   603 10181 14312  1602 17377
#   2411 14965  2193 13491 17278   591   591  2036    48   790   329  1570
#   3854  1576 13723  1960  5110 12244   264 17316  1661 13397 15270  1202
#    683  5009   250  5009  7139  7139  7862 16932  2287 13684  2287  3839
#   3839  3839    83  3543    69 21137  2574   596  2231   623   830   739
#    623   830 14987 16928  5110 13190 13133 20066   952 15063 14002 14312
#  13473 14143   973 13588 14992   973  4687    71 18865  7653   164 21137
#   1043  1930  3291   889  9109   769 12614 16938  1851   578  9254 14141
#  14186  2260  3637  6097  2721 21764  4569 20221  3291 13551 15063  1926
#    362  1926 13724   364   363   139 16123   139   527  1750   596  3457
#  17421 13473 17166   188   527   355    69   188  2044 13855 13949  9628
#  17421   978   597  1341  1341  9841  4502    69 17259 17259  3421  8309
#    648 21221  2129 12614  1198 16946 17246 14312   810  7147 14352 14352
#  13606 16218  3543   173  1722  5366  2609  2609   461  2609 16851 13040
#  13040 12512   107  1204  2129   997 21221  2459 16946 16712 17133  6093
#   6354  6843   873   997 19648 19648 15037 13746 13218   769    32     3
#   1738    29     3  1738    29    85   632 13217  2650  1584 14302 13968
#  13968  1585  1202   334   334  1202   798  5090  1926 16358  5090  1926
#    362 14797  2937  2553 19856  8144   349  2582   945  8144   349  2582
#    945  8144   349  2582   945    71 18865  7653   164    76    74 12935
#   1039   608    76  9990  1042    20  1455 11096  1736  7236 15112 15112
#  21496 16732  4416 16567 16567 14680 17192 16732 15027 13297 19579  9619
#   3858   107]
# -0.0651 0.004494514722328313

# %%
from collections import defaultdict

def list_duplicates(seq, x):
    tally = defaultdict(list)
    for i,item in enumerate(seq):
        tally[item].append(i)
    return (locs for key,locs in tally.items() 
            if key==x)

'''
ind=6
p=list_duplicates(ti,ti[ind])
#for l in p:
 #   print l
j=np.zeros(300)
print source_matrix[ind]
print source_matrix[191]
for l in p:
    for x in l:
        j+=source_matrix[x]
            
    target_matrix[ind]=j[:]/len(l)
print target_matrix[ind]
'''
# Out:
# '\nind=6\np=list_duplicates(ti,ti[ind])\n#for l in p:\n #   print l\nj=np.zeros(300)\nprint source_matrix[ind]\nprint source_matrix[191]\nfor l in p:\n    for x in l:\n        j+=source_matrix[x]\n            \n    target_matrix[ind]=j[:]/len(l)\nprint target_matrix[ind]\n'

# %%
import copy
count_no=0
j=np.zeros(300)
for r in range(0,ct1):
    #print source_matrix[r], target_matrix[r]
    #print len(source_matrix[r]),len(target_matrix[r])
    p=list_duplicates(ti,ti[r])
    j=np.zeros(300)
    for l in p:
        for x in l:
            j+=source_matrix[x]
            
        target_matrix[r]=j[:]/len(l)
    count_no+=1
    #target_matrix[r]=source_matrix[r][:]
    mi_dictionary.apply_cop(target_matrix[r],ti[r])

print count_no
# Out:
# 962

# %%
mi_dictionary.export('/home/apatra/fastText/fastText_multilingual-master/micmaq4.vec')
