# %%
import codecs
f1=codecs.open('/home/apatra/fastText/files/data/train.txt')
f2=codecs.open

# %%
import codecs

embed=[]
embed_vector=[]
f_vocab=[]
word2id={}
id2word=[]

name='/home/apatra/Desktop/work/lstm/mic1.vec'
with codecs.open(name,'r','utf-8') as f:
    (n_words, n_dim) = (int(x) for x in f.readline().rstrip('\n').split(' '))
    print (n_words, n_dim)
    
    for i, line in enumerate(f):
        
        elems = line.rstrip('\n').split(' ')
        #print (elems)
        word2id[elems[0]] = i
        f_vocab.append(elems[0])
        print(elems[0],i)
        #print (elems[0])
        #embed[i] = elems[1:]
        embed_vector = [float(i) for i in elems[1:]] # convert to list of float
        #embedding_dict[vocab_word]=embed_vector
        embed.append(embed_vector)
        id2word.append(elems[0])
# Out:
# (22926, 300)
# (u'</s>', 0)
# (u'na', 1)
# (u'aq', 2)
# (u"ta'n", 3)
# (u'ta\u2019n', 4)
# (u'aqq', 5)
# (u'tujiw', 6)
# (u'wen', 7)
# (u'mu', 8)
# (u'ula', 9)
# (u'wjit', 10)
# (u'kisna', 11)
# (u'wla', 12)
# (u'teli', 13)
# (u"se'sus", 14)
# (u'koqoey', 15)
# (u'mo', 16)
# (u'ugjit', 17)
# (u'kisi', 18)
# (u'msit', 19)
# (u'jel', 20)
# (u'gatu', 21)
# (u'mita', 22)
# (u'tel', 23)
# (u'gis', 24)
# (u"ni'n", 25)
# (u'ma', 26)
# (u'poqji', 27)
# (u'tan', 28)
# (u'weji', 29)
# (u'goqwei', 30)
# (u'pasik', 31)
# (u'mi\u2019soqo', 32)
# (u'etek', 33)
# (u'app', 34)
# (u'wenik', 35)
# (u'gjinisgam', 36)
# (u'amujpa', 37)
# (u'na\u2019sik', 38)
# (u'katu', 39)
# (u'muta', 40)
# (u'nekm', 41)
# (u'elp', 42)
# (u"mimajuinu'g", 43)
# (u'maw', 44)
# (u'ne\u2019wt', 45)
# (u'negm', 46)
# (u'mawi', 47)
# (u'ek', 48)
# (u'e', 49)
# (u'gisi', 50)
# (u'nkutey', 51)
# (u'telue', 52)
# (u'kaqi', 53)
# (u'nujj', 54)
# (u'nike\u2019', 55)
# (u'pa', 56)
# (u'me\u2019', 57)
# (u'toqo', 58)
# (u'i', 59)
# ...
