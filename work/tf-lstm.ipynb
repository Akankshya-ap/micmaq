# %%
import os
import codecs
import collections
import numpy as np


class Vocab:

    def __init__(self, token2index=None, index2token=None):
        self._token2index = token2index or {}
        self._index2token = index2token or []

    def feed(self, token):
        #print "Feeding token "+ token 
        #print type(self._token2index)
        if token not in self._token2index:
            # allocate new index for this token
            index = len(self._token2index)
            self._token2index[token] = index
            self._index2token.append(token)

        return self._token2index[token]

    @property
    #def com(self):
    #    return self._token2index
    def size(self):
        return len(self._token2index)

    def token(self, index):
        return self._index2token[index]

    def __getitem__(self, token):
        index = self.get(token)
        if index is None:
            raise KeyError(token)
        return index

    def get(self, token, default=None):
        return self._token2index.get(token, default)

    def save(self, filename):
        with open(filename, 'wb') as f:
            pickle.dump((self._token2index, self._index2token), f, pickle.HIGHEST_PROTOCOL)

    @classmethod
    def load(cls, filename):
        with open(filename, 'rb') as f:
            token2index, index2token = pickle.load(f)

        return cls(token2index, index2token)


def load_data(data_dir, max_word_length, eos='+'):

    char_vocab = Vocab()
    char_vocab.feed(' ')  # blank is at index 0 in char vocab
    #char_vocab.feed('{')  # start is at index 1 in char vocab
    #char_vocab.feed('}')  # end   is at index 2 in char vocab

    word_vocab = Vocab()
    #word_vocab.feed('|')  # <unk> is at index 0 in word vocab

    actual_max_word_length = 0

    word_tokens = collections.defaultdict(list)
    char_tokens = collections.defaultdict(list)

    for fname in ('train', 'valid', 'test'):
        print('reading', fname)
        with codecs.open(os.path.join(data_dir, fname + '.txt'), 'r', 'utf-8') as f:
            for line in f:
                line = line.strip()
                #print line
                line = line.replace('}', '').replace('{', '').replace('|', '')
                line = line.replace('<unk>', ' | ')
                if eos:
                    line = line.replace(eos, '')
                #print line
                for word in line.split():
                    if len(word) > max_word_length - 2:  # space for 'start' and 'end' chars
                        word = word[:max_word_length-2]
                        #print word
                    #word=word.lower()
                    word_tokens[fname].append(word_vocab.feed(word))
                    #print word_tokens[fname]
                    char_array = [char_vocab.feed(c) for c in word ]
                    #print char_array
                    
                    char_tokens[fname].append(char_array)
                    #print char_tokens[fname]
                    actual_max_word_length = max(actual_max_word_length, len(char_array))
                '''
                if eos:
                    word_tokens[fname].append(word_vocab.feed(eos))
                    print word_tokens[fname]
                    
                    char_array = [char_vocab.feed(c) for c in  eos ]
                    #print char_array
                    
                    char_tokens[fname].append(char_array)
                '''

    assert actual_max_word_length <= max_word_length
    
    #print word_vocab.token2index
    #count_pairs = sorted(word_vocab.com(), key=lambda x: (-x[1], x[0]))

    #words, _ = list(zip(*count_pairs))
    #for r in words:
     #   print r
    #print len(words)
    
    
    print()
    print('actual longest token length is:', actual_max_word_length)
    print('size of word vocabulary:', word_vocab.size)
    
    print('size of char vocabulary:', char_vocab.size)
    print('number of tokens in train:', len(word_tokens['train']))
    print('number of tokens in valid:', len(word_tokens['valid']))
    print('number of tokens in test:', len(word_tokens['test']))
    
    r=codecs.open('/home/apatra/Desktop/work/tokens.txt','w','utf-8')
    for i in range(0,word_vocab.size):
        print i, word_vocab.token(i)
        r.write(word_vocab.token(i))
        r.write('\n')
    '''
    # now we know the sizes, create tensors
    word_tensors = {}
    char_tensors = {}
    for fname in ('train', 'valid', 'test'):
        assert len(char_tokens[fname]) == len(word_tokens[fname])

        word_tensors[fname] = np.array(word_tokens[fname], dtype=np.int32)
        char_tensors[fname] = np.zeros([len(char_tokens[fname]), actual_max_word_length], dtype=np.int32)

        for i, char_array in enumerate(char_tokens[fname]):
            char_tensors[fname] [i,:len(char_array)] = char_array

    return word_vocab, char_vocab, word_tensors, char_tensors, actual_max_word_length
'''

# %%
load_data('/home/apatra/Desktop/work/data',65)
# Out:
# ('reading', 'train')
# ('reading', 'valid')
# ('reading', 'test')
# ()
# ('actual longest token length is:', 63)
# ('size of word vocabulary:', 24226)
# ('size of char vocabulary:', 98)
# ('number of tokens in train:', 67152)
# ('number of tokens in valid:', 4256)
# ('number of tokens in test:', 4678)
# 0 Mtul’katlku
# 1 Wjit
# 2 Koqwajo’taqann
# 3 Mimajulnu’k
# 4 Wejkuaqml’tlj
# 5 Na
# 6 Ke’sk
# 7 penoqlte’taqan
# 8 aqq
# 9 esatite’tmaqan
# 10 wjit
# 11 koqwajo’taqann
# 12 wejku’iaqmi’titlmimajulnu’k
# 13 wetapeksi’kl
# 14 elue’wuti’l
# 15 ta’n
# 16 msit
# 17 wen
# 18 poqwajite’tikl
# 19 wejkwite’tmkwsitqamu
# 20 tett
# 21 alsutk
# 22 teluej
# 23 teli-ktlamsltasij
# 24 alsutkpmawsin
# 25 keskmna’q
# 26 we’kwata’sik
# 27 kisna
# 28 kewisinu
# 29 ,
# 30 na
# 31 wla
# 32 kisi
# 33 tlapukuemk
# 34 msitmimajulnu’k
# 35 tliktantunew
# 36 mawi
# 37 espe’
# 38 .
# 39 nuta’q
# 40 tijiw
# 41 ji’nm
# 42 mu
# 43 ketu’
# 44 kisa’lawt
# 45 eliapsin
# 46 mitakespiagewe
# 47 matneke
# 48 matnmn
# 49 kestawite’taqan
# 50 emekwo’tasim
# 51 koqwajo’taqannwejku’laqmi’tl
# 52 mimajulnu’k
# 53 miamuj
# 54 etli-ankwo’tasikl
# 55 tplutaqaniktu
# 56 apoqonmatamn
# 57 tela’matultljik
# 58 eleke’wa’ki’
# 59 mimajuinu’k
# 60 naspultijik
# 61 Mawalo’mi
# 62 Eleke’wa’ki’l
# 63 kislwi’kml’tij
# 64 alsutaqn
# 65 Wi’katikniktukta’n
# 66 teli-espite’tmi’tij
# 67 iapjiw
# 68 wikaqteklkoqwajo’taqann
# 69 wejku’aqmi’till
# 70 mimejuinu’k
# 71 wkpmite’taqan
# 72 teliespite’lmij
# 73 nkutey
# 74 koqwajo’taqan
# 75 ji’nmukaqq
# 76 e’pijik
# 77 aqqkisite’tml’tij
# 78 ktmoqjnmnew
# 79 wejiwula’tekemk
# 80 mawio’mi
# 81 ajiklu’tnmimajuaqan
# 82 alsusut
# 83 mstl
# 84 eleke’wa’kl’lnastekl
# 85 Mawio’mi
# 86 lui’tmasultijiktoqlukwtnew
# 87 Eleke’wa’ki’
# 88 kisi-mawjukutine
# 89 ktmoqjenmnew
# 90 tamikepmite’tasiktn
# 91 klo’tasiktn
# 92 wejkul’aqmititl
# 93 mimajulnu’kaqqasusuti
# 94 ala’to
# 95 keknue’k
# 96 nsitmn
# 97 nenmin
# 98 koqwajo’taqannaqqalsusuti’l
# 99 kwalaman
# 100 kisitla’sitew
# 101 tel
# 102 lui’lmasultimk
# 103 nike’
# 104 Mawio’ml
# 105 telapukua’tij
# 106 :
# 107 Wula
# 108 Wtul’katikn
# 109 Koqwajo’taquann
# 110 Wejkuaqml’tij
# 111 mawiapoqntimu’k
# 112 elekewa’ki’
# 113 kulaman
# 114 aqqmsit
# 115 mawio’mi’l
# 116 wsitqamu’
# 117 klite’aq
# 118 wele
# 119 slawpukeltew
# 120 mitakinamueten
# 121 sasa’tutisnu
# 122 kepmite’tlsnu
# 123 wula
# 124 ta’nl
# 125 wejku’aqmi’kl
# 126 aqqta’n
# 127 telt
# 128 alsomsuti’k
# 129 wejinu’kwalsulti’k
# 130 ketlewa’tune
# 131 kmitkinaq
# 132 aqqse’k
# 133 wmitkiwa
# 134 ketlewa’tunen
# 135 telji’k
# 136 wsitqamu
# 137 nenasital
# 138 aqqketlamite’tasitql
# 139 kilk
# 140 ta’nik
# 141 nasupultijik
# 142 mawlo’mi
# 143 te’seleke’waki’l
# 144 we’kwiaq
# 145 we’kwlaswieke
# 146 Msit
# 147 weskwijinu’ltijik
# 148 alsumsultijik
# 149 newte’
# 150 wkpimte’tmutaqq
# 151 koqwajo’taqnn
# 152 wejkul’aqmitit
# 153 wejkul’aqmit
# 154 mimaji
# 155 teli-alsumsij
# 156 aqqtel-sankewe’k
# 157 we
# 158 Ma’
# 159 pisu’-lukwa’mit
# 160 keltaqanuksi
# 161 ;
# 162 keltaqanuksimkewey
# 163 pisu’lukalmimkeweylpa
# 164 ma
# 165 asite’tasinu
# 166 wunmajo’tasik
# 167 amaskwipilnuksik
# 168 ewlo’tasik
# 169 penoqo’tasi
# 170 wejku’aqamit
# 171 nenulte’tasin
# 172 pasik
# 173 tami
# 174 teli
# 175 skwijinulttplutaqanikiu
# 176 newte’telpukult
# 177 tplutaqaniktuk
# 178 aqqwejku’awami
# 179 keskma’q
# 180 piluite’tasinkisna
# 181 tepkislte’lmuksi
# 182 newte’tli-ikaluksin
# 183 wejku’aqamitnewte’tli-ikaluksin
# 184 kwlaman
# 185 ma’
# 186 penoqo’tasik
# 187 listmuk
# 188 telwikasik
# 189 kisnaassitmuk
# 190 wenl
# 191 listmlin
# 192 penoqite’teikeli
# 193 wejku’awamit
# 194 apoqomasutita’n
# 195 etli-ilsutekemk
# 196 teli-ewla’lujta’n
# 197 tujiw
# 198 kemutmuj
# 199 lapjiw
# 200 wikaqtek
# 201 iknmusn
# 202 tplutaqaniktukkisna
# 203 ewi’kasik
# 204 Ma
# 205 wskimtuk
# 206 kisi-pija’luksi
# 207 naqeyuksik
# 208 ejikleyuksi
# 209 tl-nutuksin
# 210 tlo’tasin
# 211 ilsumji
# 212 nujlilsuteklitl
# 213 alsumsik
# 214 welinqanilsuteke
# 215 ilite’tasikl
# 216 wkoqwajo’taqanmiaqq
# 217 natkoqoe’l
# 218 tepkatik
# 219 tla’teken
# 220 wen-aqq
# 221 telsmut
# 222 teli-o’
# 223 pla’teke
# 224 Ta’n
# 225 elsu’tmut
# 226 opla’taken
# 227 weskunk
# 228 tlite’tasinstaqa
# 229 nike’j
# 230 mna’q
# 231 teletekekis
# 232 mi’soqo
# 233 kisutasik
# 234 ketloqo
# 235 o’plateken
# 236 etlitlsumut
# 237 kejitoq
# 238 tela’sik
# 239 ikalsitew
# 240 iamujweskun
# 241 Aqq
# 242 aji
# 243 eplewi-apankitmuk
# 244 ta’nteli-opla’tekej
# 245 teli-apankitmumkis
# 246 opla’tekeje
# 247 sit
# 248 ikatluksin
# 249 sesepta’sualminikisna
# 250 ajina’mint
# 251 koqoe’
# 252 alsumsin
# 253 teli-ala’sij
# 254 ta’ntett
# 255 etlqatekej
# 256 wmitkim
# 257 kisi-nqitmn
# 258 eleke’waki’
# 259 we’kawwmitkin
# 260 apaja’in
# 261 Wla
# 262 kisi-likasiwun
# 263 opla’teken
# 264 tela’tekenta’n
# 265 wije’winuk
# 266 telltasult’tij
# 267 teliktlamsitasulti’tij
# 268 Mawio’miEleke’wa’ki
# 269 telakut
# 270 apija’tuaq
# 271 telakutk
# 272 kisnaqa’lawt
# 273 ktu’
# 274 sa’se’wa’toqta’n
# 275 Ji’nmuk
# 276 E’pijik
# 277 tepipuna’tijik
# 278 weskunmi’tij
# 279 koqwajo’taqannmalte’wultinew
# 280 wunijanultine
# 281 ketu
# 282 weni
# 283 telilnui
# 284 isna
# 285 ktlamsitasi
# 286 Wejku’aqamulti’tij
# 287 malie’wutiktu
# 288 e’sk
# 289 malie’wij
# 290 puna’teke
# 291 Kisi-malte’witaq
# 292 wenik
# 293 kitk
# 294 pewatmi’tij
# 295 ki’kajmalte’wa’lamin
# 296 Wen
# 297 wikmaq
# 298 welikoqwajite’tasik
# 299 mawi-espite’tasik
# 300 mawlo’mik
# 301 wejku’aqamitwen
# 302 ikatmuksin
# 303 Eleke’wa’ki
# 304 wejkuaqmit
# 305 alsutmin
# 306 koqoey
# 307 newtuka’lukwet
# 308 kisnamawalalsuteke
# 309 skimtuk
# 310 kisi-wusua’tuaj
# 311 alsut
# 312 telita’si
# 313 teltktlamsilasijaqq
# 314 teli-alasutma
# 315 wiaqtek
# 316 alsumsit
# 317 sa’se’wa’tun
# 318 ta’nteli-alasutmaj
# 319 telikilamsitasi
# 320 elt
# 321 etek
# 322 kisnamawukwat
# 323 sankewimajukatmin
# 324 mestiaknutmin
# 325 teli-alusutmaj
# 326 kisnateli-ketlamsitasij
# 327 kina’muet
# 328 etlintawa’qato
# 329 alasutmaj
# 330 aqqtelimajukatk
# 331 teli-alasutmat
# 332 teli-klamsitasi
# 333 telita’sij
# 334 telue
# 335 wlakoqwajo’taqaniktuk
# 336 kesma’q
# 337 sespeta’sualmint
# 338 aqqkisi
# 339 kwilmi
# 340 msinmn
# 341 iknmuetun
# 342 kinu’tmaqan
# 343 ankita’suaqan
# 344 mataqa’taqanewe’wk
# 345 tet
# 346 alsumsultinew
# 347 sankewi’mawita’newaqq
# 348 kisi-mawo’ltine
# 349 ki’kaji
# 350 nasa’luksik
# 351 naspi
# 352 kisi-ika’lsin
# 353 teli-nikana’tumkwmitki
# 354 koqwaju
# 355 mkunanta’niknikana’tu’tij
# 356 tele’k
# 357 wmitki
# 358 wejkut’aqmit
# 359 newte’kistllukwen
# 360 kaplno’l
# 361 wmitkin
# 362 telpewatmi’tij
# 363 na’te’l
# 364 wjiatew
# 365 tela’taqatijikta’nik
# 366 nikana’tu’tij
# 367 eleke’wa’k
# 368 nemitasitew
# 369 tijlw
# 370 menaqajmekunuj
# 371 loq
# 372 kimlapukwemk
# 373 newte’teli-assutmuk
# 374 mkunuj
# 375 nikanpukultiji
# 376 kis
# 377 pilute’telmamin
# 378 wejkui’aqmit
# 379 newtetliapankiluksin
# 380 newte
# 381 lukutl’tiji
# 382 elukwet
# 383 tetpaqi
# 384 apankituksin
# 385 kwlamanpkwatew
# 386 nekmaqq
# 387 mimajuaqan
# 388 teplaq
# 389 telukupmite’lmuj
# 390 aqqankuawtukomuksin
# 391 apoqnmuksin
# 392 elam
# 393 nuta’
# 394 teli-mila’sit
# 395 atlasmi
# 396 laqtek
# 397 telipkijlukwet
# 398 na’kwekl
# 399 iknumutl
# 400 apankitasiklatlasmin
# 401 ala’si
# 402 kisi-pkwatun
# 403 ta’ntelwele’k
# 404 telwelawsit
# 405 nekm
# 406 wikma
# 407 wiaqkitmumk
# 408 mijipjewe
# 409 tapsun
# 410 wikitaqq
# 411 telmaliamut
# 412 kesnukwaj
# 413 piluey
# 414 apoqonmasuti
# 415 wejkul’aqmitlkoqwajo’taqann
# 416 apoqonmuksin
# 417 kislukwe
# 418 ksnukwa
# 419 ejele’
# 420 siku’skewi
# 421 kisikulj
# 422 pkwatuk
# 423 wmimajuaqanm
# 424 mita
# 425 natala’teke
# 426 mijuajl’j
# 427 weskwijinultijik
# 428 malie’wimk
# 429 moq
# 430 newte’tli-anko’tasullila
# 431 ekina’masuti
# 432 awlinu
# 433 amskweseweyaqq
# 434 Amskwesewey
# 435 ekina’masutl
# 436 wessua’to
# 437 Ekina’masuti
# 438 ktmoqjentew
# 439 nsitatultinen
# 440 tqamutatultinu
# 441 wela’matutlinumsit
# 442 telakutimkl
# 443 teli-alasutmak
# 444 aqqstawa’tew
# 445 lukwaqanpemlukwatmi’tij
# 446 wantaqo’tl
# 447 stawwije’wmn
# 448 Knki’kwinaq
# 449 wejku’aqmitij
# 450 wesko’tmi’tij
# 451 nikantek
# 452 koqwajo’taqankisimkunmnew
# 453 tlkina’muaten
# 454 wunijanua
# 455 telo’lti’tijknutanmina
# 456 wekasin
# 457 lukwaqaney
# 458 nsituo’qo
# 459 kisi-wekasin
# 460 piley
# 461 koqoeykejitumk
# 462 wulapesi
# 463 maltaptmuksin
# 464 koqwaje’kaqq
# 465 wejikisitasik
# 466 wetapeksik
# 467 kjijitaqaniktu
# 468 wi’katikniktuk
# 469 kisltasik
# 470 ta’nnekm
# 471 kisa’to
# 472 kwlamantlwl-pmlatew
# 473 wkoqwajo’taqannaqq
# 474 wtalsusuti’ml
# 475 ewikasikl
# 476 Wikatikniktuk
# 477 tla’sit
# 478 wejkui’aqmitlkukwaqann
# 479 wutanm
# 480 kisi’sitew
# 481 ta’ntelqamiksi
# 482 alsusuti’lma’
# 483 ewe’wasinukl
# 484 popwajilukwektn
# 485 telapukuek
# 486 telite’tmumkipn
# 487 wtui’katiknua
# 488 Mu
# 489 wikasik
# 490 tlkitmumint
# 491 tluekin
# 492 Eleke’wa’k
# 493 kisnamimajuinu
# 494 wejkui’aqmijl
# 495 tilukwen
# 496 ta’ntli-ksika’tutal
# 497 alsusuti’l
# 498 kisiwikasik
# 499 Ula
# 500 Teli-Ilumuek
# 501 Weja’tekemk
# 502 kisi-panuijkatmik
# 503 koque
# 504 kisa’tumk
# 505 aq
# 506 kisi-wi’kmik
# 507 tan
# 508 teli-ilumuek
# 509 Mi’kmawey
# 510 koquey
# 511 teli-klo’tasik
# 512 Beaton
# 513 Institu’t
# 514 teli-mnuekeyek
# 515 kjijitasin
# 516 kisi-wikasik
# 517 etl-klo’tasik
# 518 Institutk
# 519 Unama’kik
# 520 Espi-Kina’matnewo’kuomk
# 521 nqamasian
# 522 teli-msnmik
# 523 ula
# 524 sa’qewe’l
# 525 espite’tasikl
# 526 kisi-wekkete
# 527 newtqo’ltijik
# 528 weliaqmuo
# 529 nuji-kina’mua’tite’wk
# 530 panuijkatmi’tij
# 531 ktikik
# 532 mimajuinu’
# 533 teltek
# 534 apoqnmuli
# 535 kwilmin
# 536 we’jitun
# 537 mi’kmawey
# 538 sa’qewey
# 539 Pi’tn
# 540 Institu’tk
# 541 etl-klo’tasi
# 542 lukwaqn
# 543 wejiaq
# 544 te’sik
# 545 Ethnoculturally
# 546 Koque
# 547 kisi-il-wi’kikipe
# 548 kisi-to’qi-ankaptikipnn
# 549 wi’katiknn
# 550 kisi-mawitasikl
# 551 ki’s
# 552 piamiw
# 553 tapuiska’q
# 554 je
# 555 na’n
# 556 tesi-punqekl
# 557 klaman
# 558 Ilumuek
# 559 nik
# 560 tetpaqtetew
# 561 telo’ltimk
# 562 menaqa
# 563 tli-nmitasitew
# 564 etekl
# 565 etli-klo’tasik
# 566 piltuamu’kl
# 567 koque’l
# 568 kaqi’sk
# 569 ewe’wmi’titl
# 570 kwiluasultite’wk
# 571 kaqismilamuksultiji
# 572 meta
# 573 pikwelk
# 574 kelu’lk
# 575 kjijitaqn
# 576 ete
# 577 niktua’tasik
# 578 ta’p
# 579 pukwel
# 580 wikasin
# 581 Vision
# 582 Statemen
# 583 policies
# 584 services
# 585 wejiaql
# 586 Institute
# 587 teli-Ilumuek
# 588 wel-klo’tasik
# 589 sko’ten
# 590 nekaw
# 591 nqamasiatew
# 592 teli-we’wmi
# 593 Tli’a
# 594 tleyawik
# 595 wutanminal
# 596 tum
# 597 siawi
# 598 klo’tew
# 599 anko’te
# 600 Wela’liek
# 601 tli
# 602 mawita’ne
# 603 etamulek
# 604 piskwa’n
# 605 eyme
# 606 tliatew
# 607 tel-mnueke
# 608 Iknmuinen
# 609 ksaltultinen
# 610 siawa’tesnen
# 611 ksalsuti
# 612 tamia
# 613 kepmite’lsultine
# 614 kijijitutesnen
# 615 newte’kj
# 616 wejiet
# 617 Ki’le
# 618 mlkite’lsultine
# 619 nutajite’lsik
# 620 lukwatmn
# 621 ktlukwagan
# 622 menaqajewo’ltine
# 623 klman
# 624 ewlek
# 625 ewla’lat
# 626 kikmana
# 627 penoqite’lsutine
# 628 espite’lsik
# 629 wikma’j
# 630 Aq
# 631 Niska
# 632 iknmuinen
# 633 ketleweyuti
# 634 waqme’ktital
# 635 nkamulamunal
# 636 njijaqmijinaq
# 637 nmu’lek
# 638 elmi’kni
# 639 My
# 640 Mesgigji'jit
# 641 Abeneki-
# 642 Mi'gmewei
# 643 glusuaqann
# 644 nasteg
# 645 wenuj
# 646 intelnet
# 647 igtug
# 648 !
# 649 Epjilaasi
# 650 mi'walul
# 651 ta'n
# 652 teljugu'e
# 653 Mi'watm
# 654 au
# 655 Ni'n
# 656 Abeneki-Mi'gmewa'j
# 657 teluisi
# 658 Sa'n
# 659 «Jean»
# 660 Claude
# 661 Béliveau(Sa'nGlo't
# 662 Béliveau
# 663 ktapekiaqnn
# 664 weji
# 665 ktapekiasikl
# 666 wjitkkisikuminaq
# 667 kniskamijinaqik
# 668 ta'npewatmi'tipnek
# 669 siawiknan
# 670 Megumaagee
# 671 aqteli'sulti'kw
# 672 ke'sk
# 673 koqqwa'tu'kw
# 674 kina'matneweimin
# 675 wejkul'aqmit
# 676 koqwajo'taqan
# 677 teluejaqq
# 678 ge'amujpa
# 679 etlsegnatl
# 680 iltaqane'watmeg
# 681 epatgupugultieg
# 682 alsutaqan
# 683 gina'masut
# 684 Nuta'q
# 685 maw
# 686 wi'kmnew
# 687 lnuwulti'k
# 688 knijannaq
# 689 lnuwi'sultinew
# 690 nekmowkw
# 691 siawa'taq
# 692 Mawio'm
# 693 Elugwa'tasin
# 694 'nui'sultinej
# 695 L'nui'etlintu'tieg
# 696 Kepmite'tmnej
# 697 wetapeksulti'kw
# 698 epmite'tmnej
# 699 teli-l'nuulti'kw
# 700 ---------------------------------------------------------------
# 701 ami
# 702 e'w'g
# 703 mtln
# 704 newtiskaq
# 705 si'st
# 706 tepgunset
# 707 tapuiska'q
# 708 jelukumujin
# 709 na'gwe
# 710 Ala
# 711 ne'wt
# 712 na'gweg
# 713 me'
# 714 jel
# 715 ukumujin
# 716 Apunknajit
# 717 de
# 718 Kjikú
# 719 Gisoltieg
# 720 powwo
# 721 Ne'wt
# 722 te's
# 723 ne'w
# 724 l'uiknek
# 725 gtigina'gwe
# 726 isku
# 727 Inu'
# 728 Saqamawk
# 729 Wnaqapenkkekunmi'tij
# 730 meski'k
# 731 lu'ko'kwaqan
# 732 kinjanaq
# 733 wktoqalamaki'kespek
# 734 kinamasu't
# 735 ekji'taq
# 736 koqwey
# 737 teliaqta'n
# 738 eymu'ti'jk
# 739 Inu'k
# 740 telki'k
# 741 wksitqam
# 742 Mi'kmaqKis
# 743 te'sikl
# 744 Se't
# 745 A'newimkl
# 746 pemiaql
# 747 mi'soqo
# 748 wi'katikn
# 749 wi'k
# 750 Kjikeptin
# 751 Alexander
# 752 Denny
# 753 etli
# 754 nsituapukuep
# 755 Potlotek
# 756 tewji
# 757 nuta'q
# 758 Lnu'k
# 759 klo'tmnew
# 760 Lnuwultijik
# 761 mlki
# 762 maliaptminew
# 763 lnuey
# 764 koqoe
# 765 teluep
# 766 Nuta'jik
# 767 t'an
# 768 pemkina'masultijik
# 769 pema'tu'tij
# 770 kina'matinewey
# 771 l'nuey
# 772 nike'
# 773 maliaptmuwk
# 774 pukwelk
# 775 ksika'site
# 776 Kikmanaq
# 777 kisiku'k
# 778 pemkaqieji
# 779 nenmi'ti
# 780 Mi'kamaq
# 781 telo'lti'tij
# 782 newmowkw
# 783 attimk
# 784 a'tukwetew
# 785 katu
# 786 wi'kmin
# 787 klusuaqn
# 788 Ta'n
# 789 telo'titij
# 790 wi'kasin
# 791 klo'taq
# 792 lnuwultiji
# 793 a'tukwaqn
# 794 Mikma'k
# 795 Pukwelk
# 796 we'n
# 797 apoqnmuwi
# 798 nuta'nuk
# 799 kejitutij
# 800 wela'lio
# 801 Ketu
# 802 a'tukowuloq
# 803 lnu'wo'lti'ti'j
# 804 lnuita'sulti
# 805 ketlamsitasultijik
# 806 kiwto'qa'sik
# 807 wskitqamu
# 808 weja'tekemk
# 809 weskwijinuit
# 810 kaqie
# 811 Te's
# 812 tepknuset
# 813 ajiet
# 814 pilua'sik
# 815 kutey
# 816 ika'q
# 817 siwkw
# 818 poqji
# 819 paskasueta'jik
# 820 nipi'jk
# 821 wasuek
# 822 Waisisk
# 823 penatmu'tiji
# 824 App
# 825 wskitaqamu
# 826 mimaju'a
# 827 Jipji'jk
# 828 waisisk
# 829 tukwia'tiji
# 830 Nike'
# 831 app
# 832 niwa'sik
# 833 na'ku'set
# 834 miklkina
# 835 kejitu'tij
# 836 tela'sik
# 837 wije'wmi'ti
# 838 Amskwes
# 839 kujjinaqi'k
# 840 i'ajiwsultipni'k
# 841 elta'jik
# 842 kelu'kw
# 843 ekwitamtimk
# 844 ktantekem
# 845 Kejitu'tip
# 846 kaqi
# 847 ktananew
# 848 kwitamalanew
# 849 mime'jk
# 850 weskewita'tij
# 851 tlikina'muksit
# 852 nenmn
# 853 kikiasiaq
# 854 Kiskuk
# 855 ne'kayiw
# 856 newte'
# 857 ktlamsitasultijik
# 858 jiko'tmn
# 859 we'wmn
# 860 wskitqam
# 861 Mita
# 862 anko'tmu'k
# 863 emqatu'si'k
# 864 we'ki
# 865 alsutmuk
# 866 wsitqam
# 867 kikma'j
# 868 apoqnmat
# 869 mijipjeweyiktu
# 870 tapsuniktu
# 871 sulieweyiktu
# 872 metue'k
# 873 ikaj
# 874 mawita'jik
# 875 apoqnmatultiji
# 876 ta'pu
# 877 anki'tasik
# 878 o'pltesk
# 879 wikma'jl
# 880 apoqnmuwa
# 881 lien
# 882 toqo
# 883 nuta'n
# 884 apoqnmasuti
# 885 msinte
# 886 kesite'tmi'tij
# 887 tetul
# 888 akutulti'j
# 889 kesala'tiji
# 890 mijua'ji'jk
# 891 kekmite'lma'tij
# 892 Kisiku'k
# 893 wniskamijewiliji
# 894 mekite'lmaji
# 895 ketlamsitwaj
# 896 mekite'lmatl
# 897 wukmi'eml
# 898 kijueml
# 899 wulmitoq
# 900 askate'lke
# 901 Nekm
# 902 mijua'ji'jik
# 903 nuji
# 904 ilumaji
# 905 keleiwaj
# 906 Keskelmitijiwuji'jk
# 907 wejinketoqi
# 908 Nukmi'
# 909 mawnaji
# 910 ilumaj
# 911 lita'suwalut
# 912 tele'k
# 913 tlia
# 914 sa'q
# 915 ki's
# 916 nekmowey
# 917 majukwatmi'tij
# 918 mekite'lma'titl
# 919 A'nal
# 920 Niskam
# 921 kijue'ml
# 922 nisikwi'sk
# 923 Nipialasutmank
# 924 Pestie'wa'ltim
# 925 L'nu'k
# 926 ewe'mi'ti
# 927 Meknasikl
# 928 wisunn
# 929 newtiska'q
# 930 na'kwek
# 931 pestie'wa'lu
# 932 mimajuinu'k
# 933 elta'tipn
# 934 wenjikuoml
# 935 pestie'wa'lut
# 936 mijipjewey
# 937 klujjiewey
# 938 ela'tu
# 939 meluij
# 940 amalkaltultijik
# 941 mijisultiji
# 942 ktik
# 943 kaqia
# 944 nike
# 945 pestie'wa'lujik
# 946 tajik
# 947 wi'kupaltultim
# 948 E'pijik
# 949 etoqta'tijik
# 950 ela'tu'tij
# 951 etl
# 952 pestie'wa'ltim
# 953 Ne'kayiw
# 954 mekenasikl
# 955 kisiku'
# 956 Amalkaltimk
# 957 mijisultimk
# 958 wikmuji
# 959 iknmutl
# 960 klujjieweymual
# 961 teluitmi'titl
# 962 telimut
# 963 la
# 964 ktwasuekm
# 965 peji
# 966 apu'sk
# 967 ktansale'witm
# 968 sapo'nuk
# 969 na'kwekm
# 970 Pikwelk
# 971 eykik
# 972 pestie'wa'ltimk
# 973 kepmite'lma'tij
# 974 kesik
# 975 mesnsik
# 976 pastek
# 977 wastew
# 978 mkumi
# 979 kelu'k
# 980 meketa'tij
# 981 kata
# 982 wissukwatl
# 983 katewapu'l
# 984 pkwasaw
# 985 elia'tij
# 986 Nkma'ji'j
# 987 piskwa'n
# 988 pkwasaq
# 989 wissukwa'tiji
# 990 lu'sknik
# 991 Apuknajit
# 992 piskwa't
# 993 esma'titl
# 994 nespitawaqtma'tijik
# 995 aptaqna'tinew
# 996 ku'jultine
# 997 maltikle'wimk
# 998 waltesta'tiji
# 999 Ki's
# 1000 Na'nike'
# 1001 aknutm
# 1002 suel
# 1003 ntu'kip
# 1004 waltestam
# 1005 Kaplno'l
# 1006 pa'tlia'sk
# 1007 ksika'tu'tis
# 1008 waltesta'
# 1009 timk
# 1010 ksika'la'tipn
# 1011 ksika'toqip
# 1012 te'sik
# 1013 ajipjutkip
# 1014 kiwaska'lan
# 1015 lnu'
# 1016 Pa'tlia'sk
# 1017 kesatmu'tikip
# 1018 waltesta'tim
# 1019 kisikuo'p
# 1020 ne'slijik
# 1021 wte'pitem
# 1022 tele'ksip
# 1023 naqa'tasikip
# 1024 waltesaqnn
# 1025 koqkwa'tasiksip
# 1026 Katu
# 1027 kiskuk
# 1028 waltesta'tijik
# 1029 ankaptmi'tik
# 1030 waltestamk
# 1031 o'pla'tekem
# 1032 pukweluk
# 1033 natawitoq
# 1034 waltestaqnn
# 1035 kisikuo'po'q
# 1036 JijiPo'lo'q
# 1037 ntawito'q
# 1038 Nekmaq
# 1039 teluet
# 1040 nuta't
# 1041 kmu'j
# 1042 metuina'
# 1043 Mqoqt
# 1044 to'q
# 1045 klu'k
# 1046 elikuwa'nu
# 1047 we'jitu'n
# 1048 tetpaqik
# 1049 we'wtew
# 1050 wikpi
# 1051 kmu'jm
# 1052 ila'kittu'n
# 1053 tlki'k
# 1054 "
# 1055 Kaqi
# 1056 lsmi
# 1057 ekwija'tu'n
# 1058 salaweyapuiktuk
# 1059 wejaqma'tu'n
# 1060 newtikiskik
# 1061 ejikl
# 1062 kma'tu'n
# 1063 sismoqnewap
# 1064 ilsmin
# 1065 we'kayiw
# 1066 aminte
# 1067 ewe'wmn
# 1068 waqn
# 1069 teluisik
# 1070 tla'knip
# 1071 naqamasianuk
# 1072 waltestaqno'q
# 1073 kiwto'qipit
# 1074 poqasutley
# 1075 pase'
# 1076 kisa'tu'n
# 1077 kispas
# 1078 kispast
# 1079 waltestaqno'
# 1080 ika'lit
# 1081 astua'li
# 1082 tapu'kl
# 1083 sasqe'l
# 1084 kuntal
# 1085 ke'kupo'tu'nl
# 1086 winpiasik
# 1087 Miamuj
# 1088 menaqajewa'sin
# 1089 pepke'jit
# 1090 naskoqtesintew
# 1091 pempiasi
# 1092 telpiasit
# 1093 tlpitew
# 1094 Ta'pu
# 1095 tepi
# 1096 wikispasit
# 1097 tepaqipiasik
# 1098 ili
# 1099 wjaqma'lit
# 1100 kaqpiasit
# 1101 ila'qipult
# 1102 me'ilika'li
# 1103 Tujiw
# 1104 ilwaqnoqsasit
# 1105 menaqaj
# 1106 wasoqite't
# 1107 pewjaqqe'ji'jk
# 1108 miawe'k
# 1109 ika'tu'
# 1110 Pewjaqqe'ji'j
# 1111 naqsi
# 1112 nasqotesintew
# 1113 e'plowa'lukuti'k
# 1114 waltestaqnji'jk
# 1115 tenu
# 1116 Waltestaqnk
# 1117 metue'kik
# 1118 eliu
# 1119 i'we'wmi'tipn
# 1120 tia'mue'l
# 1121 waqntal
# 1122 qalipue'l
# 1123 pasi
# 1124 metue'nukip
# 1125 mesnmik
# 1126 ketantaqitipni'
# 1127 wowjiktuk
# 1128 i'wjitu'tipn
# 1129 nekmowe'l
# 1130 klu'ktipn
# 1131 weli
# 1132 piatek
# 1133 ewe'wasikl
# 1134 wenjitia'
# 1135 mue'l
# 1136 waqnta
# 1137 mesnmin
# 1138 wejaqma'tu'nl
# 1139 jiklkmiaq
# 1140 wi'n
# 1141 mime
# 1142 Ela'kipuljik
# 1143 wasoqite'jik
# 1144 pasei'ti
# 1145 la'qittaqn
# 1146 kloqwej
# 1147 ewi'
# 1148 kit
# 1149 waltestaqniktu
# 1150 Asukom
# 1151 te'sijik
# 1152 eli'ji
# 1153 Kitmaqnk
# 1154 metuei'k
# 1155 Kmu'ji'japi
# 1156 sipikk
# 1157 laska'tum
# 1158 kitmaqnk
# 1159 wejiujik
# 1160 kmu'ji'jap
# 1161 ne'sijik
# 1162 kisukuw'
# 1163 skwa
# 1164 Naniska'ql
# 1165 kmu'ji'j
# 1166 Kisikuo'p
# 1167 etuwiw
# 1168 walnoqsasit
# 1169 kisikui'skwaq
# 1170 anapsasiji
# 1171 Kitmaqnn
# 1172 teluisit
# 1173 kisikuwi'skwaq
# 1174 telui'tujik
# 1175 tqamuewe'
# 1176 pqoji
# 1177 waltesta'titesnu
# 1178 papuaqn
# 1179 wsuwa'toq
# 1180 ki'kajeyu
# 1181 wel
# 1182 pase'k
# 1183 pla'kit
# 1184 elmiaq
# 1185 waltestaqn
# 1186 wnaqa'tumk
# 1187 ksikaweresknuk
# 1188 paskinetesknu
# 1189 Tapusijik
# 1190 astu
# 1191 pa'tijik
# 1192 wenaqa'tu'tij
# 1193 waltestaq
# 1194 tapusi'tij
# 1195 pukwelni'tij
# 1196 pantetesnulti'tij
# 1197 ejaqjepulti'tij
# 1198 waltestaqnk
# 1199 ikanwunaqa'to
# 1200 Poqji
# 1201 astu'te'matiji
# 1202 ne'patu'titl
# 1203 kmuji'jl
# 1204 tqamuewe'l
# 1205 kisikuo'pa
# 1206 kikmanaq
# 1207 waltestaji
# 1208 ne'wtewij
# 1209 ne'siskl
# 1210 kmu'ji'jl
# 1211 iknumut
# 1212 naskoqte'ma'ti
# 1213 ktmaqsete'mi'titl
# 1214 kisikui'skwa
# 1215 soqo
# 1216 tlpi'tij
# 1217 ika'tutl
# 1218 pesqunatek
# 1219 tqamuewey
# 1220 ne'pato
# 1221 pkwi'sikm
# 1222 tqamuewe
# 1223 kitmikl
# 1224 naskoqte'ma'timk
# 1225 -
# 1226 ika'tu'nl
# 1227 pesqunatekl
# 1228 Kloq
# 1229 kespiteskl
# 1230 ketmaqseta'sikl
# 1231 wetta'si
# 1232 Pkwimu
# 1233 (wla
# 1234 wette'mn
# 1235 telui'tasik
# 1236 pkwimu
# 1237 kwetapa'lit
# 1238 ne'patoq
# 1239 kespu'tuwet
# 1240 ne'patu
# 1241 wetto't
# 1242 ketmaqset'sik
# 1243 ketmaqseta'sik
# 1244 kitmaqnn
# 1245 wetta'j
# 1246 esnoqnem
# 1247 Ketantatl
# 1248 kisiku
# 1249 puksuk
# 1250 lo'tan
# 1251 mnkimt
# 1252 kisikuo'
# 1253 ne'wtewin
# 1254 ika'tan
# 1255 (puksuk)
# 1256 ta'puewin
# 1257 kmu'ji'jl'
# 1258 ne'patu'n
# 1259 nankl
# 1260 Nankl
# 1261 iko'tan
# 1262 Kitk
# 1263 elo'taji
# 1264 wnaqa'tew
# 1265 apatta'tl
# 1266 telui'tmik
# 1267 apajawlet
# 1268 tapuawtikl
# 1269 lo'ta'tit
# 1270 ne'patuk
# 1271 ktitk
# 1272 apankitatim
# 1273 menkima'titl
# 1274 wetta'tl
# 1275 kisikuo'pal
# 1276 apankitutl
# 1277 lo'tat
# 1278 Kisi
# 1279 iko'toq
# 1280 asukom
# 1281 iknmuwatl
# 1282 mnkimaj
# 1283 to'qo
# 1284 iko'taj
# 1285 na'tami
# 1286 kisiku'l
# 1287 apankituwatl
# 1288 ktikl
# 1289 na'
# 1290 telkitmn
# 1291 na'n
# 1292 esatikjawlet
# 1293 Meki
# 1294 ki'kajeyatultijik
# 1295 kapaqsimtultijik
# 1296 waltestajik
# 1297 ankama'tiji
# 1298 amalimtultiji
# 1299 wetta'sit
# 1300 apankitasit
# 1301 wi'kuo'qtatim
# 1302 iko'tatl
# 1303 mnte'k
# 1304 wenaqa'toq
# 1305 ne'
# 1306 patoq
# 1307 ika'taj
# 1308 ne'wte'
# 1309 kmu'jij
# 1310 epi
# 1311 pemlo'tatl
# 1312 tlisip
# 1313 newtute'k
# 1314 kislo'
# 1315 tatl
# 1316 mena'to
# 1317 Eyk
# 1318 pikwelkl
# 1319 lo'tatl
# 1320 mnte'muk
# 1321 milesit
# 1322 pekwi'sik
# 1323 ntutma
# 1324 simtuk
# 1325 ntutmaq
# 1326 nesute'k
# 1327 Jijuaqa
# 1328 pkwimu'l
# 1329 kwetapa'latl
# 1330 telitpiaq
# 1331 na'tuen
# 1332 pemwenaqa'toq
# 1333 wutanji'j
# 1334 l'nu'k
# 1335 tekweyatultiji
# 1336 weljaqe'k
# 1337 ketanaql
# 1338 pasiaq
# 1339 pkwim
# 1340 wasewi
# 1341 Newtapaqmik
# 1342 na'tuenl
# 1343 kiseiwatl
# 1344 winaknut
# 1345 piami
# 1346 mila'teket
# 1347 kewteskmuatl
# 1348 wtuom
# 1349 meluijj
# 1350 wekayik
# 1351 ekina'maq
# 1352 meka'sit
# 1353 atkitemi
# 1354 Telimatl
# 1355 tla'li
# 1356 nu'kwa'l
# 1357 kltaqpili
# 1358 mukk
# 1359 paqasaqali
# 1360 ti
# 1361 jipatk
# 1362 samqwa
# 1363 pkwimuo'q
# 1364 kwetapietaq
# 1365 poqjikwe'kaq
# 1366 elmi
# 1367 nespelmitaq
# 1368 awsma
# 1369 menuekepnek
# 1370 tla'luksi
# 1371 netutmat
# 1372 apjiw
# 1373 iko'
# 1374 kqama'ta
# 1375 kaqama'taj
# 1376 eyk
# 1377 wusapunk
# 1378 kejita'toq
# 1379 nastekl
# 1380 netutma
# 1381 telkitasikl
# 1382 esnoqnemkel
# 1383 tapuiska'ql
# 1384 apankitkl
# 1385 lo'ta
# 1386 weskweywaq
# 1387 pepse'k
# 1388 ktmaqseto'
# 1389 qsi
# 1390 apankituj
# 1391 wskunmaj
# 1392 la'lukete
# 1393 ela'luket
# 1394 ne'patoql
# 1395 mna'q
# 1396 ne'wtewi
# 1397 ela'lukwet
# 1398 wskunaj
# 1399 kisikuo'pl
# 1400 newte'jk
# 1401 l'uikne
# 1402 asuko
# 1403 pilu'kitmikl
# 1404 patu'n
# 1405 ika'tu'n
# 1406 Tqamuewey
# 1407 Si'st
# 1408 elekeji
# 1409 ta'sewik
# 1410 me'koqoey
# 1411 wenaqa'to
# 1412 Ktik
# 1413 a'maq
# 1414 nek
# 1415 a'ma
# 1416 attmk
# 1417 teluejik
# 1418 sapa'lukwetaq
# 1419 kespu'tueta
# 1420 kespu'tue
# 1421 Ke'jel
# 1422 waltesta'titek
# 1423 Sugar
# 1424 Joann
# 1425 ilpa'ti
# 1426 tij
# 1427 ikani
# 1428 wunaqa'toq
# 1429 Joanne
# 1430 elekej
# 1431 Francis
# 1432 iknmuatl
# 1433 weskumajik
# 1434 lpik
# 1435 waltestaqnji'j
# 1436 Nikma'ji'j
# 1437 kesikawiaq
# 1438 teleyi'ti
# 1439 naskoqte'
# 1440 ma'ti
# 1441 mile'sit
# 1442 koloql
# 1443 wettat
# 1444 Me'mu
# 1445 wetta'q
# 1446 esnoqnejik
# 1447 utay
# 1448 ta'puewi
# 1449 i'ka'tua'tl
# 1450 ta'sewi
# 1451 ne'wtewit
# 1452 klapis
# 1453 telimaji
# 1454 ukk
# 1455 jiksutuap
# 1456 Suga
# 1457 po
# 1458 se'skwetaq
# 1459 wetta'ta
# 1460 wejinu'kwalsit
# 1461 apitta'n
# 1462 enqa'toq
# 1463 waltes
# 1464 apankitut
# 1465 mnkima'titl
# 1466 apankituat
# 1467 telimatl
# 1468 satikjawlet
# 1469 welta'si
# 1470 wetto'l
# 1471 wtute'sk
# 1472 tmaqsete'so
# 1473 Wenaqa'toq
# 1474 ika'tuwaj
# 1475 kmu'ji'
# 1476 mente'
# 1477 muate
# 1478 Klapis
# 1479 Wunjek
# 1480 nasa'toq
# 1481 is
# 1482 kqama'tayanek
# 1483 sespemaji
# 1484 waltesaqnk
# 1485 waltestanji'jk
# 1486 newte'jit
# 1487 kitmaqn
# 1488 keptetesin
# 1489 ika'tuaj
# 1490 mena'toq
# 1491 kmu'ji'jek
# 1492 wusapun
# 1493 kqama'
# 1494 tayanek
# 1495 elapa'sit
# 1496 Sugaral
# 1497 kmu'ji'jml
# 1498 apankitk
# 1499 kisukuo'
# 1500 pal
# 1501 newte'kmu'ji'j
# 1502 weskunma
# 1503 kejiatl
# 1504 kspu'tuwelital
# 1505 la'lukwet
# 1506 etlintoq
# 1507 iamuj
# 1508 ika'
# 1509 lsi
# 1510 amalka
# 1511 L'uiknek
# 1512 ela'lukwey
# 1513 ksipu'taq
# 1514 Sugarsi'st
# 1515 ta'
# 1516 sewik
# 1517 i'
# 1518 mawa'tatl
# 1519 newkl
# 1520 lpultik
# 1521 ne'wtewita
# 1522 ela'lioq
# 1523 sapa'lukwekaq
# 1524 Sugaro'
# 1525 tey
# 1526 kespu'tu
# 1527 kinu'tmuksinew
# 1528 Klujjiewto't
# 1529 Kweltamultimk
# 1530 eliet
# 1531 sipu'ji'jk
# 1532 wejkwapniaq
# 1533 alasutmat
# 1534 samqwan
# 1535 esamqwat
# 1536 sipu'ji'jl
# 1537 nepitekekl
# 1538 tele'
# 1539 Essisoqnik
# 1540 kmtniktuk
# 1541 elta'ji
# 1542 Teluejik
# 1543 e'pite's
# 1544 A'nis
# 1545 nmiasna
# 1546 kijinu
# 1547 Ma'li
# 1548 Na'te'l
# 1549 wejinpisi
# 1550 Weja'tekemk
# 1551 aqtatpa'q
# 1552 asu'taqmiji
# 1553 Ne'ki
# 1554 alasutma'tijik
# 1555 ika'tij
# 1556 klujjieweyiktu
# 1557 Na'qaji'jk
# 1558 nqano'pati
# 1559 naqana'ma'tij
# 1560 elma'tu'ti
# 1561 elta'qik
# 1562 mimajuinu'
# 1563 mselsit
# 1564 nepiteke
# 1565 Pa'kewimk
# 1566 pekije'nuk
# 1567 Lapa'tko'tekem
# 1568 Santi
# 1569 Mawio'mi
# 1570 Potlote
# 1571 Mnikuk
# 1572 alame'sik
# 1573 Mawio'miaq
# 1574 ilutma'tijik
# 1575 ilutmi'tij
# 1576 tle'ktitew
# 1577 A'newitn
# 1578 Mawio'miey
# 1579 ilutmne
# 1580 Ke'sk
# 1581 aklasie'wk
# 1582 pejita'tikek
# 1583 Mi'kma'k
# 1584 nujutmi'ti
# 1585 tl
# 1586 kwitamtitaq
# 1587 ktantaqatitaq
# 1588 te'
# 1589 sijik
# 1590 wikultitaq
# 1591 ne'wte
# 1592 wmitk
# 1593 matnaqatitaq
# 1594 kjisaqmaw
# 1595 wikite
# 1596 teliaq
# 1597 wmitkiwaq
# 1598 ika'lujik
# 1599 nutqo'tijikji'nmji'jk
# 1600 semaqita'jik
# 1601 kinuwa'taqatiji
# 1602 kinuwa'taqatijik
# 1603 welte'tmi'tij
# 1604 sapa'si
# 1605 lukutiji
# 1606 pukuwik
# 1607 Mi'kmamaq
# 1608 maliama'tiji
# 1609 a'sisamat
# 1610 nutqwe'k
# 1611 kisikuwi
# 1612 mawikwaji
# 1613 Mi'kma'ki
# 1614 kjisaqamaw
# 1615 ikana'to
# 1616 putu'
# 1617 ilutma
# 1618 Kjikepti
# 1619 nujeywajik
# 1620 keptinaq
# 1621 maliaptik
# 1622 lnue'kati
# 1623 keptin
# 1624 keptina
# 1625 Nekmowkw
# 1626 wtlukwaqnmual
# 1627 teltekl
# 1628 majulkwatmnew
# 1629 kisutmi'ti
# 1630 Lapa'tko'tekemk
# 1631 Mawio'mia
# 1632 maqita'jik
# 1633 ilutinajik
# 1634 A'newiten
# 1635 A'newimk
# 1636 ilutmaji
# 1637 nuta'
# 1638 na't
# 1639 wsku'tasi
# 1640 ji'nmuk
# 1641 piluamuksultijik
# 1642 alqopaqjikapimuaq
# 1643 maqtewi
# 1644 musqunamuksilitl
# 1645 aloqpaqjikapim
# 1646 Putu's
# 1647 plamuowamuksilitl
# 1648 aloqpogjikapim
# 1649 kjikeptin
# 1650 watapsilitl
# 1651 alqopaqjikapim
# 1652 muskunamuksultiliji
# 1653 alqopaqjikapimua
# 1654 apoqntmu'
# 1655 tijik
# 1656 mawio'
# 1657 mi
# 1658 piluamuksultiliji
# 1659 ji'nm
# 1660 waqma'toq
# 1661 awti
# 1662 A'n
# 1663 la'laten
# 1664 mekwe'litl
# 1665 pma'toq
# 1666 maqtewi-mkwe'
# 1667 litl
# 1668 pema'la'titl
# 1669 stoqnamuksiliji
# 1670 alqopaqjikapimual
# 1671 ma'w
# 1672 ntutma'tiji
# 1673 nujo'tkl
# 1674 te'pe'pni'l
# 1675 wape'litl
# 1676 ijinjewamuksiliji
# 1677 alqopaqikapimua
# 1678 Mempeltuo'q
# 1679 sikntasitek
# 1680 alasutmewinu'
# 1681 Kujjinaqi'k
# 1682 ntawo'ltipni'k
# 1683 nemitu'tip
# 1684 pma'lukutaq
# 1685 Mi'kama
# 1686 Pa'pe'wa'ki
# 1687 kisutmapni'k
# 1688 nekmowe
# 1689 L'napskuk
# 1690 Concordate
# 1691 a'tukwatk
# 1692 kisutma'ti
# 1693 l'napskuk
# 1694 kitmn
# 1695 patatujk
# 1696 ika'n
# 1697 pa'tlia's
# 1698 l'nu
# 1699 kelnmi'tij
# 1700 klujjiewe
# 1701 inaqnek
# 1702 kaqmiji
# 1703 ewikasik
# 1704 patatuj
# 1705 teluek
# 1706 tleywata
# 1707 Mi'kamiq
# 1708 kekmite'taq
# 1709 keknuwaqn
# 1710 amskwesewey
# 1711 Pa'pe'
# 1712 wa'ki
# 1713 te'sliji
# 1714 wnaqapemk
# 1715 Ankweyu'lkwl
# 1716 wklusuaqnml
# 1717 se'sa'tu'tisn
# 1718 teluekl
# 1719 ksal
# 1720 apiksikt
# 1721 tetpaqa'n
# 1722 Ta'puewey
# 1723 alasutuo'kuom
# 1724 pantetek
# 1725 tuopit
# 1726 Pantetek
# 1727 tuopiti
# 1728 Pa'pe'wit
# 1729 ktu
# 1730 alasutmewultine
# 1731 kepmite'k
# 1732 Mi'kamawe
# 1733 Si'stewey
# 1734 komkwajuikasik
# 1735 asite'lmaji
# 1736 alasutmewinu'k
# 1737 alasutuo'kuoml
# 1738 l'tunew
# 1739 alame'sikenew
# 1740 kina'muanew
# 1741 kepme'k
# 1742 kesalt
# 1743 weleya
# 1744 Ne'wewey
# 1745 Pie'l
# 1746 wtapisqeik
# 1747 Nekmowe'l
# 1748 wji
# 1749 Saqmaw
# 1750 nenk
# 1751 alsusit
# 1752 Weji
# 1753 nastek
# 1754 l'napskukiktuk
# 1755 kjijitutew
# 1756 keleywaji
# 1757 alsusuti
# 1758 weja'toq
# 1759 Niskamewiktuk
# 1760 tepiatew
# 1761 jileywaq
# 1762 Na'newey
# 1763 kaqmijik
# 1764 Mi'kamaw
# 1765 toqa'maji
# 1766 Newte'
# 1767 pukuiji
# 1768 kelnik
# 1769 ewni'skopalikaqnji'
# 1770 ewni'skopalikaqnji'j
# 1771 keknuwatk
# 1772 me'newte'
# 1773 klotesnuk
# 1774 alsusulti'k
# 1775 l'nuwo'lti'k
# 1776 maliaptite
# 1777 wesku'tk
# 1778 telimapni
# 1779 Asukomowey
# 1780 wmitkiwal
# 1781 nasita'sni'k
# 1782 kisutma'tip
# 1783 Pa'pe'wa'k
# 1784 L'uiknekewey
# 1785 tmaqn
# 1786 tmi'k
# 1787 nekowey
# 1788 elui'tmasip
# 1789 majukwatmnew
# 1790 siaw
# 1791 naspin
# 1792 toqoqwa'tij
# 1793 Ukmuljinewey
# 1794 toqtekl
# 1795 tespo'qasiknn
# 1796 keknuwatmi'tij
# 1797 wjisaqmaw
# 1798 apoqnmuan
# 1799 kina'muan
# 1800 sape'wui
# 1801 koqwajiaqewey
# 1802 apiksiktuaq
# 1803 pkwatoq
# 1804 kejitatekl
# 1805 maqamikewiktu
# 1806 kluijiewey
# 1807 Mi'kama'ki
# 1808 kloqowe
# 1809 mtawekn
# 1810 wape'
# 1811 Ewikasik
# 1812 me'kwek
# 1813 Mawio'mi'
# 1814 sa'
# 1815 mekwe'k
# 1816 mawio'mi
# 1817 Potolek
# 1818 mawa'matultine
# 1819 kikmanaqi'k
# 1820 nujilutma'tipni'
# 1821 wiaqiepni'k
# 1822 wapna'kiewaq
# 1823 kwetej
# 1824 Wji
# 1825 eykipnek
# 1826 teluisiksipnek
# 1827 ukte
# 1828 kisutmi'tipne
# 1829 Klujjiewey
# 1830 kepmite'tk
# 1831 alasutmewinultiji
# 1832 eloqpi
# 1833 kekmuwatk
# 1834 telki'
# 1835 Kespe'kewaq
# 1836 Ktaqimku
# 1837 keknuwaqnn
# 1838 weskuna'tij
# 1839 Sa'qewe'jaqi'k
# 1840 mawio'miaqi'k
# 1841 nekml
# 1842 kekuna'tip
# 1843 ewikasi
# 1844 kiwto'qiwi'kasi
# 1845 klujjiewe'l
# 1846 kmtnk
# 1847 keknuwatmi'titl
# 1848 saqmaq
# 1849 ewe'watl
# 1850 e'sus
# 1851 ewlite'lmine
# 1852 a'li
# 1853 alasutmelsewinen
# 1854 Eleke'waki
# 1855 apoqnmatultinew
# 1856 matntultine
# 1857 Tplutaqnn
# 1858 kisitu'tipn
# 1859 klo'ttaq
# 1860 tela'matultipni
# 1861 nekmowki'k
# 1862 klo'tmnow
# 1863 pejita'jik
# 1864 nsitmnew
# 1865 alsusultijik
# 1866 Kujjinaqni'k
# 1867 nemitutis
# 1868 kwitamti'tij
# 1869 ktantaqati'tij
# 1870 alsumsultita
# 1871 l'ta'ti
# 1872 nemitu'tipnek
# 1873 maliaptasin
# 1874 wejkwita'ji
# 1875 kisituma'tipnek
# 1876 ek
# 1877 kelo'tmi'tij
# 1878 Wikewiku's
# 1879 Kjipuktuk
# 1880 sku'tmi'ti'j
# 1881 kisa'matulti'tip
# 1882 wsuwa'la'tiji
# 1883 wnaqapemua
# 1884 ankaptimi'tij
# 1885 nsitmi'tij
# 1886 ewey
# 1887 pukwin
# 1888 awi
# 1889 lita's
# 1890 waltimk
# 1891 La'patko'tekemk
# 1892 eptek
# 1893 wsitkqam
# 1894 alta'jik
# 1895 l'nue'kati'
# 1896 tewa'timk
# 1897 emittukwaltultim
# 1898 Mi'jua'ji'jk
# 1899 tkismultijik
# 1900 papultiji
# 1901 nuku
# 1902 pkije'nuk
# 1903 A'newite
# 1904 Na'
# 1905 Peskewiku's
# 1906 a'qitayik
# 1907 wskwijinu'k
# 1908 liwsultijik
# 1909 A'newultiji
# 1910 Wikuoml
# 1911 kaqmultikl
# 1912 wisukwa'tiji
# 1913 Eykik
# 1914 amalimtmeta'jik
# 1915 tekisimultiji
# 1916 oqa'tij
# 1917 apoqnmujik
# 1918 ewi'ka'tijik
# 1919 pite'muji
# 1920 na'kwekl
# 1921 pkiji
# 1922 A'newim
# 1923 mimajuwinu'k
# 1924 Pikwelkik
# 1925 etetkl
# 1926 wikual
# 1927 kaqmo'tu'titl
# 1928 tent
# 1929 pemwi'ka'tiji
# 1930 Apoqnmatultijik
# 1931 ewi'ka
# 1932 poqjiaq
# 1933 mniku
# 1934 Mimajuinu'k
# 1935 wisukwa'tijik
# 1936 emittukwaltultiji
# 1937 Mijua'ji'jk
# 1938 pempejita'jik
# 1939 walipotl
# 1940 asuwita'q
# 1941 kweltamultimk
# 1942 emittukwaltultijik
# 1943 pite'ma'tiji
# 1944 amskwes
# 1945 nemi'tultijik
# 1946 newtipunqek
# 1947 wejita'jik
# 1948 amasek
# 1949 pastumkewa'ki
# 1950 l'nuwe'kati'
# 1951 Meluij
# 1952 welta'suwaltultiji
# 1953 Tami
# 1954 telimuksin
# 1955 ijisi
# 1956 tukwia'ti'tij
# 1957 asuwita'ql
# 1958 walpoitl
# 1959 pemi
# 1960 pejiwsultiji
# 1961 qame'k
# 1962 oqa't
# 1963 eskmatmi'titl
# 1964 walipot
# 1965 atel
# 1966 pejo'tu'titl
# 1967 saske'al
# 1968 wi'ka'tita
# 1969 a'soqmasit
# 1970 naqtmuk
# 1971 kaqiaq
# 1972 wissukwataqtijik
# 1973 pingowik
# 1974 Mawwio'm
# 1975 Mijua'ji'jik
# 1976 mila'taqatiji
# 1977 Kespitek
# 1978 pemkaqama'tu'titl
# 1979 wikua
# 1980 Emittukwaltultijik
# 1981 Pemi
# 1982 atelk
# 1983 welkaqani
# 1984 Na'tami
# 1985 e'pijik
# 1986 kesispa'lu
# 1987 Alasutmaqnn
# 1988 ujjie
# 1989 kuleina
# 1990 te'siji
# 1991 Se'su
# 1992 Ma'l
# 1993 So'se
# 1994 Ki'lwelmitu'n
# 1995 sape'win
# 1996 A'
# 1997 Ekitk
# 1998 ksispa'luj
# 1999 piskweta'jik
# 2000 etawaqtma'tijik
# 2001 wnijanua
# 2002 ksnukowinu'
# 2003 eskmaqtma'tijik
# 2004 alasutmelsewuji
# 2005 liet
# 2006 attawaqtma
# 2007 Anji'j
# 2008 Po'l
# 2009 A'naq
# 2010 kesispa'luji
# 2011 wape'k
# 2012 a'tlawekn
# 2013 we'wmi'tij
# 2014 waqme'
# 2015 kasa'lut
# 2016 temino'tasik
# 2017 tepu'tjik
# 2018 e'piji
# 2019 pu'tayji'jk
# 2020 pekisula'tiji
# 2021 weswa'tu'tij
# 2022 a'tlaweknji'j
# 2023 samqwanji'j
# 2024 elma'tu'tij
# 2025 ktlamsitasulti'tij
# 2026 kno'tulu
# 2027 Wtapsun
# 2028 naso'tulut
# 2029 wasuekl
# 2030 naso'tasikl
# 2031 e'pite'ji'k
# 2032 apoqtmu'tiji
# 2033 kisa'lut
# 2034 alasutuo'kuo
# 2035 tewa'lu
# 2036 ilajultijik
# 2037 wa'qmalsultijik
# 2038 kikjuk
# 2039 Walipotl
# 2040 puni
# 2041 kikia'skiteskma'tijik
# 2042 a'sukujik
# 2043 malsano'kuoml
# 2044 pepjoqita'q
# 2045 Nike'alme'si
# 2046 ala'sit
# 2047 ala'toql
# 2048 te'pe'pni'
# 2049 wesuo'tutit
# 2050 klujjiewto'sit
# 2051 malqutk
# 2052 elmo'tu'titl
# 2053 wikuaq
# 2054 kaqnmawin
# 2055 wsko'tmi
# 2056 Siaw
# 2057 tpi'kettal
# 2058 ala'mesik
# 2059 ilpukueta'jik
# 2060 tua'laten
# 2061 Tlia'kispesaq
# 2062 na'kwe
# 2063 sespete'tmuk
# 2064 ne'ata'tew
# 2065 tua'lu
# 2066 Msitt
# 2067 kaqjesma'tiji
# 2068 Siswa'qate'kn
# 2069 poqtita'q
# 2070 ika'nasit
# 2071 Tom
# 2072 Syllibo
# 2073 Raymond
# 2074 Stevens
# 2075 pema'to
# 2076 pemukwalat
# 2077 Sante
# 2078 pemita'ji
# 2079 Nujintu'tijik
# 2080 pemukwala'tiji
# 2081 teluisikl
# 2082 O'sape'win
# 2083 Matle'newey
# 2084 pemlamutimi'tit
# 2085 so'qita'm
# 2086 mtaweknn
# 2087 pema'tu'titl
# 2088 pemukwala'tij
# 2089 Ikana'sik
# 2090 A'newe
# 2091 Malia'n
# 2092 Ma'sl
# 2093 e'pite'ji'jk
# 2094 pem
# 2095 wije'wa'tit
# 2096 Viola
# 2097 Christmas
# 2098 Malkalit
# 2099 Gloade
# 2100 pema'tu'tit
# 2101 Nike'Pie'l
# 2102 Doucette
# 2103 pemie
# 2104 pemamkistoql
# 2105 wasuekji'jl
# 2106 la'late
# 2107 A'na
# 2108 wtejk
# 2109 tapusijik
# 2110 Dianna
# 2111 Malsulian
# 2112 pema'tiji
# 2113 Nujeywa'tiji
# 2114 atl
# 2115 piltuwila'lujik
# 2116 pemiaq
# 2117 newtipunqe
# 2118 pemukwala'titl
# 2119 Mawi
# 2120 wejita'ji
# 2121 ikati'j
# 2122 klujjieweyiktuk
# 2123 ika'lut
# 2124 kuntewiktuk
# 2125 mawita'ji
# 2126 nestuapukwa'tijik
# 2127 kaqma'sit
# 2128 nestuwimaji
# 2129 kaqawistoq
# 2130 elapatoq
# 2131 kuntewiktu
# 2132 nutqo'ltijik
# 2133 klujjiewto'sultijik
# 2134 metoqita'm
# 2135 kuntew
# 2136 niwianuk
# 2137 ketui
# 2138 elie
# 2139 me'telpek
# 2140 kaqita'tijk
# 2141 telpemita'jik
# 2142 apija'lu
# 2143 elte'mi'tij
# 2144 ipkelmulek
# 2145 metal
# 2146 elta'mk
# 2147 Alasutmamk
# 2148 elapekulti'titl
# 2149 newti
# 2150 kiskik
# 2151 pejita'ji
# 2152 walipotji'jl
# 2153 panteta'q
# 2154 amalimtma'
# 2155 alasutuo'kuomk
# 2156 nike'app
# 2157 pingowi
# 2158 alsopia'tijik
# 2159 altuku'ltiji
# 2160 wli
# 2161 pqojiaq
# 2162 Ping
# 2163 kuta'tikl
# 2164 kispesan
# 2165 sespete'tmi'tik
# 2166 kispesa
# 2167 Bingoe'ma'tiji
# 2168 Knekk
# 2169 wetsitmunkl
# 2170 pepkijeta'ql
# 2171 metewelmultijik
# 2172 se'skutijik
# 2173 a'ho
# 2174 nutqoltijik
# 2175 asuita'jik
# 2176 elmite
# 2177 na'kwet
# 2178 ilpalikat
# 2179 wutmo'taqnwual
# 2180 lo'tu'titl
# 2181 qasqe'k
# 2182 na'taqmquswa'timkewe
# 2183 alme'siek
# 2184 kiwyo'qi
# 2185 alasutmam
# 2186 kisa'tu'tij
# 2187 kiwtoqi
# 2188 alasutmamkewe'l
# 2189 piskweta'm
# 2190 piskweta'mk
# 2191 mawiejik
# 2192 nespu
# 2193 ika'tu'tij
# 2194 suliewe
# 2195 Kaqnk
# 2196 ilta'luji
# 2197 i'l
# 2198 welmitu'n
# 2199 Sape'win
# 2200 ekitasi
# 2201 meselsultiji
# 2202 Mitklpukuweta'jik
# 2203 A'newultijij
# 2204 Me'nkk
# 2205 muisultijiji
# 2206 apajita'tij
# 2207 Me'nk
# 2208 mawo'tu'tij
# 2209 l'nui
# 2210 npisu
# 2211 kispasmi'ti
# 2212 wi'tmu
# 2213 milamu'k
# 2214 npisun
# 2215 ni'n
# 2216 maqatewiksuwa'tu
# 2217 L'nui
# 2218 elita'suwatmn
# 2219 ki'l
# 2220 tawaqtman
# 2221 npilulni
# 2222 Pukwelkik
# 2223 me'kiskuk
# 2224 ewe'mi'tij
# 2225 awnaqa
# 2226 nenmi'tij
# 2227 l'nue'kati
# 2228 pukwelkik
# 2229 wikultiji
# 2230 ketl
# 2231 mijua'ji'jl
# 2232 we'jitat
# 2233 lpa'tu'ji'j
# 2234 ewliskwiji
# 2235 telue'jik
# 2236 ani'stmaqweyk
# 2237 ke'
# 2238 pqujulsultine'j
# 2239 nqalanej
# 2240 wunija
# 2241 Ketl
# 2242 kaqita'tki'k
# 2243 weskwiet
# 2244 Nikma'jji'j
# 2245 jiktek
# 2246 eymu
# 2247 alpukuweta'tij
# 2248 nutuwa'titl
# 2249 meto'temilit
# 2250 kwiluwasultiji
# 2251 Amskwestelta'
# 2252 sultijik
# 2253 amalsiktma'
# 2254 wlnutua'titl
# 2255 mijua'ji'j
# 2256 piskweta'tij
# 2257 we'jia'titl
# 2258 etlnuneskwelitl
# 2259 wkwij
# 2260 neplisn
# 2261 we'kwata'sultijik
# 2262 tal
# 2263 klu'sik
# 2264 mijua'ji'
# 2265 ke
# 2266 pa'qekene
# 2267 wesua'la'titl
# 2268 poqtituku'la'tit
# 2269 ansma
# 2270 pa'qeke'tij
# 2271 kelusit
# 2272 telimaj
# 2273 pe
# 2274 pa'qaqalip
# 2275 aknutmuloq
# 2276 wskwijinuia
# 2277 ika'limkip
# 2278 wskitqamu'k
# 2279 kinu'tmuan
# 2280 aknutk
# 2281 jiksituik
# 2282 kinu'tmasultik
# 2283 kilow
# 2284 kinu'tmuatoqsip
# 2285 kaqewistoq
# 2286 apaji
# 2287 kjita'sitaq
# 2288 msnmi'tip
# 2289 kespia'tuksi'
# 2290 wlpiskwa't
# 2291 ktantaqatiji
# 2292 lintukk
# 2293 tia'
# 2294 muk
# 2295 kelu'sultiji
# 2296 Ji'nmuk
# 2297 soqita'jik
# 2298 ketantaqitiji
# 2299 amasiko'lti'k
# 2300 maliamtultijik
# 2301 askate'tatiji
# 2302 T'an
# 2303 ijk'j
# 2304 mawtita'jik
# 2305 wl
# 2306 nemitumk
# 2307 kesnukwat
# 2308 nepk
# 2309 kinuwa'taqn
# 2310 kesi
# 2311 mimajuinu'l
# 2312 pneltit
# 2313 mimajuinu
# 2314 pnet
# 2315 newtukwa'lukwe
# 2316 Pejita'jik
# 2317 elakut
# 2318 elta'titl
# 2319 apiksiktatultiji
# 2320 pekijipnet
# 2321 me'kaqi
# 2322 kisa'tekek
# 2323 na'twenl
# 2324 eskamalatl
# 2325 kisit'sultilik
# 2326 alasutma'tiji
# 2327 Ktikik
# 2328 wskwijnu
# 2329 wikm
# 2330 pejo'tu'tij
# 2331 sulieweya'la'tij
# 2332 pnej
# 2333 ne'wtapaqmia
# 2334 ekitmi'titl
# 2335 aniapsimkewe'
# 2336 Summink
# 2337 nespikima'tiji
# 2338 el
# 2339 ketlamsitas
# 2340 pa'qapukuwe
# 2341 lo'q
# 2342 meske
# 2343 nemi'n
# 2344 elisin
# 2345 npo'qnek
# 2346 Mal
# 2347 alasutmaqnn
# 2348 nenqi
# 2349 kitmi'tikl
# 2350 wskwjinu
# 2351 ewilamiej
# 2352 waju'taq
# 2353 lami
# 2354 kespisawe'k
# 2355 wkwatl
# 2356 tekikl
# 2357 wqusi'k
# 2358 piluamukweta'li
# 2359 Wpukwikl
# 2360 poqj
# 2361 saqpiku'niaql
# 2362 aptitek
# 2363 Pem
# 2364 awisiw
# 2365 Pikwelken
# 2366 tluetew
# 2367 welinpawanek
# 2368 newtitpa'q
# 2369 mettewe'k
# 2370 mettetesk
# 2371 npek
# 2372 wije'tultita
# 2373 kiwalsultiji
# 2374 Apjiw
# 2375 ne
# 2376 nujimaji
# 2377 weskwieliji
# 2378 wlmajita'
# 2379 atkitemulti'k
# 2380 ktlamsit
# 2381 asik
# 2382 mewima
# 2383 Ewlistuatl
# 2384 mewimt
# 2385 tlimut
# 2386 lkita's
# 2387 kikmanu
# 2388 kaqietew
# 2389 naqateskasi
# 2390 kaqtaq
# 2391 nepkaq
# 2392 wskwijinuaq
# 2393 Pekisitu'tij
# 2394 tekweywa'tij
# 2395 sultij
# 2396 me
# 2397 kijka'
# 2398 jentesk
# 2399 elmita'jik
# 2400 iknmua'tiji
# 2401 atlasmultine
# 2402 petteqmultijik
# 2403 wapk
# 2404 waqma'tu'tij
# 2405 Epijik
# 2406 elo'tutij
# 2407 nipapiktuate
# 2408 Kaqapija'laltitl
# 2409 elaqpilekn
# 2410 npuinu
# 2411 lisinte
# 2412 oqpilup
# 2413 wutqutalute
# 2414 pekisitasij
# 2415 npuwinu
# 2416 wikmawa
# 2417 alasutmamk
# 2418 kaqama'sip
# 2419 kwijmuk
# 2420 netawet
# 2421 lasutmaykipo'q
# 2422 ekimujik
# 2423 ekitasik
# 2424 knekk
# 2425 epa'sit
# 2426 pite'mat
# 2427 mijisit
# 2428 kaq
# 2429 tepiaq
# 2430 Atukitijik
# 2431 wekowoltijik
# 2432 weskuma'titl
# 2433 wskwijinua
# 2434 nenua'tisn
# 2435 Aknutmi'tij
# 2436 mimajuin
# 2437 ua
# 2438 kisw'
# 2439 kisnaq
# 2440 wlmitoqsipna
# 2441 sikutesknuk
# 2442 ketlamsitasulti'k
# 2443 wtqutanew
# 2444 kweltamutimk
# 2445 ki'sna
# 2446 Ekntiewim
# 2447 ne'siptaq
# 2448 wutqutam
# 2449 Elta'mk
# 2450 alame'si
# 2451 alame's
# 2452 l'nuikilja'tijik
# 2453 l'nuwintu'tiji
# 2454 ela'lut
# 2455 wutqutaqne'kati
# 2456 Pa'tlia's
# 2457 lisqeikn
# 2458 nisa'sik
# 2459 meknmi'tij
# 2460 tupkwanji'j
# 2461 eleke'tij
# 2462 wutqutaqniktu
# 2463 wutqutamk
# 2464 saliteyi
# 2465 Meski'kl
# 2466 pataluti'l
# 2467 smujik
# 2468 wutmo'taqn
# 2469 wskwijin
# 2470 tepkiso'tu'tij
# 2471 wnaqa'tasito
# 2472 Ne'wte'jit
# 2473 e'pit
# 2474 wi'kik
# 2475 telawtik
# 2476 ntui'skasik
# 2477 Ji'nm
# 2478 asuimtma't
# 2479 pemwunaqnk
# 2480 na'tq
# 2481 nike'naqsun
# 2482 eptaq
# 2483 sapkawej
# 2484 ela'tuj
# 2485 mesnk
# 2486 apankit
# 2487 apoqntiki
# 2488 wenaqo'tasit
# 2489 Elmi
# 2490 wunaqo'tasik
# 2491 e'piteweyey
# 2492 ji'nmuik
# 2493 wnaqa'tu'tik
# 2494 maliapti
# 2495 kitasik
# 2496 suliewey
# 2497 ankaptasik
# 2498 tettue
# 2499 piamiaq
# 2500 iknutmu
# 2501 elsutmitij
# 2502 A'newiktuk
# 2503 Mawio'miktuk
# 2504 na'twen
# 2505 apoqnmuwaji
# 2506 lsuttaq
# 2507 tla'toq
# 2508 apankitasik
# 2509 Pe'nuku
# 2510 kaqia'tukwey
# 2511 ajipjulk
# 2512 me'na't
# 2513 kinu'tmasin
# 2514 ankua'tu
# 2515 I'taliagas
# 2516 amgwes
# 2517 agnutg
# 2518 Wikewiku’s
# 2519 aqalasie'w
# 2520 kunugwa’sude
# 2521 guvulnol
# 2522 Edward
# 2523 Cornwallis
# 2524 negmewe'g
# 2525 ‘nutuplu
# 2526 mawita'jig
# 2527 HMS
# 2528 Beaufor
# 2529 na'taqamtug
# 2530 Chebucto
# 2531 gjigan
# 2532 teluisigu
# 2533 Halifa
# 2534 Nopa
# 2535 Sko'sia
# 2536 sma'gnisg
# 2537 mesimatl
# 2538 negm
# 2539 ilsutegete
# 2540 -Scalp
# 2541 Proclamation-
# 2542 gasa'latl
# 2543 Mi'gmewa'jg
# 2544 pgoatoan
# 2545 nepaietj
# 2546 negmowowei
# 2547 menuegetoq
# 2548 mo
# 2549 alasutumak
# 2550 aptaqat
# 2551 Teplumatl
# 2552 pounds
# 2553 lpa
# 2554 ms't
# 2555 kestej
# 2556 pa
# 2557 tegen
# 2558 getemetesultijig
# 2559 nenkajae
# 2560 newtiskaqji'nm
# 2561 e'pite'jij
# 2562 Acadie
# 2563 ilsutegetew
# 2564 sespeiwat
# 2565 jile'g
# 2566 ne'pa'tl
# 2567 l'nug
# 2568 milui'tatl
# 2569 Micmac
# 2570 tam
# 2571 Gelutget
# 2572 saputaqatg
# 2573 maqamigal
# 2574 ejigla'to
# 2575 Cincinnati
# 2576 university
# 2577 pemegegnu'tmuatl
# 2578 Geoffrey
# 2579 Plank
# 2580 telte'tg
# 2581 upsugatp'
# 2582 suliewei
# 2583 sa'se'wa'lat
# 2584 uvulnol
# 2585 matntimg
# 2586 moqwa'
# 2587 goqwei
# 2588 gesgmnaq
# 2589 ana
# 2590 Sko'si
# 2591 Glusuaqan
# 2592 egitgl
# 2593 g'pnno'lewa
# 2594 Chamber
# 2595 of
# 2596 commerc
# 2597 Gelusit
# 2598 mattuntim
# 2599 Woktukodea
# 2600 pegedunumadimkawa
# 2601 kese
# 2602 kejela'tasi
# 2603 a
# 2604 getmenejig
# 2605 Iapjiw
# 2606 Mesgi'g
# 2607 matnaggewaqan
# 2608 wesgowa's'g
# 2609 apugjig
# 2610 agnutmuate
# 2611 Toqo
# 2612 eime
# 2613 etug
# 2614 na'jigaieg
# 2615 emego'tegew
# 2616 ne'patat
# 2617 kusna
# 2618 ewnasa'sit
# 2619 gepmite'tme
# 2620 Moqwa'
# 2621 sa'se'wi'tatlg
# 2622 sgu'lu
# 2623 awti'
# 2624 maqamige
# 2625 tewatalgan
# 2626 telui't'g
# 2627 wejitoqos
# 2628 Ganata
# 2629 gjiganji'j
# 2630 teluisig
# 2631 Halifax
# 2632 gjiga
# 2633 eteg
# 2634 maqamigew
# 2635 Ganat
# 2636 [Westaulg
# 2637 elg
# 2638 telui'tut
# 2639 Waseteg
# 2640 muta
# 2641 pas'g
# 2642 gisa'lataq
# 2643 mimajuinu'g
# 2644 gisi
# 2645 ns'tmi'tij
# 2646 teliaqewei
# 2647 ugjit
# 2648 Gjinisga
# 2649 Gesgmnaq
# 2650 ugs'tqamu
# 2651 gisita's'gtnugwe
# 2652 Gjiglusuaqan
# 2653 gis
# 2654 eig'
# 2655 Westaul
# 2656 Toqqwatg'pnig
# 2657 Gjinisgaml
# 2658 Gjinisgamewi
# 2659 N
# 2660 Mujga
# 2661 amgweseweie
# 2662 Westaulg
# 2663 Gjiglusuaqa
# 2664 toqqwatg'pnig
# 2665 Gjinisgam
# 2666 Gisitoqop
# 2667 'ms't
# 2668 neg
# 2669 Mo
# 2670 gisita's'gtnuisoq
# 2671 gisitugs'p
# 2672 Etna
# 2673 gisa'toqop
# 2674 mimajigtn
# 2675 ignmuataq
# 2676 iapjiwewei
# 2677 mimajuaqa
# 2678 Negmow
# 2679 msnmi'tij
# 2680 guguntaq
# 2681 Ugtwasetegm
# 2682 ilgwengutaq
# 2683 wijei
# 2684 waseteg
# 2685 oqonitpa'qigtu
# 2686 elaseg
# 2687 oqonitpa'qigtug
# 2688 oqonitpa'q
# 2689 nqa'suatug
# 2690 gatu
# 2691 wasetete
# 2692 tetaputesg
# 2693 iga'
# 2694 petgimapnn
# 2695 ugtagnutmewinuml
# 2696 Sa'
# 2697 Pegising
# 2698 tliman
# 2699 wasete
# 2700 glaman
# 2701 nuttaq
# 2702 agnutmaqan
# 2703 'gtlams'tta
# 2704 pegising
# 2705 wa'so'q
# 2706 Ilgwenaji
# 2707 gji'tutaq
# 2708 We'gaw
# 2709 gisitoqop
# 2710 ugs'tqam
# 2711 ugs'tqamugewaq
# 2712 nenua'ti'gw
# 2713 pegisinnite
# 2714 Je
# 2715 ugmaqamigemg
# 2716 elieteg
# 2717 ugtmimajuinum
# 2718 Lesui'pa
# 2719 menuege'tigupn
# 2720 Gatu
# 2721 wenig
# 2722 menuege'titl
# 2723 getlams'tua'titl
# 2724 ignmuaji
# 2725 un'jani
# 2726 Ta'nig
# 2727 getlams'tasulti'tij
# 2728 minui
# 2729 ugs'tqamultiji
# 2730 'st'ge'
# 2731 ginu
# 2732 ugs'tqamulti'gw
# 2733 gn'gi'guina
# 2734 ugs'tqamultijig
# 2735 ji'nmul
# 2736 ujjult'pn
# 2737 ujj
# 2738 gisa'laji
# 2739 mimajuinualsip
# 2740 eig'p
# 2741 wigulti'gw
# 2742 ta'sipunqe
# 2743 uleiugsi'gw
# 2744 telimugsi'gw
# 2745 Nisgam
# 2746 Ta'sieg
# 2747 nemitueg'p
# 2748 uggepmite'lgaqanm
# 2749 paqtate
# 2750 gepmitelgaqanm
# 2751 mesng'p
# 2752 Wegwisit
# 2753 newgte'jilitl
# 2754 un'jan
# 2755 wesgumat
# 2756 Gesigawwe
# 2757 “Etna
# 2758 wesgumg'p
# 2759 telueiane
# 2760 ‘Ugtejg
# 2761 ni'neg
# 2762 'pgisintew
# 2763 ji'n
# 2764 Me'
# 2765 espe'g
# 2766 igan
# 2767 i'g'p
# 2768 ugs'tqamuiwane
# 2769 nige'
# 2770 neialsi
# 2771 Se'sus
# 2772 n
# 2773 ”
# 2774 welapetmu'g
# 2775 pugwelgl
# 2776 goqwe'l
# 2777 ignmugsi'gw
# 2778 gelu'lgl
# 2779 tetuji
# 2780 pugwelgt'tal
# 2781 muni
# 2782 gsalugsi'gw
# 2783 gitmun
# 2784 gaqianug
# 2785 ignmugsi'gup
# 2786 'tplutaqan
# 2787 wet
# 2788 sapu
# 2789 lugwet
# 2790 Mowiso'q
# 2791 amujpa
# 2792 gaq
# 2793 jigs'tmugul
# 2794 gisna
# 2795 ugtap'titesn
# 2796 ugt'gsaltuaqanm
# 2797 apigsigtugsi'gw
# 2798 Se'sugulial
# 2799 gegina'mugsi'gw
# 2800 teliaqewe
# 2801 Menaq
# 2802 nemiagul
# 2803 Nisgaml
# 2804 un'jann
# 2805 uggwisl
# 2806 nemit
# 2807 Negm
# 2808 Nisgamewit
# 2809 e'taqatijig
# 2810 ujjl
# 2811 telimugsi'gup
# 2812 Lesui'paq
# 2813 iganpugultijig
# 2814 ta'nig
# 2815 eimu'tijig
# 2816 Selusalemg
# 2817 elgima'tiji
# 2818 patlia'sg
# 2819 alt
# 2820 apoqonmua'tiji
# 2821 'gjia'sutuo'guomg
# 2822 Sa'ne
# 2823 pipanimane
# 2824 “Wenin
# 2825 ta
# 2826 gi'
# 2827 ?
# 2828 Tali
# 2829 ugsualsin
# 2830 Nujiugs'tawi'wetewi
# 2831 petgimatal
# 2832 ilgwenan
# 2833 ugmimajuinum
# 2834 megt'g
# 2835 angam
# 2836 tlimaj
# 2837 “Moqwa
# 2838 Pipanima'tit
# 2839 “Gatu
# 2840 gi'l
# 2841 Gi'l
# 2842 iganigjitegewinu
# 2843 Ilaij
# 2844 Asitemaj
# 2845 “Moqwa'
# 2846 ni'
# 2847 “Gi'l
# 2848 wesgutg'
# 2849 Telima'tit
# 2850 “Tlimieg
# 2851 Amujpa
# 2852 apaja'tueg
# 2853 glusuaqan
# 2854 petgimugsieg'pni
# 2855 taltelsi
# 2856 asitemaj
# 2857 Teli
# 2858 ugsualsi
# 2859 ni'nna
# 2860 gesigawewistoqpaqtaqamigtu
# 2861 Gjisaqamaw
# 2862 wejgu'e
# 2863 Ms't
# 2864 te'sioq
# 2865 gisgajo'ltig
# 2866 iganigjitegewinuo'qAiseiao'q
# 2867 teluepna
# 2868 negmow
# 2869 elgimut'pnig
# 2870 Palasiaq
# 2871 pipanima'tit
# 2872 Nujiugs'tawi'wetewiwn
# 2873 Ilaija
# 2874 sign'tue
# 2875 “Samqwan
# 2876 e'wm
# 2877 mawpugua'tioq
# 2878 newgte'jit
# 2879 gilew
# 2880 nenuawo
# 2881 Nige'
# 2882 toqosip
# 2883 gji'jio
# 2884 no'q
# 2885 tepawgtiw
# 2886 we'gaw
# 2887 oqolomgwaqwa'sin
# 2888 apgwa'tuan
# 2889 umugsnapi'
# 2890 teliaqap
# 2891 gutan
# 2892 Pettani
# 2893 qame'g
# 2894 sipu
# 2895 Jol'ta
# 2896 ugjipenu
# 2897 sign'tuet
# 2898 na'te'
# 2899 wapgeg
# 2900 nemiatl
# 2901 Se'susal
# 2902 wejgu'elitl
# 2903 negmeg
# 2904 “Ge'
# 2905 lapita'g
# 2906 ugjijgluewji'jml
# 2907 ejigla'toqol
# 2908 ugtlue'utiwa
# 2909 ‘Ji'nm
# 2910 ugji
# 2911 pgisinte
# 2912 gejiaqap
# 2913 wenite
# 2914 pegisinap
# 2915 nut
# 2916 sign'tuan
# 2917 samqwanigtug
# 2918 gji'jiata
# 2919 “Nemi'g'p
# 2920 Wejuli
# 2921 nisa'sit
# 2922 ples
# 2923 eig
# 2924 Se'suseg
# 2925 Westaulge
# 2926 telianugweg
# 2927 nenuaqap
# 2928 petgimip
# 2929 telimi
# 2930 ‘Gi'l
# 2931 nmiates
# 2932 nisa'sitew
# 2933 i'ttew
# 2934 ji'nmu
# 2935 sign'tuetew
# 2936 e'watal
# 2937 tlue
# 2938 “Ni'n
# 2939 nemituap
# 2940 tlian
# 2941 telimuloq
# 2942 uggwis
# 2943 ap
# 2944 na'te'l
# 2945 sipug
# 2946 Jol'tan
# 2947 ugjipenug
# 2948 tapusiliji
# 2949 unaqapem
# 2950 nemiateg
# 2951 pemieli
# 2952 “Ula
# 2953 ugjijgluewji'jm
# 2954 Tapusiliji
# 2955 unaqapemg
# 2956 nuta'ti'titeg
# 2957 wije'wa'titl
# 2958 Se'susa
# 2959 gawasg'pugua'sit
# 2960 nemiaji
# 2961 majulgwalji
# 2962 pipanimaj
# 2963 “Goqwei
# 2964 puatmo
# 2965 asitema'tit
# 2966 “Tami
# 2967 wigi
# 2968 Lapa
# 2969 (Na
# 2970 Lapai
# 2971 “Nujigina'mue
# 2972 )
# 2973 “Wije'wi
# 2974 nat
# 2975 nmitu
# 2976 (Na'tami
# 2977 mewlia'gwe
# 2978 nemitu'titl
# 2979 wigilij
# 2980 wijitgweiwa'titl
# 2981 esgwiaq
# 2982 Newgte'jit
# 2983 ji'nmug
# 2984 Antle
# 2985 Simon
# 2986 wijigatiji
# 2987 Smtug
# 2988 Antle'
# 2989 gwiluatl
# 2990 wijigumatl
# 2991 Pie'lal
# 2992 telimat
# 2993 “Gisi
# 2994 weltesgaqat
# 2995 Nujiugs'tawi'wet
# 2996 megnatl
# 2997 pegisulatl
# 2998 Simonal
# 2999 Se'suse
# 3000 angamatl
# 3001 Simo
# 3002 guj
# 3003 tlitulten
# 3004 ‘Sipas
# 3005 wisun
# 3006 Pie'
# 3007 “gun'te
# 3008 wapg
# 3009 gisita'sit
# 3010 Galaliewa'gi
# 3011 Weltesguatl
# 3012 Pilipal
# 3013 “Jugu'
# 3014 wije'w
# 3015 Pilip
# 3016 tleiawit
# 3017 Petse'ta
# 3018 tleiawiji
# 3019 Natanielal
# 3020 “We'jig'tt'p
# 3021 Mowis
# 3022 ewi'gig'p
# 3023 wi'gatign
# 3024 'tplutaqanei
# 3025 iganigjitegewinugi'g
# 3026 ewi'gmi'ti
# 3027 So'sepal
# 3028 Nasaletgewa'
# 3029 Nataniel
# 3030 asita'pugue
# 3031 “Nat
# 3032 ugjietew
# 3033 Nasaletg
# 3034 gelu'si
# 3035 asitemat
# 3036 naji
# 3037 anga
# 3038 wije'watl
# 3039 Pilipa
# 3040 negme
# 3041 wejgu'et
# 3042 tetapu'et
# 3043 Isle'lewa'j
# 3044 sangewite'lmu
# 3045 Getmite'tg
# 3046 goqwe
# 3047 Gegnu
# 3048 pmiet
# 3049 pipanimat
# 3050 “Tal
# 3051 nenui
# 3052 “Nemu'lap
# 3053 eimneg
# 3054 pi'gmenaqsigtug
# 3055 wigumulugwe
# 3056 Isle'laq
# 3057 ugtelege'witemua
# 3058 “Etugjel
# 3059 gtlams'tmn
# 3060 tlimul
# 3061 nemu'lap
# 3062 pi'gmenaqsigtu
# 3063 Teliaq
# 3064 telimu
# 3065 'ms'gi'gt'tew
# 3066 nemitun
# 3067 ul
# 3068 “Telimulo
# 3069 nmittoqs'p
# 3070 pana's'g
# 3071 ugtansale'witemg
# 3072 toqjuitaliji
# 3073 wejgu
# 3074 nisita'liji
# 3075 mimajuinualsia
# 3076 telimulo
# 3077 tapuguna'gwe
# 3078 malie'uti
# 3079 gutanji'j
# 3080 Gen
# 3081 Galaliewa'gig
# 3082 uggwitl
# 3083 eimlit
# 3084 wigumut'pnig
# 3085 malie'ut
# 3086 moqopa'q
# 3087 samqwolti'ti
# 3088 toqotesip
# 3089 telimt
# 3090 “Ga'qanma'titeg
# 3091 moqopa'
# 3092 “Giju
# 3093 menaq
# 3094 tetaputestnug
# 3095 mesgi'gl
# 3096 tla'tegen
# 3097 mut
# 3098 sespete'tm
# 3099 Mali
# 3100 lugowinu'
# 3101 “Tla'taqatigw
# 3102 telimugsio
# 3103 epultijig
# 3104 asugom
# 3105 te'sijig
# 3106 samqwano'q
# 3107 gun'teweie'
# 3108 pisoqol
# 3109 aqataig
# 3110 malige'
# 3111 Wegla
# 3112 e'wmi'tij
# 3113 gisapa'tu'titl
# 3114 ugpitnual
# 3115 mijjulti'tij
# 3116 gesispa'laji
# 3117 telteg
# 3118 Lesui'pewei
# 3119 'tplutaqa
# 3120 “Ugjupego'lug
# 3121 negla
# 3122 tetpepego'la'tij
# 3123 “Nige'
# 3124 'nqana'mug
# 3125 la'tug
# 3126 iganpuguit
# 3127 malie'waqa
# 3128 ela'tua'ti
# 3129 wett'g
# 3130 gawasga'tas'g
# 3131 moqopa'qigtu
# 3132 geitug's
# 3133 (pas'g
# 3134 lugowinu'g
# 3135 nqanigmi'tij
# 3136 geitu'tij
# 3137 wigumatl
# 3138 malie'wilit
# 3139 Telimat
# 3140 “Tmg
# 3141 lugoug
# 3142 mujgajewei
# 3143 samqwolti'tij
# 3144 anawgtig
# 3145 geggunmn
# 3146 glapis
# 3147 ugtejgewe
# 3148 gaqa
# 3149 lugwatg
# 3150 amgwesewei
# 3151 ms'gi'g
# 3152 'lgowaqan
# 3153 musga'toq
# 3154 ugml'gigno'tim
# 3155 getlams'tua'tit
# 3156 malie'waqan
# 3157 gaqia
# 3158 uggwit
# 3159 ugjignam
# 3160 el'ta'jig
# 3161 Gapelniamg
# 3162 ta'suguna'
# 3163 gigja's'g
# 3164 ugpestiewtimuow
# 3165 “Siawa'timgewe
# 3166 ntuisgelatiji
# 3167 wen'jitia'mu
# 3168 jijgluewji'j
# 3169 sa'se'wa'taqatijig
# 3170 pemgopultijig
# 3171 ugpatautimua
# 3172 pugumaqan
# 3173 el'toq
# 3174 apapiei
# 3175 ejigltesguaji
# 3176 wi'sisg
# 3177 'gjia'sutuo'guom
# 3178 gitg
# 3179 jijgluewji'jg
# 3180 Aputasgate'gl
# 3181 ugpatautimual
# 3182 ugsulieweimual
# 3183 se'sa'teg
# 3184 ntuisga'tiliji
# 3185 “Tuo'lug
# 3186 negl
# 3187 Mut
# 3188 nujj
# 3189 wiguow
# 3190 e'wmuanew
# 3191 ntuisga'tim
# 3192 migwite'tmi'tij
# 3193 wi'gas'g'pneg
# 3194 ugtwi'gatig
# 3195 “'Ntnisgamum
# 3196 gesatmul
# 3197 giguow
# 3198 tela'taqati'tij
# 3199 giguaq
# 3200 asgaiwiji
# 3201 Tetuji
# 3202 uggwai
# 3203 sisue
# 3204 tla'tegej
# 3205 pipanima'titl
# 3206 “Wen
# 3207 ignmasg
# 3208 iganpugui
# 3209 Goqwei
# 3210 mesgi'g
# 3211 musga'tuitesnen
# 3212 “Gis
# 3213 gaqsuisga'tuoq
# 3214 a'sutuo'guo
# 3215 nesuguna'q
# 3216 apajitute
# 3217 “Ne'wisgegipunqeg'pnn
# 3218 gisitu'titeg
# 3219 a'sutuo'guom
# 3220 tl'te'tmn
# 3221 apajitutes
# 3222 a'sutuo'guomg
# 3223 nesuguna'
# 3224 sigti
# 3225 paqalaiultiji
# 3226 wesgutg'p
# 3227 wa'q
# 3228 nepliteg
# 3229 minunsite
# 3230 teluelis
# 3231 getlams'tmi'tij
# 3232 ugtwi'gatign
# 3233 ugglusuaqanm
# 3234 gaqi
# 3235 gji'tuaji
# ...
# 23330 Historic
# 23331 Project
# 23332 kaqi-kisa’tumkis
# 23333 Days
# 23334 Wooden
# 23335 Ships
# 23336 Brief
# 23337 History
# 23338 Madam
# 23339 wi’kiksip
# 23340 Bondro
# 23341 weji-naqalo’tmi’tis
# 23342 wikilik
# 23343 wasoqnmamkewey
# 23344 elmiktaqami
# 23345 pukwelta’tikisni
# 23346 pkwateluataq
# 23347 Kesatmek
# 23348 tela’tekem
# 23349 kaqi-kisitasik
# 23350 Nipialasutmam
# 23351 wasoqnmaqnatkwl
# 23352 panta’tumkisn
# 23353 newtuktmum
# 23354 isikui’skw
# 23355 Menaqajewa’sit
# 23356 nata’lukwe
# 23357 ktlukwaqn
# 23358 mese’
# 23359 pem-pa’skite’ke
# 23360 iloqaptik
# 23361 siawintoq
# 23362 siawlukwe
# 23363 Tal-lukwe
# 23364 aji-tmasqite’kl
# 23365 msiku’l
# 23366 aji-seta’newultita
# 23367 Wju’sn-iktuk
# 23368 pessetumk
# 23369 kisi-tmasqita’sik
# 23370 msik
# 23371 tkniewuti
# 23372 pemijuik
# 23373 wpukik
# 23374 wsisqunk
# 23375 witu’l
# 23376 nispa’q
# 23377 niwetesk
# 23378 ika’nuk
# 23379 tmasqite’kl
# 23380 pskweso’qn-iktu
# 23381 elqanatekewe’l
# 23382 eji-npisianik
# 23383 Mi’kmawe’knepiteka’tijik
# 23384 wkwisualkisinpis
# 23385 kiskajeyi
# 23386 Nklamuksis
# 23387 inaqank
# 23388 wtijin
# 23389 pa’sek
# 23390 waqa’qnik
# 23391 Elia’tisnik
# 23392 maskwie’k
# 23393 wteptaqnua
# 23394 sekki’sasijik
# 23395 jipiskl
# 23396 kelnmi’ti
# 23397 sespete’lmajl
# 23398 wji’numuml
# 23399 kejitoqsip
# 23400 apaji-pkisinlik
# 23401 Etawep
# 23402 iknua
# 23403 tli’katew
# 23404 wejuowkw
# 23405 i’tew
# 23406 Na’ku’set
# 23407 piskwasit
# 23408 tuopiti-iktu
# 23409 atlasmit
# 23410 petapilk
# 23411 epetek
# 23412 chocolate
# 23413 weli-eptek
# 23414 te’plma’sewe
# 23415 Wunjianuaq
# 23416 tepwijo’ltijik
# 23417 maliamanew
# 23418 jijklue’wjik
# 23419 ala’tu’tij
# 23420 Ewlikwetutki
# 23421 na’msitewe’l
# 23422 wunijan
# 23423 etl-wutqutasijl
# 23424 siawqatmn
# 23425 etl-wlqat
# 23426 siawa’toqsip
# 23427 Kisatalulti’tij
# 23428 amal-aknutma’tijik
# 23429 Jerseyewi’sultiji’k
# 23430 aji-mkink
# 23431 pestie’wa’laj
# 23432 malie’wili
# 23433 jukwa’latl
# 23434 ministl
# 23435 wejielitl
# 23436 Aklasiew’waki
# 23437 telte’tk
# 23438 panta’tasiktn
# 23439 pilui-ktlamsitasultijik
# 23440 tlo’taq
# 23441 menuaqluji
# 23442 welte’tk
# 23443 pipanuistmatew
# 23444 oqwa’tasik
# 23445 smaqkitasi
# 23446 e’pitaq
# 23447 mil-lukwetaq
# 23448 teli-pkijawsit
# 23449 asu’kitmi’tisn
# 23450 kistla’tekep
# 23451 elukomis
# 23452 napukwatasiktn
# 23453 nasmisko’lasnik
# 23454 pasko’ltilijik
# 23455 we’jiusnik
# 23456 mulqutimk
# 23457 eli’sikl
# 23458 Aklasie’wey
# 23459 wenujuey
# 23460 kisitoqi
# 23461 Mawo’tu’tij
# 23462 telo’titij
# 23463 wi’kasin
# 23464 klo’taq
# 23465 Mikma’k
# 23466 wije’wmi’ti
# 23467 anko’tmu’k
# 23468 emqatu’si’k
# 23469 we’ki
# 23470 kesite’tmi’tij
# 23471 akutulti’j
# 23472 kesala’tiji
# 23473 kekmite’lma’tij
# 23474 teluitmi’titl
# 23475 pestie’wa’laten
# 23476 waltesta’tijik
# 23477 ankaptmi’tik
# 23478 menaqajewa’sin
# 23479 pepke’jit
# 23480 Ta’pu
# 23481 metuei’k
# 23482 waltesta’titesnu
# 23483 lo’tan
# 23484 ne’wtewin
# 23485 ika’tan
# 23486 ta’puewin
# 23487 kmu’ji’jl’
# 23488 iko’toq
# 23489 pepse’k
# 23490 ktmaqseto’
# 23491 ela’lukwe
# 23492 patu’n
# 23493 “wapp
# 23494 kspu’tuwelital
# 23495 “Ela’lukwet
# 23496 elta’ji
# 23497 Na’newey
# 23498 ewni’skopalikaqnji’j
# 23499 me’newte’
# 23500 alsusulti’k
# 23501 l’nuwo’lti’k
# 23502 sape’wui
# 23503 Kespe’kewaq
# 23504 we’wmi’tij
# 23505 waqme’
# 23506 Tlia’kispesaq
# 23507 sespete’tmuk
# 23508 ne’ata’tew
# 23509 tua’lu
# 23510 pemita’ji
# 23511 Matle’newey
# 23512 pemlamutimi’tit
# 23513 so’qita’m
# 23514 pema’tu’titl
# 23515 pemukwala’tij
# 23516 Nujeywa’tiji
# 23517 piltuwila’lujik
# 23518 kuta’tikl
# 23519 pepkijeta’ql
# 23520 se’skutijik
# 23521 “Ta’ho
# 23522 ika’tu’tij
# 23523 ilta’luji
# 23524 apajita’tij
# 23525 Me’nk
# 23526 mawo’tu’tij
# 23527 kispasmi’ti
# 23528 ke’kwa’l
# 23529 ksinukowinu’k
# 23530 elo’tutl
# 23531 waqma’tu’tij
# 23532 Kaqapija’laltitl
# 23533 Aknutmi’tij
# 23534 kisw’
# 23535 Elta’mk
# 23536 wenaqo’tasit
# 23537 Teli-wtunkatmek
# 23538 Wjijaqmijl
# 23539 MandelaSape’wik
# 23540 pukmaqnnMatntimkewe’l
# 23541 etl-utqutasiklKaqmultiek
# 23542 wetapeksultiekAnli
# 23543 Maupltuo’
# 23544 koqwajo’taqaniktuk
# 23545 mataqa’taqan
# 23546 pjiw
# 23547 gepmite'lule
# 23548 Kina’matimkey
# 23549 Apoqnmati
# 23550 (KAK)
# 23551 telpijo’luj
# 23552 telnujeyuj
# 23553 o’plataqatijik
# 23554 pijo’lujik
# 23555 tapuipnqe
# 23556 kisima’muio’pla’lul
# 23557 pewalulnek
# 23558 keknuweyuksin
# 23559 ankweyuksin
# 23560 koqwajo’tiktuk
# 23561 kepmite’taqa
# 23562 Ukjiksu’k
# 23563 Wikultimkl
# 23564 Kisimsntes
# 23565 ketu’kjijitu’n
# 23566 amsala’lɨskɨ
# 23567 pasɨk
# 23568 eltaqte’majik
# 23569 NUKewaq
# 23570 kelutm
# 23571 kiseyasikw
# 23572 (sɨtke’
# 23573 ankweywatl
# 23574 kisio’pla’lutp
# 23575 telopla’teke
# 23576 ilsumutɨ
# 23577 keytu’n
# 23578 ta’nwen
# 23579 ‘opla’lsɨkɨ
# 23580 ‘knua’taqan
# 23581 kisie’wasɨktɨtew
# 23582 ilsumuj
# 23583 e’wasɨktɨtew
# 23584 mawita’tij
# 23585 NUK
# 23586 ilsutmi’tij
# 23587 apiksiktuksin
# 23588 apatkimuksin
# 23589 kisio’pla’tekep
# 23590 wikin
# 23591 teliltaqte’mulk
# 23592 tllimam’k
# 23593 pictured
# 23594 frame
# 23595 presented
# 23596 kisa’toq
# 23597 tel-knekk
# 23598 pekisuluksi’
# 23599 wejinmitasitewit
# 23600 be
# 23601 seen
# 23602 Camero
# 23603 wesua'tuek
# 23604 Unaited
# 23605 tel-tepkisa'toq
# 23606 telwl'te'tmek
# 23607 ajipjulkijjik
# 23608 Sko'siaewaq
# 23609 --
# 23610 kina'masultinew
# 23611 kjijitunew
# 23612 teli-milpntijik
# 23613 apoqnmuksinen
# 23614 ‘nsanoqona’tas’ktn
# 23615 ulo’tinenu
# 23616 wenwi’tmn
# 23617 weitaiek’p
# 23618 mawimtue’k
# 23619 tewjisa’q
# 23620 eimu’tiek
# 23621 Kpno’lewuti
# 23622 iktikek
# 23623 kitmnew
# 23624 kis-wi'km
# 23625 kis­pmiaq
# 23626 (-
# 23627 kjijitu'tij
# 23628 aji-wlpiatew
# 23629 telo'ltim
# 23630 elukwatme
# 23631 kis-tluek
# 23632 kisite'tmn
# 23633 lukwasin
# 23634 Kis-tlimultoqsi
# 23635 wji-kina’masitew
# 23636 welapesim
# 23637 wel-kina’masimk
# 23638 Ketu'
# 23639 wsku'tmann
# 23640 wi'katikn-iktu
# 23641 ComSta
# 23642 pem-pikwel-we'wasik
# 23643 maliaptmek
# 23644 winjik
# 23645 eymu'
# 23646 pisko'tu'ti
# 23647 estakepekejit
# 23648 Kepmite’lmuemkKepmite’te’n
# 23649 KkijinuMaqamike
# 23650 kepmite’lmKisiku’mimajuinu’k
# 23651 ta’ntel-milamuksit
# 23652 kwetnu’kwatk
# 23653 kisi-kekinu’-kina’muan
# 23654 ksi-nta’-lukutinew
# 23655 jiptueke’l
# 23656 wjietaqq
# 23657 wli-pkit-lukutitaqq
# 23658 wtapesultitaqq
# 23659 i’-nkuti-mimajuinu’
# 23660 utanmua
# 23661 “Piley
# 23662 pem-natelk
# 23663 tl-lukwess
# 23664 Kini’squneje’kemk
# 23665 mawki’kis
# 23666 weli-pkwataqatijik
# 23667 ekwitamewinu’k
# 23668 jakejue’kem
# 23669 telta’sultipnik
# 23670 siklati’
# 23671 ketana’tikipni
# 23672 Ekinua’tuasnik
# 23673 kis-malqumu
# 23674 nastesultiji
# 23675 mime’ji’j
# 23676 telita’sultijik
# 23677 qame’kewe’l
# 23678 natqapiluemkewe’l
# 23679 o’pla’tu’tijek
# 23680 teli-ktanuj
# 23681 telo’tmi’tij
# 23682 koqqwaja’luksiki’k
# 23683 nesutmumkek
# 23684 mercur
# 23685 Henry
# 23686 Stockle
# 23687 Link
# 23688 etli-esnoqa’tisnik
# 23689 Aputamkiejitewe’kati
# 23690 Marion
# 23691 Bridg
# 23692 Eykisnik
# 23693 sawbenchl
# 23694 ela’kittunew
# 23695 Kne’ke
# 23696 Vincent
# 23697 Donovan
# 23698 mulqemkewey
# 23699 kiskaja’taqn
# 23700 pikwekl
# 23701 eltasiksipnl
# 23702 wasoqateskewe
# 23703 nukte’mumk
# 23704 etl-klo’tmumk
# 23705 Ewe’wmumk
# 23706 wasaqta’w
# 23707 kisi-nispilmumk
# 23708 etl-mulqatekemk
# 23709 etl-mulqatmumkis
# 23710 ala’la’tisnik
# 23711 ika’taqnji’j
# 23712 kaqi-ksika’siksip
# 23713 Mc
# 23714 Evoy
# 23715 ika’taqaney
# 23716 weskwiaqsip
# 23717 ejikla’tasikek
# 23718 etli-ilite’tmumk
# 23719 etel
# 23720 maw-pukwelkik
# 23721 Eykinik
# 23722 Lithuaniansik
# 23723 atl-lukutinew
# 23724 Mines’i
# 23725 Pie’rk
# 23726 malsanewe’
# 23727 telita’sultisnik
# 23728 o’pla’taq
# 23729 teli’sultijik
# 23730 melkuktmi’tis
# 23731 poqtamkia’q
# 23732 pekwankwi’tis
# 23733 telita’simk
# 23734 kajjimenewo’ltim
# 23735 ika’tu’tisnl
# 23736 “La
# 23737 Societe
# 23738 L’assumption”
# 23739 etui’simkewey
# 23740 poqji-naqa’sikip
# 23741 lukewinue’l
# 23742 mawi-alsutasikl
# 23743 aji-nqamasiaq
# 23744 teli-i’k
# 23745 pemi-aji-tkle’jijk
# 23746 pekije’kek
# 23747 tepietaq
# 23748 pejiwsulupnik
# 23749 pemi-keknuika’tu’tij
# 23750 te’sunemiksim
# 23751 na’taqamto’ket
# 23752 putu
# 23753 ketmoqjikwatasik
# 23754 jitoqmumkl
# 23755 kiwto’qa’sikewe’l
# 23756 apaji-ke’kwa’tumk
# 23757 wutawti
# 23758 tel-mawa’luj
# 23759 at-lukutine
# 23760 nenmuk
# 23761 nsitmu
# 23762 “shifting
# 23763 links
# 23764 “sliding
# 23765 blocks
# 23766 “cross
# 23767 heads
# 23768 “equalizing
# 23769 beams
# 23770 Kaqiaql
# 23771 kaqiaql
# 23772 ksipukwa’taqnnNa’msit
# 23773 ewle’jultiek
# 23774 etajiktultesne
# 23775 we’kwi
# 23776 netajiktultesnenNmu’ltesnen
# 23777 pi’tipene
# 23778 lluikne’k
# 23779 assuatijo’lajik
# 23780 “picknickersik”
# 23781 atelika’tiji
# 23782 kepjoqa’tasiksip
# 23783 tapuiskimtlnaqnipunqe
# 23784 aknimujik
# 23785 tetuji-kejikawey
# 23786 lukweke
# 23787 alsutmi’ti
# 23788 (BESCO)
# 23789 pemi-ajki’ksi
# 23790 tlui’tasiksip
# 23791 DOSC
# 23792 weli-pkwatekeksip
# 23793 matntimkl
# 23794 Friday
# 23795 Hawker
# 23796 Siddily
# 23797 ekinua’tekeksip
# 23798 kepjoqa’tasik
# 23799 SYSC
# 23800 wtmtmo’taqney
# 23801 il-lukwasik
# 23802 apsa’tumk
# 23803 kepjoqa’tasikl
# 23804 etl-toqtaluj
# 23805 kespi-puktewsawek
# 23806 Slavicaq”
# 23807 mawa’tumk
# 23808 koqqwaja’tekemk
# 23809 weja’tu’tij
# 23810 tleyawulti’ti
# 23811 Lasui’pa
# 23812 etl-lukutikipnik
# 23813 tel-mawikwamk
# 23814 tl-kina’mua’tita
# 23815 aknutmaqne’l
# 23816 kis-wikasikek
# 23817 “From
# 23818 Dea
# 23819 sikoqi’katasiksip
# 23820 Bloom
# 23821 Mil
# 23822 l’uiknekewey
# 23823 tekpeka’luekewey
# 23824 sikoqta’siksipn
# 23825 “Wejko’tu’tij
# 23826 jijklue’wjuapi’
# 23827 ala’tu’tipnek
# 23828 nalkwe’mne
# 23829 piptoqopskik
# 23830 Etl-nalke’kemewe’l
# 23831 kepta’toq
# 23832 musika’luekewey
# 23833 ke’kwa’toq
# 23834 piptoqopskekiktu
# 23835 Chisholmal
# 23836 wikilitl
# 23837 Pukuluapemk
# 23838 wessua’tu’ti
# 23839 poqitiknji’j
# 23840 waqame’k
# 23841 essawiatmi’tis
# 23842 kisi’kasnik
# 23843 telawtiksip
# 23844 shillings
# 23845 shilling
# 23846 poqtamkiaq
# 23847 Kukwesaq
# 23848 MacAskillo’q
# 23849 Englishtown
# 23850 etl-kina’masisnaq
# 23851 asoqma’sis
# 23852 Kelly’s
# 23853 naji-kina’masi
# 23854 Munroeaq
# 23855 nu’ka’qsipni’k
# 23856 poqji-kina’mua’tisnik
# 23857 apje’jkl
# 23858 mukla’qatik
# 23859 telo’ltisni
# 23860 ekina’mua’tisnik
# 23861 kaqamiksipnek
# 23862 etl-klmuejaske’ka’timk
# 23863 Pataluti
# 23864 Pon
# 23865 nukwa’qsipnek
# 23866 miawnipk
# 23867 Wutankewaq
# 23868 awnasitu’tis
# 23869 kaqikisa’tasiksip
# 23870 mijuaji’jk
# 23871 nulmikjijitunew
# 23872 wla’taqatinew
# 23873 tel-kina’masulti’ti
# 23874 a’jela’tua’tij
# 23875 kisiku’ltite’wk
# 23876 kaqi-we’wmi’ti
# 23877 aji-nutqo’ltilijik
# 23878 wijikma’tijik
# 23879 MacFarlan
# 23880 nuji-kina’mues
# 23881 Pekte’snuk
# 23882 etlkina’mues
# 23883 pekte’snuk
# 23884 malie’wi’tikek
# 23885 Alec
# 23886 Granta
# 23887 wel-mikuite’tm
# 23888 etl-kiwtoqa’toq
# 23889 pitoqsit
# 23890 Mcmaster
# 23891 (nutkisnet
# 23892 ela’tumkl
# 23893 etli-pu’kwetmumk
# 23894 Fellows
# 23895 Hall”
# 23896 kejikiya
# 23897 elukweyap
# 23898 litaqwi’kikemk
# 23899 kaq-lukweyane
# 23900 wejikinu’tmasis
# 23901 Brothersey
# 23902 wikip
# 23903 nikana’lasnik
# 23904 Scout
# 23905 kapitanewip
# 23906 eliaql
# 23907 meski’kewe’l
# 23908 nemiu
# 23909 Union
# 23910 mtmo’taqewo’kuo’m
# 23911 Kwesamkia
# 23912 siawa’tumkewe’l
# 23913 Welkne’kek
# 23914 aja’tasiksi
# 23915 ela’tumkis
# 23916 malsano’kuo’mim
# 23917 Gran
# 23918 (Munroe)
# 23919 Naqana’pi’jk
# 23920 MacLea
# 23921 knek
# 23922 weji-wisunm
# 23923 MacMilla
# 23924 ketlewe’nuk
# 23925 etlite’tasik
# 23926 panta’siksip
# 23927 eljaqmumkis
# 23928 o’km
# 23929 sekapilasiksip
# 23930 weskitjaqasi
# 23931 Te’sipunqek
# 23932 mesin-lukwasi
# 23933 kis-kina’masijek
# 23934 tapuiskekayikl
# 23935 mattaqte’ket
# 23936 ika’qtitew
# 23937 mattaqte’k
# 23938 te’sunemi’kl
# 23939 kisi-naso’lajik
# 23940 Weji-mnkitasik
# 23941 telawti’tij
# 23942 etl-mawse’nmamk
# 23943 poqji-lukwatmap
# 23944 elqatija’sikl
# 23945 tapaqn-iktu
# 23946 ntlmaqnm
# 23947 ketaqateskmuksiap
# 23948 ntun
# 23949 elmiku’te’kaq
# 23950 apaji-qama’si
# 23951 Wejueya
# 23952 kis-nasa’tupnl
# 23953 newe’jilitl
# 23954 mkumie’jl
# 23955 wesimkwa
# 23956 oqwe’
# 23957 jipaqo’ltiji
# 23958 maltejueye
# 23959 Rubbere’l
# 23960 tl-tmsitesk
# 23961 tetpaqikiji
# 23962 pemjiklika’t
# 23963 pessik
# 23964 pukwelki’
# 23965 Wunaqiatulta
# 23966 tel-lukweya
# 23967 Awnaqa
# 23968 patkwete’k
# 23969 MacLellano’
# 23970 mal’pale’wita
# 23971 npaq
# 23972 “we’
# 23973 kisi-iloqaptikek
# 23974 tli-ksua’tutes-
# 23975 klu’ktn
# 23976 Melkiaqasit
# 23977 tlueti
# 23978 nu’kwa’q
# 23979 etl-lukwen
# 23980 nu’kwa’
# 23981 Apoqnmaqip
# 23982 nujja
# 23983 telte’tm
# 23984 wkwija
# 23985 teltenuksipnl
# 23986 apankituksiweki
# 23987 Elie’sip
# 23988 aji-nikalt
# 23989 npuin
# 23990 Kelu’sitaq
# 23991 MacDonaldo’
# 23992 Na’te’
# 23993 pektaqi-kisoqe’k
# 23994 welikwenmaql
# 23995 mil-qamikek
# 23996 elakwekl
# 23997 naqtasikl
# 23998 maw-klu’kipnl
# 23999 melkilukutijik
# 24000 etlqatmne
# 24001 Pemayjimkutitijek
# 24002 nemitu’tij
# 24003 kikjikatultimk
# 24004 amaskmi’tiksip
# 24005 l’ta’ji
# 24006 amasqaltultijik
# 24007 alasutuo’kuo’
# 24008 Pekitqatkis
# 24009 wutjewijik
# 24010 assua’tisnik
# 24011 naji-mittukwalane
# 24012 wessua’tu’tis
# 24013 i’ka’taqneymuew
# 24014 Mulapukek
# 24015 toqi
# 24016 maliaptmi’tis
# 24017 Apoqnmuksiek
# 24018 tel-jukwitayek
# 24019 nklamuksi
# 24020 Senusaqtek
# 24021 Malapukue
# 24022 lita’suatmnen
# 24023 teli-kiskik
# 24024 alatuek
# 24025 a’qatpiatek
# 24026 wla’site
# 24027 Kisikwena’tipnik
# 24028 Kisi-mawte’mne
# 24029 Nqano’pati’jek
# 24030 nikna
# 24031 pite’mamkewe
# 24032 etli-mawto’p
# 24033 poqtapilut
# 24034 etl-kleyu
# 24035 katu’
# 24036 welta’simk
# 24037 mlakejewu’lkw
# 24038 oqwa’
# 24039 sespeta’simi
# 24040 Eskmayek
# 24041 piskia
# 24042 elika’timk
# 24043 tel-temik
# 24044 nemiujik
# 24045 lampo’
# 24046 Pilui-ktanujik
# 24047 alisukwiek
# 24048 ekina’masit
# 24049 pemi-aji-tkle’jijik
# 24050 wissukwa’tij
# 24051 winamukwa’tu’k
# 24052 ketmaqseto’jik
# 24053 mejike’k
# 24054 teli-nqamasianuk
# 24055 pa’skite’ketki’k
# 24056 loqte’kniketki’
# 24057 sespete’tme
# 24058 teli-anko’tmumk
# 24059 Apoqntmn
# 24060 wsitqamey
# 24061 iljo’te
# 24062 nisaqn
# 24063 Wisqisultiji
# 24064 kimteskuj
# 24065 kesikawita’ta
# 24066 mtiji
# 24067 wije’wuksiekik
# 24068 kate’ka’tiji
# 24069 kesiktana’tijik
# 24070 wikpa’tiki
# 24071 kisiajik
# 24072 ne’aqa’taqnn
# 24073 Peji-mittukwalkip
# 24074 wlqatmekip
# 24075 apaja’tinen
# 24076 kaqi-kina’masi
# 24077 amal-lukwemk
# 24078 ewe’wmap
# 24079 mesnmanek
# 24080 mulinji’ja’si
# 24081 I’ke’kwa’tuapnek
# 24082 npo’qn-iktu
# 24083 kesnukwajek
# 24084 entuap
# 24085 ankui’kasi
# 24086 ankui’kaye’k
# 24087 kisitoqip
# 24088 kisituipne
# 24089 poqji-luli’tijiik
# 24090 l’tuan
# 24091 kisite’tkip
# 24092 telpili
# 24093 kisi-mawi’smumkl
# 24094 (weskewe’k
# 24095 Ala’tijik
# 24096 al-jikeywa’tijik
# 24097 Eluluksi
# 24098 nikan-tlimuksi
# 24099 menueke’ti
# 24100 we’jituap
# 24101 wltetew
# 24102 elqanatekewe
# 24103 elieya
# 24104 ewi’km
# 24105 jitnatqa’m
# 24106 a’tlawekn-iktu
# 24107 ilekism
# 24108 nasa’t
# 24109 Kelwi’km
# 24110 Wasoqitestu
# 24111 kaqi-nasi’si
# 24112 nutayan
# 24113 ala’tes
# 24114 kisi-wasoqitestasi
# 24115 Siku’skewianek
# 24116 ewle’jiap
# 24117 maliamkik
# 24118 nijink
# 24119 kisita’siap
# 24120 pekwateke
# 24121 kaqi-nastapoqa’teken
# 24122 tetpapeka’teke
# 24123 kaqi-kisa’lit
# 24124 mawi’sa
# 24125 Etlite’tm
# 24126 Etang
# 24127 wi’katiknek
# 24128 teluisikek
# 24129 “Cabot
# 24130 Whit
# 24131 l’ta’tij
# 24132 nmia’tital
# 24133 Unama’kikewe’l
# 24134 pkwateltaq
# 24135 Tela’tekek
# 24136 amalsasiji
# 24137 Weja’tu
# 24138 kisitaqn
# 24139 amalikk
# 24140 wlpultijik
# 24141 welitpamuksijik
# 24142 wel-wikasultijik
# 24143 tetapui-nastapoqata’sik
# 24144 pipanimus
# 24145 maw-meskilkl
# 24146 etlitasitl
# 24147 kaqapijo’la’tisnik
# 24148 ekna’taqne’l
# 24149 etl-mawita’mkewey
# 24150 peji-mittukutijik
# 24151 wsupu’taqn
# 24152 kisaptmuj
# 24153 maw-wltek
# 24154 Mittukutite’wk
# 24155 mknanew
# 24156 kespu’tuelitl
# 24157 mekena’tisnl
# 24158 Catherineal
# 24159 naqsunm
# 24160 el’toqsipnl
# 24161 kna’taqne’l
# 24162 kepmite’taqney
# 24163 kispukua’tu’tip
# 24164 weji-pkwata’tisnik
# 24165 maliama’tijik
# 24166 etlitasi
# 24167 ekimujek
# 24168 tekle’jisnik
# 24169 el’tu’tij
# 24170 mtmo’taqewo’kuom
# 24171 siawqatmu’tijek
# 24172 tli-ankaptasik
# 24173 e’pite’ski’
# 24174 ewle’jultisnik
# 24175 pejita’sni’k
# 24176 mimajuaq
# 24177 pejitkweywa’tijik
# 24178 wjiknamuaq
# 24179 wo’kmawa
# 24180 lukutijik
# 24181 al-waqama’taqatine
# 24182 ajipjutmi’tij
# 24183 espi-kina’masulti’tij
# 24184 nutsaqika’tijik
# 24185 ewi’kika’tiji
# 24186 nepitaqatiji
# 24187 etli-npitekemk
# 24188 mtmo’taqne’
# 24189 Kisaknutma'ti'kw
# 24190 kkpno'minaq
# 24191 weja'tekmk
# 24192 mawlukutinew
# 24193 e'wmu'k
# 24194 kepmite'taqan
# 24195 welte'taqan
# 24196 telmawpukulti'k
# 24197 tlísuti
# 24198 (tel-wikasik
# 24199 Alasiéw-iktuk
# 24200 Wenuj-iktuk)
# 24201 tléawik
# 24202 eweketútij
# 24203 wqayij
# 24204 tésijik
# 24205 Míkmawa
# 24206 Pastunkewáki
# 24207 eykepenik
# 24208 wikipenik
# 24209 Natel
# 24210 kisitetemitisenek
# 24211 siaw-katemene
# 24212 eltuwaji
# 24213 wikuwa
# 24214 ewsi
# 24215 samkwaneke
# 24216 alapasi
# 24217 kekunkl
# 24218 jilamuk
# 24219 jipal
# 24220 Netake
# 24221 i’-naqawe
# 24222 teli-kjijituekip
# 24223 seyeimik
# 24224 Kelo’tmuinamitt
# 24225 ajipjitasut
