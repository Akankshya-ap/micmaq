# %%
fil=[]
doc=[]
par=[]
sent=[]
lines=''
k=0
####sentence_wise
f0=open('/home/apatra/Desktop/work/doc/corpus_edited_sent.txt','w')
#####paragraph_wise
f1=open('/home/apatra/Desktop/work/doc/corpus_edited_par.txt','w')
#####document_wise
f2=open('/home/apatra/Desktop/work/doc/corpus_edited_doc.txt','w')
with open('/home/apatra/Desktop/work/corpus_micmac_cleanponctuation.txt') as f4:
    for line in f4:   

        if '</s>' in line:
            #print "hi"
            k=0
            print lines
            f0.write(lines)
            f0.write("\n")
            par.append(lines)
            lines=''
        if k==1:
            if '\r\n' or '\n' in line:
                #print "hi"
                #print line
                line=line.replace("\r\n"," ")
                line=line.replace(",","")
                line=line.replace(".","")
                line=line.replace("?","")
            lines+=line
        if '<s>' in line:
            #print "hi"
            k=1

        if '</p>' in line:
            f1.write(str(par))
            f1.write("\n")
            doc.append(par)
            #print doc
            par=[]
        if '</doc>' in line:
            f2.write(str(doc))
            f2.write("\n")
            fil.append(doc)
            #print fil
            doc=[]
    #print len(fil)
    #print fil
# Out:
# Mtul’katlku Wjit Koqwajo’taqann Mimajulnu’k Wejkuaqml’tlj
# Na Ke’sk kejitastkl wkpmlte’taqn lapjiw lame’k eykl aqq nkute’jklaqqmukislkaswl’kasinukl koqwajo’taqann wejku’laqml’tl mimajulnu’k na nekmewe’lelqanetekewe’l wjit alsumsim  koqwaja’taqan aqq wantaqo’tl wsitqamu’
# Na Ke’sk penoqlte’taqan aqq esatite’tmaqan wjit koqwajo’taqann wejku’iaqmi’titlmimajulnu’k wetapeksi’kl elue’wuti’l ta’n msit wen poqwajite’tikl aqq wejkwite’tmkwsitqamu ta’n tett msit wen alsutk ta’n teluej aqq teli-ktlamsltasij aqq alsutkpmawsin keskmna’q we’kwata’sik kisna kewisinu  na wla kisi tlapukuemk msitmimajulnu’k tliktantunew mawi espe’
# Na Ke’sk nuta’q ta’n tijiw ji’nm mu ketu’ kisa’lawt eliapsin mitakespiagewe  matneke  matnmn kestawite’taqan aqq emekwo’tasim  na koqwajo’taqannwejku’laqmi’tl mimajulnu’k miamuj etli-ankwo’tasikl tplutaqaniktu
# Na Ke’sk nuta’q apoqonmatamn ta’n tela’matultljik eleke’wa’ki’
# ...

# %%
f0.close()
f1.close()
f2.close()

# %%
###number of documents
print len(fil)
# Out:
# 69

# %%
f0=open('/home/apatra/Desktop/work/doc/corpus_edited_sent.txt','r')

x0=f0.read()
#####number of tokens
print len(x0.split())
# Out:
# 65754

# %%
#####number of types
print(len(set(x0.split())))
# Out:
# 24225

# %%
for x in  (set(x0.split())):
    print x
# Out:
# kisi-mawanqa’tumkek
# aklasiewaloqsultiji
# esma’titl
# gelulatl
# etlitum
# Malpalewitelemut
# pem-natelk
# gi'lewei
# Western
# litaqnwikas’kl
# mimajuinuigtug
# Valle
# atkitemi
# mikwite’tmu
# maw-wlamu’k
# Kaplno'l
# kiwto’qa’sikewe’l
# elakutultijik
# apgwa'tuan
# jijgluewjig
# iknemat
# pilue’
# “Toqwaqji’jk
# pma'toq
# nemiatijel
# wels'tua'tigul
# kajjimenewa’kik
# wtuisunmual
# iknemaj
# wuji
# wejgwa'lawoqo
# teke’k
# nasgua'tiji
# nuj-seknika’tijik)
# telkisi
# mawelkisni
# a'tugwaqa
# tetpoqpilaqn
# Ewe’wmn
# Naqtiki’l
# Tal-lukwe
# pem-ajelkik
# westawu’lkw
# pajjoqe’kemk
# kidi
# kisikuitl
# ukwita'q
# ta'p
# seskutaq
# la'lukete
# wije’wmi’ti
# ta'n
# un'jan
# gji'jiaqat
# nutaptukl
# Vernon
# (rattle)
# Mawiomijijel
# Eleke’waki
# ntawa’qa’taqatijik
# pemi______________elkomiktule
# nutankuat
# Melkiknaq
# te'sukunit
# Snapshot
# ktantekelin
# Miti's
# eleka’lik
# kmu’ji’jek
# puljaynewe’l
# mime’jk
# wape'gna'milij
# toqi-lukuti’tiji
# Morrel
# eliaqi
# eliaql
# Le
# ...
